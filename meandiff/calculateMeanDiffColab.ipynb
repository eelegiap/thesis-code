# %%
import pandas as pd
import random
import json
import math
import statistics
import re
import time
import numpy as np

# %% [markdown]
# ### Stanza doesn't work fuck

# %%
# pip uninstall stanza -y

# %%
# pip install stanza

# %%
import stanza
# stanza.download('uk')
stanza.download('ru')

# %%
nlp = stanza.Pipeline('ru',processors='tokenize,pos,lemma')
# Out:
# 2022-10-22 12:30:59 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# 2022-10-22 12:31:00 INFO: Loading these models for language: ru (Russian):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | syntagrus |
# | pos       | syntagrus |
# | lemma     | syntagrus |
# =========================
#
# 2022-10-22 12:31:00 INFO: Use device: cpu
# 2022-10-22 12:31:00 INFO: Loading: tokenize
# 2022-10-22 12:31:00 INFO: Loading: pos
# 2022-10-22 12:31:01 INFO: Loading: lemma
# 2022-10-22 12:31:01 INFO: Done loading processors!

# %% [markdown]
# ### Does Spacy work?

# %%
# pip install spacy

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# !python -m spacy download ru_core_news_lg
# Out:
# Collecting ru-core-news-lg==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_lg-3.4.0/ru_core_news_lg-3.4.0-py3-none-any.whl (513.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.4/513.4 MB 481.3 kB/s eta 0:00:0000:0100:02
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from ru-core-news-lg==3.4.0) (3.4.2)
# Requirement already satisfied: pymorphy2>=0.9 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from ru-core-news-lg==3.4.0) (0.9.1)
# Requirement already satisfied: dawg-python>=0.7.1 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from pymorphy2>=0.9->ru-core-news-lg==3.4.0) (0.7.2)
# Requirement already satisfied: docopt>=0.6 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from pymorphy2>=0.9->ru-core-news-lg==3.4.0) (0.6.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from pymorphy2>=0.9->ru-core-news-lg==3.4.0) (2.4.417127.4579844)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (0.4.2)
# Requirement already satisfied: setuptools in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (63.4.1)
# Requirement already satisfied: packaging>=20.0 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (21.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (1.0.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (1.10.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (1.0.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2.28.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (3.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (4.64.1)
# Requirement already satisfied: pathy>=0.3.5 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (0.6.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (1.23.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (3.0.10)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (8.1.5)
# Requirement already satisfied: jinja2 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (3.1.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (3.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/paigelee/opt/anaconda3/envs/stanzaenv/lib/python3.10/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2.1.1)
# Installing collected packages: ru-core-news-lg
# Successfully installed ru-core-news-lg-3.4.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_lg')

# %%
import spacy 
nlp = spacy.load("ru_core_news_lg")

# %% [markdown]
# ### Install other pacakges

# %%
# pip install nltk

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/paigelee/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import stopwords

rustops = set(stopwords.words('russian'))
ukstops = ['а', 'аби', 'абиде', 'абиким', 'абикого', 'абиколи', 'абикому', 'абикуди', 'абихто', 'абичий', 'абичийого', 'абичийому', 'абичим', 'абичию', 'абичия', 'абичиє', 'абичиєму', 'абичиєю', 'абичиєї', 'абичиї', 'абичиїй', 'абичиїм', 'абичиїми', 'абичиїх', 'абичого', 'абичому', 'абищо', 'абияка', 'абияке', 'абиякий', 'абияким', 'абиякими', 'абияких', 'абиякого', 'абиякому', 'абиякою', 'абиякої', 'абияку', 'абиякі', 'абиякій', 'абиякім', 'або', 'абощо', 'авжеж', 'авось', 'ага', 'ад', 'адже', 'аж', 'ажень', 'аз', 'ай', 'але', 'ало', 'амінь', 'ант', 'ану', 'ані', 'аніде', 'аніж', 'анізащо', 'аніким', 'анікого', 'анікогісінько', 'аніколи', 'анікому', 'аніскільки', 'аніхто', 'анічим', 'анічого', 'анічогісінько', 'анічому', 'аніщо', 'аніяка', 'аніяке', 'аніякий', 'аніяким', 'аніякими', 'аніяких', 'аніякого', 'аніякому', 'аніякою', 'аніякої', 'аніяку', 'аніякі', 'аніякій', 'аніякім', 'аніякісенька', 'аніякісеньке', 'аніякісенький', 'аніякісеньким', 'аніякісенькими', 'аніякісеньких', 'аніякісенького', 'аніякісенькому', 'аніякісенькою', 'аніякісенької', 'аніякісеньку', 'аніякісенькі', 'аніякісенькій', 'аніякісенькім', 'аніякісінька', 'аніякісіньке', 'аніякісінький', 'аніякісіньким', 'аніякісінькими', 'аніякісіньких', 'аніякісінького', 'аніякісінькому', 'аніякісінькою', 'аніякісінької', 'аніякісіньку', 'аніякісінькі', 'аніякісінькій', 'аніякісінькім', 'ат', 'ато', 'атож', 'ау', 'ах', 'ач', 'ачей', 'аякже', 'б', 'ба', 'багато', 'багатьма', 'багатьом', 'багатьох', 'баз', 'бай', 'бат', 'бах', 'бац', 'баш', 'бе', 'беж', 'без', 'безперервно', 'бел', 'бер', 'би', 'бир', 'бич', 'близько', 'близько від', 'бо', 'бов', 'бод', 'бодай', 'боз', 'бош', 'був', 'буває', 'буде', 'будем', 'будемо', 'будете', 'будеш', 'буду', 'будуть', 'будь', 'будь ласка', 'будьмо', 'будьте', 'була', 'були', 'було', 'бути', 'бух', 'буц', 'буцім', 'буцімто', 'бі', 'біб', 'більш', 'більше', 'біля', 'в', 'в бік', 'в залежності від', 'в міру', 'в напрямі до', 'в порівнянні з', 'в процесі', 'в результаті', 'в ролі', 'в силу', 'в сторону', 'в супроводі', 'в ході', "в ім'я", 'в інтересах', 'вад', 'важлива', 'важливе', 'важливий', 'важливі', 'вак', 'вам', 'вами', 'ван', 'вас', 'ват', 'ваш', 'ваша', 'ваше', 'вашим', 'вашими', 'ваших', 'вашого', 'вашому', 'вашою', 'вашої', 'вашу', 'ваші', 'вашій', 'вашім', 'ввесь', 'вві', 'вгору', 'вдалині', 'вед', 'верх', 'весь', 'вех', 'вже', 'вздовж', 'ви', 'виз', 'вис', 'височині', 'вище ', 'вйо', 'власне', 'властиво', 'вміти', 'внаслідок', 'вниз', 'внизу', 'во', 'вон', 'вона', 'вони', 'воно', 'восьмий', 'вперед', 'вподовж', 'впоперек', 'впритиск', 'впритул', 'впродовж', 'впрост', 'все', 'всередині', 'всею', 'вслід', 'всупереч', 'всього', 'всьому', 'всю', 'всюди', 'вся', 'всяк', 'всяка', 'всяке', 'всякий', 'всяким', 'всякими', 'всяких', 'всякого', 'всякому', 'всякою', 'всякої', 'всяку', 'всякі', 'всякій', 'всякім', 'всі', 'всій', 'всіляка', 'всіляке', 'всілякий', 'всіляким', 'всілякими', 'всіляких', 'всілякого', 'всілякому', 'всілякою', 'всілякої', 'всіляку', 'всілякі', 'всілякій', 'всілякім', 'всім', 'всіма', 'всіх', 'всією', 'всієї', 'втім', 'ві', 'віг', 'від', 'від імені', 'віддалік від', 'відколи', 'відносно', 'відповідно', 'відповідно до', 'відсотків', 'відтепер', 'відтоді', 'він', 'вісім', 'вісімнадцятий', 'вісімнадцять', 'віт', 'віф', 'віх', 'віц', 'віщо', 'віщось', 'г', 'га', 'гав', 'гаразд', 'ге', 'гез', 'гем', 'геп', 'гет', 'геть', 'гех', 'ги', 'гик', 'гир', 'гич', 'гм', 'го', 'говорив', 'гог', 'гоп', 'гоц', 'гу', 'гуп', 'д', 'да', 'давай', 'давати', 'давно', 'далеко', 'далеко від', 'далі', 'даром', 'два', 'двадцятий', 'двадцять', 'дванадцятий', 'дванадцять', 'двох', 'дві', 'де', "дев'ятий", "дев'ятнадцятий", "дев'ятнадцять", "дев'ять", 'дедалі', 'деким', 'декого', 'деколи', 'декому', 'декотра', 'декотре', 'декотрий', 'декотрим', 'декотрими', 'декотрих', 'декотрого', 'декотрому', 'декотрою', 'декотрої', 'декотру', 'декотрі', 'декотрій', 'декотрім', 'декілька', 'декільком', 'декількома', 'декількох', 'декім', 'десь', 'десятий', 'десять', 'дехто', 'дечий', 'дечийого', 'дечийому', 'дечим', 'дечию', 'дечия', 'дечиє', 'дечиєму', 'дечиєю', 'дечиєї', 'дечиї', 'дечиїй', 'дечиїм', 'дечиїми', 'дечиїх', 'дечого', 'дечому', 'дечім', 'дещо', 'деяка', 'деяке', 'деякий', 'деяким', 'деякими', 'деяких', 'деякого', 'деякому', 'деякою', 'деякої', 'деяку', 'деякі', 'деякій', 'деякім', 'деінде', 'для', 'до', 'добре', 'довго', 'довкола', 'довкіл', 'дог', 'доки', 'допоки', 'допіру', 'досить', 'досі', 'дотепер', 'доти', 'другий', 'друго', 'дуже', 'дякую', 'дійсно', 'діл', 'е', 'еге', 'еж', 'ей', 'ерг', 'ест', 'ет', 'ех', 'еч', 'ж', 'же', 'жоден', 'жодна', 'жодне', 'жодний', 'жодним', 'жодними', 'жодних', 'жодного', 'жодному', 'жодною', 'жодної', 'жодну', 'жодні', 'жодній', 'жоднім', 'жоднісінька', 'жоднісіньке', 'жоднісінький', 'жоднісіньким', 'жоднісінькими', 'жоднісіньких', 'жоднісінького', 'жоднісінькому', 'жоднісінькою', 'жоднісінької', 'жоднісіньку', 'жоднісінькі', 'жоднісінькій', 'жоднісінькім', 'жуз', 'з', 'з метою', 'з нагоди', 'з приводу', 'з розрахунку на', 'з-за', 'з-над', 'з-перед', 'з-поза', 'з-поміж', 'з-понад', 'з-поперед', 'з-посеред', 'з-проміж', 'з-під', 'з-серед', 'за', 'за винятком', 'за допомогою', 'за посередництвом', 'за рахунок', 'завгодно', 'завдяки', 'завжди', 'завше', 'задля', 'зазвичай', 'зайнята', 'зайнятий', 'зайнято', 'зайняті', 'залежно', 'залежно від', 'замість', 'занадто', 'заради', 'зараз', 'зас', 'зате', 'збоку', 'збоку від', 'зважаючи на', 'зверх ', 'зверху', 'звичайно', 'звиш', 'звідки', 'звідкилясь', 'звідкись', 'звідкіль', 'звідкіля', 'звідкілясь', 'звідси', 'звідсіль', 'звідсіля', 'звідти', 'звідтіль', 'звідтіля', 'звідусюди', 'звідусіль', 'звідціля', 'згідно з', 'здається', 'здовж', 'зем', 'зет', 'ззаду', 'зиз', 'зик', 'значить', 'знову', 'зо', 'зовсім', 'зсередини', 'зух', 'зі', 'зіс', 'и', 'ич', 'й', 'ймовірно', 'йно', 'йо', 'його', 'йой', 'йол', 'йому', 'йор', 'йот', 'йох', 'к', 'каже', 'каз', 'кар', 'каф', 'ках', 'ке', 'кед', 'кет', 'кеш', 'кив', 'кий', 'кил', 'ким', 'кимось', 'кимсь', 'ких', 'киш', 'коб', 'коби', 'кого', 'когось', 'кожен', 'кожна', 'кожне', 'кожний', 'кожним', 'кожними', 'кожних', 'кожного', 'кожному', 'кожною', 'кожної', 'кожну', 'кожні', 'кожній', 'кожнім', 'кожнісінька', 'кожнісіньке', 'кожнісінький', 'кожнісіньким', 'кожнісінькими', 'кожнісіньких', 'кожнісінького', 'кожнісінькому', 'кожнісінькою', 'кожнісінької', 'кожнісіньку', 'кожнісінькі', 'кожнісінькій', 'кожнісінькім', 'коли', 'колись', 'коло', 'кому', 'комусь', 'котра', 'котрась', 'котре', 'котресь', 'котрий', 'котрийсь', 'котрим', 'котрими', 'котримись', 'котримось', 'котримсь', 'котрих', 'котрихось', 'котрихсь', 'котрого', 'котрогось', 'котрому', 'котромусь', 'котрою', 'котроюсь', 'котрої', 'котроїсь', 'котру', 'котрусь', 'котрі', 'котрій', 'котрійсь', 'котрім', 'котрімсь', 'котрісь', 'коц', 'коч', 'коштом', 'край', 'краще', 'кру', 'круг', 'кругом', 'крю', 'кря', 'крізь', 'крім', 'куди', 'кудись', 'кудою', 'кілька', 'кільком', 'кількома', 'кількох', 'кім', 'кімось', 'кімсь', 'кінець', 'л', 'лаж', 'лап', 'лас', 'лат', 'ле', 'ледве', 'ледь', 'лет', 'лиш', 'лише', 'лишень', 'лум', 'луп', 'лут', 'льє', 'люди', 'людина', 'ля', 'лі', 'ліворуч від', 'лік', 'лім', 'м', 'мабуть', 'майже', 'мало', 'мати', 'мац', 'ме', 'меж', 'мене', 'менше', 'мені', 'мерсі', 'мет', 'мжа', 'ми', 'мимо ', 'миру', 'мит', 'мною', 'мо', 'мов', 'мовби', 'мовбито', 'могла', 'могли', 'могло', 'мого', 'могти', 'мож', 'може', 'можем', 'можемо', 'можете', 'можеш', 'можна', 'можу', 'можуть', 'можіть', 'мой', 'мол', 'мою', 'моя', 'моє', 'моєму', 'моєю', 'моєї', 'мої', 'моїй', 'моїм', 'моїми', 'моїх', 'му', 'мі', 'міг', 'між', 'мій', 'мільйонів', 'н', 'на', 'на адресу', 'на базі', 'на благо', 'на випадок', 'на відміну від', 'на засадах', 'на знак', 'на зразок', 'на користь', 'на кшталт', 'на межі', 'на основі', 'на противагу', 'на підставі', 'на честь', 'на чолі', 'на ґрунті', 'навколо', 'навкруг', 'навкруги ', 'навкіл', 'навпаки', 'навперейми', 'навпроти', 'навіть', 'навіщо', 'навіщось', 'нагорі', 'над', 'надо', 'надовкола', 'надокола', 'наді', 'назавжди', 'назад', 'назустріч', 'най', 'найбільш', 'нам', 'нами', 'наоколо ', 'наокруг ', 'наокруги ', 'наокіл', 'наперед', 'напередодні', 'напереді', 'наперекір', 'напереріз', 'наприкінці', 'напроти', 'нарешті', 'нарівні з', 'нас', 'насеред', 'насподі', 'наспід', 'настрічу', 'насупроти', 'насупротив ', 'нате', 'наче', 'начеб', 'начебто', 'наш', 'наша', 'наше', 'нашим', 'нашими', 'наших', 'нашого', 'нашому', 'нашою', 'нашої', 'нашу', 'наші', 'нашій', 'нашім', 'не', 'не до', 'не можна', 'неабичим', 'неабичого', 'неабичому', 'неабищо', 'небагато', 'небагатьма', 'небагатьом', 'небагатьох', 'небудь', 'невважаючи', 'невже', 'недалеко', 'недалеко від', 'неж', 'незалежно від', 'незважаючи', 'незважаючи на', 'ней', 'немає', 'немов', 'немовби', 'немовбито', 'неначе', 'неначебто', 'неподалеку', 'неподалеку від', 'неподалечку', 'неподалечку від', 'неподалік', 'неподалік від', 'нерідко', 'нех', 'нехай', 'нещодавно', 'нею', 'неї', 'нижче', 'низько', 'ник', 'ним', 'ними', 'них', 'нич', 'но', 'ну', 'нуг', 'нуд', 'нум', 'нумо', 'нумте', 'ньо', 'нього', 'ньому', 'ню', 'нюх', 'ня', 'няв', 'ні', 'ніби', 'ніби-то', 'нібито', 'ніде', 'ніж', 'нізащо', 'нізвідки', 'нізвідкіля', 'ній', 'ніким', 'нікого', 'нікогісінько', 'ніколи', 'нікому', 'нікотра', 'нікотре', 'нікотрий', 'нікотрим', 'нікотрими', 'нікотрих', 'нікотрого', 'нікотрому', 'нікотрою', 'нікотрої', 'нікотру', 'нікотрі', 'нікотрій', 'нікотрім', 'нікуди', 'нім', 'нінащо', 'ніскільки', 'ніт', 'ніхто', 'нічий', 'нічийна', 'нічийне', 'нічийний', 'нічийним', 'нічийними', 'нічийних', 'нічийного', 'нічийному', 'нічийною', 'нічийної', 'нічийну', 'нічийні', 'нічийній', 'нічийнім', 'нічийого', 'нічийому', 'нічим', 'нічию', 'нічия', 'нічиє', 'нічиєму', 'нічиєю', 'нічиєї', 'нічиї', 'нічиїй', 'нічиїм', 'нічиїми', 'нічиїх', 'нічого', 'нічому', 'ніщо', 'ніяк', 'ніяка', 'ніяке', 'ніякий', 'ніяким', 'ніякими', 'ніяких', 'ніякого', 'ніякому', 'ніякою', 'ніякої', 'ніяку', 'ніякі', 'ніякій', 'ніякім', 'ніякісінька', 'ніякісіньке', 'ніякісінький', 'ніякісіньким', 'ніякісінькими', 'ніякісіньких', 'ніякісінького', 'ніякісінькому', 'ніякісінькою', 'ніякісінької', 'ніякісіньку', 'ніякісінькі', 'ніякісінькій', 'ніякісінькім', 'о', 'об', 'обабіч', 'обаполи', 'обидва', 'обр', 'обік', 'обіруч', 'обіч', 'ов', 'од', 'один', 'одинадцятий', 'одинадцять', 'одна', 'однак', 'одначе', 'одне', 'одним', 'одними', 'одних', 'одно', 'одного', 'одного разу', 'одному', 'одною', 'одної', 'одну', 'одні', 'одній', 'однім', 'однією', 'однієї', 'ож', 'ой', 'окрай', 'окроме', 'округ', 'округи', 'окрім', 'окіл', 'ом', 'он', 'онде', 'онно', 'оно', 'оподаль', 'оподаль від', 'оподалік', 'оподалік від', 'опостін', 'опостінь', 'опроче', 'опріч', 'опріче', 'опісля', 'осе', 'оскільки', 'особливо', 'осторонь', 'ось', 'осісьо', 'от', 'ота', 'отак', 'отака', 'отаке', 'отакий', 'отаким', 'отакими', 'отаких', 'отакого', 'отакому', 'отакою', 'отакої', 'отаку', 'отакі', 'отакій', 'отакім', 'отакісінька', 'отакісіньке', 'отакісінький', 'отакісіньким', 'отакісінькими', 'отакісіньких', 'отакісінького', 'отакісінькому', 'отакісінькою', 'отакісінької', 'отакісіньку', 'отакісінькі', 'отакісінькій', 'отакісінькім', 'отам', 'оте', 'отже', 'отим', 'отими', 'отих', 'ото', 'отого', 'отож', 'отой', 'отому', 'отою', 'отої', 'отсе', 'оттак', 'отто', 'оту', 'отут', 'оті', 'отій', 'отім', 'отією', 'отієї', 'ох', 'оце', 'оцей', 'оцим', 'оцими', 'оцих', 'оцього', 'оцьому', 'оцю', 'оця', 'оці', 'оцій', 'оцім', 'оцією', 'оцієї', 'п', "п'я", "п'ятий", "п'ятнадцятий", "п'ятнадцять", "п'ять", 'па', 'пад', 'пак', 'пек', 'перед', 'передо', 'переді', 'перетака', 'перетаке', 'перетакий', 'перетаким', 'перетакими', 'перетаких', 'перетакого', 'перетакому', 'перетакою', 'перетакої', 'перетаку', 'перетакі', 'перетакій', 'перетакім', 'перший', 'пиж', 'плі', 'по', 'поблизу', 'побік', 'побіля', 'побіч', 'поверх', 'повз', 'повздовж', 'повинно', 'повище', 'повсюди', 'повсюдно', 'подаль від', 'подалі від', 'подекуди', 'подеяка', 'подеяке', 'подеякий', 'подеяким', 'подеякими', 'подеяких', 'подеякого', 'подеякому', 'подеякою', 'подеякої', 'подеяку', 'подеякі', 'подеякій', 'подеякім', 'подовж', 'подібно до', 'поз', 'поза', 'позад', 'позаду', 'позата', 'позате', 'позатим', 'позатими', 'позатих', 'позатого', 'позатой', 'позатому', 'позатою', 'позатої', 'позату', 'позаті', 'позатій', 'позатім', 'позатією', 'позатієї', 'позаяк', 'поздовж', 'поки', 'покрай', 'покіль', 'помежи', 'помимо', 'поміж', 'помість', 'понад', 'понадо', 'понаді', 'понижче', 'пообіч', 'поодаль від', 'поодалік від', 'поперед', 'попереду', 'поперек', 'попліч', 'попри', 'попросту', 'попід', 'пора', 'поруч', 'поряд', 'поряд з', 'порівняно з', 'посеред', 'посередині', 'потрібно', 'потім', 'поуз', 'початку', 'почерез', 'праворуч від', 'пред', 'предо', 'преді', 'прекрасно', 'прецінь', 'при', 'притому', 'причому', 'причім', 'про', 'проз', 'промеж', 'проміж', 'просто', 'проте', 'проти', 'против', 'противно', 'протягом', 'пря', 'пріч', 'пхе', 'пху', 'пі', 'пів', 'півперек', 'під', 'під знаком', 'під приводом', 'під час', 'підо', 'пізніше', 'пім', 'пір', 'після', 'р', 'ради', 'раз', 'разом з', 'разу', 'рано', 'раніш', 'раніш від', 'раніше', 'раніше від', 'раптом', 'ре', 'рет', 'риж', 'рим', 'рип', 'роб', 'року', 'років', 'рос', 'рох', 'році', 'рус', 'рух', 'руч', 'рік', 'с', 'саж', 'саз', 'сак', 'сам', 'сама', 'саме', 'сами', 'самий', 'самим', 'самими', 'самих', 'само', 'самого', 'самому', 'самою', 'самої', 'саму', 'самі', 'самій', 'самім', 'сап', 'сас', 'свого', 'свою', 'своя', 'своє', 'своєму', 'своєю', 'своєї', 'свої', 'своїй', 'своїм', 'своїми', 'своїх', 'свій', 'се', 'себе', 'себто', 'сей', 'сен', 'серед', 'середи', 'середу', 'сеч', 'си', 'сив', 'сиг', 'сиз', 'сик', 'сиріч', 'сих', 'сказав', 'сказала', 'сказати', 'скрізь', 'скільки', 'скільки-то', 'скількись', 'скільком', 'скількома', 'скількомась', 'скількомось', 'скількомсь', 'скількох', 'скількохось', 'скількохсь', 'сли', 'слідом за', 'соб', 'собою', 'собі', 'соп', 'спасибі', 'спереду', 'спочатку', 'справ', 'справді', 'став', 'стосовно', 'стільки', 'стільком', 'стількома', 'стількох', 'су', 'судячи з', 'супроти', 'супротив', 'суть', 'суч', 'суш', 'сьогодні', 'сьомий', 'сюди', 'ся', 'сяг', 'сяк', 'сяка', 'сяке', 'сякий', 'сяким', 'сякими', 'сяких', 'сякого', 'сякому', 'сякою', 'сякої', 'сяку', 'сякі', 'сякій', 'сякім', 'сям', 'сі', 'сім', 'сімнадцятий', 'сімнадцять', 'сіп', 'т', 'та', 'таж', 'так', 'така', 'таке', 'такенна', 'такенне', 'такенний', 'такенним', 'такенними', 'такенних', 'такенного', 'такенному', 'такенною', 'такенної', 'такенну', 'такенні', 'такенній', 'такеннім', 'таки', 'такий', 'таким', 'такими', 'таких', 'такого', 'також', 'такому', 'такою', 'такої', 'таку', 'такі', 'такій', 'такім', 'такісінька', 'такісіньке', 'такісінький', 'такісіньким', 'такісінькими', 'такісіньких', 'такісінького', 'такісінькому', 'такісінькою', 'такісінької', 'такісіньку', 'такісінькі', 'такісінькій', 'такісінькім', 'тал', 'там', 'тамки', 'тамта', 'тамте', 'тамтим', 'тамтими', 'тамтих', 'тамтого', 'тамтой', 'тамтому', 'тамтою', 'тамтої', 'тамту', 'тамті', 'тамтій', 'тамтім', 'тамтією', 'тамтієї', 'тар', 'тат', 'таш', 'тва', 'твого', 'твою', 'твоя', 'твоє', 'твоєму', 'твоєю', 'твоєї', 'твої', 'твоїй', 'твоїм', 'твоїми', 'твоїх', 'твій', 'те', 'тебе', 'тег', 'теж', 'тем', 'тепер', 'теперечки', 'тес', 'теф', 'теє', 'ти', 'тик', 'тил', 'тим', 'тими', 'тисяч', 'тих', 'то', 'тобою', 'тобто', 'тобі', 'того', 'тоді', 'тож', 'той', 'тол', 'тому', 'тому що', 'тот', 'тощо', 'тою', 'тої', 'тра', 'тре', 'треба', 'третій', 'три', 'тринадцятий', 'тринадцять', 'трохи', 'тс', 'тсс', 'ту', 'туди', 'тудою', 'туп', 'тут', 'тутеньки', 'тутечки', 'тутки', 'туф', 'туц', 'тю', 'тюг', 'тюп', 'тяг', 'тяж', 'тям', 'тяп', 'ті', 'тій', 'тільки', 'тім', 'тією', 'у', 'у бік', 'у вигляді', 'у випадку', 'у відповідності до', 'у відповідь на', 'у залежності від', "у зв'язку з", 'у міру', 'у напрямі до', 'у порівнянні з', 'у процесі', 'у результаті', 'у ролі', 'у силу', 'у сторону', 'у супроводі', 'у ході', 'ув', 'увесь', 'уві', 'угу', 'уже', 'узбіч', 'уздовж', 'укр', 'ум', 'унаслідок', 'униз', 'унизу', 'унт', 'уперед', 'уподовж', 'упоперек', 'упритиск до', 'упритул до', 'упродовж', 'упрост', 'ус', 'усе', 'усередині', 'услід', 'услід за', 'усупереч', 'усього', 'усьому', 'усю', 'усюди', 'уся', 'усяк', 'усяка', 'усяке', 'усякий', 'усяким', 'усякими', 'усяких', 'усякого', 'усякому', 'усякою', 'усякої', 'усяку', 'усякі', 'усякій', 'усякім', 'усі', 'усій', 'усіляка', 'усіляке', 'усілякий', 'усіляким', 'усілякими', 'усіляких', 'усілякого', 'усілякому', 'усілякою', 'усілякої', 'усіляку', 'усілякі', 'усілякій', 'усілякім', 'усім', 'усіма', 'усіх', 'усією', 'усієї', 'утім', 'ух', 'ф', "ф'ю", 'фа', 'фаг', 'фай', 'фат', 'фе', 'фед', 'фез', 'фес', 'фет', 'фзн', 'фоб', 'фот', 'фра', 'фру', 'фу', 'фук', 'фур', 'фус', 'фіш', 'х', 'ха', 'хаз', 'хай', 'хап', 'хат', 'хащ', 'хе', 'хет', 'хи', 'хиб', 'хм', 'хо', 'хов', 'хол', 'хон', 'хоп', 'хор', 'хотіти', 'хоч', 'хоча', 'хочеш', 'хро', 'хрю', 'хто', 'хтось', 'ху', 'хуз', 'хук', 'хух', 'хху', 'хіба', 'ц', 'це', 'цебто', 'цей', 'цеп', 'ци', 'цим', 'цими', 'цир', 'цих', 'цло', 'цоб', 'цок', 'цоп', 'цор', 'цс', 'цсс', 'цуг', 'цур', 'цуц', 'цього', 'цьому', 'цю', 'цюк', 'ця', 'цяв', 'цяп', 'ці', 'цід', 'цій', 'цім', 'ціною', 'цією', 'цієї', 'ч', 'чал', 'чар', 'час', 'часто', 'частіше', 'часу', 'чах', 'чей', 'чень', 'через', 'четвертий', 'чи', 'чий', 'чийого', 'чийогось', 'чийому', 'чийомусь', 'чийсь', 'чик', 'чим', 'чимось', 'чимсь', 'чир', 'численна', 'численне', 'численний', 'численним', 'численними', 'численних', 'численні', 'чию', 'чиюсь', 'чия', 'чиясь', 'чиє', 'чиєму', 'чиємусь', 'чиєсь', 'чиєю', 'чиєюсь', 'чиєї', 'чиєїсь', 'чиї', 'чиїй', 'чиїйсь', 'чиїм', 'чиїми', 'чиїмись', 'чиїмось', 'чиїмсь', 'чиїсь', 'чиїх', 'чиїхось', 'чиїхсь', 'чля', 'чого', 'чогось', 'чом', 'чому', 'чомусь', 'чон', 'чоп', 'чортзна', 'чос', 'чотири', 'чотирнадцятий', 'чотирнадцять', 'чу', 'чум', 'чур', 'чш', 'чім', 'чімось', 'чімсь', 'чіт', 'ш', 'ша', 'шаг', 'шал', 'шам', 'шво', 'шед', 'шен', 'шиз', 'шир', 'шляхом', 'шостий', 'шістнадцятий', 'шістнадцять', 'шість', 'щ', 'ще', 'щем', 'щеп', 'щип', 'щир', 'що', 'щоб', 'щоби', 'щодо', 'щойно', 'щоправда', 'щось', 'щі', 'ь', 'ю', 'юз', 'юн', 'юнь', 'юс', 'ют', 'юхт', 'я', 'яв', 'яд', 'яз', 'язь', 'як', 'яка', 'якась', 'якби', 'яке', 'якесь', 'який', 'якийсь', 'яким', 'якими', 'якимись', 'якимось', 'якимсь', 'яких', 'якихось', 'якихсь', 'якого', 'якогось', 'якому', 'якомусь', 'якось', 'якою', 'якоюсь', 'якої', 'якоїсь', 'якраз', 'яку', 'якусь', 'якщо', 'які', 'якій', 'якійсь', 'якім', 'якімсь', 'якісь', 'ял', 'ям', 'ян', 'янь', 'яо', 'яп', 'ярл', 'ясь', 'ять', 'є', 'єр', 'єси', 'і', 'ібн', 'ід', 'із', 'із-за', 'із-під', 'іззаду', 'ізм', 'ізсередини', 'ік', 'ікс', 'ікт', "ім'я", 'імовірно', 'інакша', 'інакше', 'інакший', 'інакшим', 'інакшими', 'інакших', 'інакшого', 'інакшому', 'інакшою', 'інакшої', 'інакшу', 'інакші', 'інакшій', 'інакшім', 'інколи', 'іноді', 'інша', 'інше', 'інший', 'іншим', 'іншими', 'інших', 'іншого', 'іншому', 'іншою', 'іншої', 'іншу', 'інші', 'іншій', 'іншім', 'інь', 'іч', 'іще', 'ї', 'їдь', 'їй', 'їм', 'їх', 'їхнього', 'їхньому', 'їхньою', 'їхньої', 'їхню', 'їхня', 'їхнє', 'їхні', 'їхній', 'їхнім', 'їхніми', 'їхніх', 'її', 'ґ']

# %%
def initializeRec(recText):
    if isinstance(recText, str):
        return recText.strip()
    else:
        return False

def skipLine(line, idx):
    if len(line.strip()) == 0:
        return False
    
    # throw hashtag line
    if line.strip()[0] == '#':
        return True
    
    # throw attribution line
    for attr in ['из личного','личный блог','источник:','авторский блог']:
        if attr in line.lower():
            return True
        
    # dots at the beginning
    matches = re.search("[\*\+\^-_][*+^-_= ]+", line.strip()) 
    if matches:
        return True
    
    # is none of it alphanumeric
    containsAlpha = False
    for char in line:
        if char.isalpha():
            containsAlpha = True
            break
    if not containsAlpha:
        return True
    
    return False


def processRec(rec):
    recText = initializeRec(rec['Text'])
    cleanLines = []
    if recText:
        # decide which lines to keep
        lines = recText.split('\n')
        for i, line in enumerate(lines):
            if skipLine(line, i):
                continue
            cleanLines.append(line)
    return '\n'.join(cleanLines)

# %%
# https://pypi.org/project/translate-api/
# !pip3 install translators --upgrade
import translators as ts
# Out:
# Using United States server backend.

# %% [markdown]
# ### Parse records into docs

# %%
# pip install openpyxl

# %%
df = pd.read_excel('../Excel_files/Full_Poem_Dataset_12-17.xlsx')
records = df.to_dict('records')

# %%
doc = nlp(random.choice(records)['Text'][:100])
for token in doc:
    print(token.text, token.lemma_)
# Out:
# Аватарки аватарки
# моих мой
# друзей друг
# и и
# любимых любимый
# становятся становиться
# чёрными чёрный
# кругами круг
#
#
#
#
#
# словно словно
# невидимый невидимый
# биатлонист биатлонист
# выбивает выбивать
# их их

# %%
from tqdm import tqdm

# %%
# %%time
for rec in tqdm(records):
    # if i % 250 == 0:
    #     print(f'{i}/{len(records)} parsed')
    cleanedText = processRec(rec)
    rec['cleanedText'] = cleanedText
    rec['doc'] = nlp(cleanedText)
# Out:
# 100%|███████████████████████████████████████| 3289/3289 [03:57<00:00, 13.83it/s]
# CPU times: user 3min 34s, sys: 8.08 s, total: 3min 42s
# Wall time: 3min 57s

# %%
# wrote pickle
import pickle

with open('recsWithSpacyDocs1-9.pickle', 'wb') as handle:
    pickle.dump(records, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# !pip3 install pickle5
# import pickle5 as pickle

# %% [markdown]
# ### Load Pickle with Docs

# %%
# read pickle
import pickle

with open('recs3502WithSpacyDocs10-23.pickle', 'rb') as handle:
    records = pickle.load(handle)

# %%
records[0]
# Out:
# {'Unnamed: 0': 0,
#  'Text': 'НА «–ОЙ»\nНемой город, или просто уже не мой.\nВяжущей глаз окантовкой по центровой:\nБарьеры, ограды, решетки. Иду домой.\nМолча. И город безмолвствует. Как понятой.\nРодной город или антигерой,\nВырастающий тенью (за прямой спиной\nМоей, в четвертом поклонении коренной),\nСтиснутой колумбарными плитами прифронтовой Тверской.\nСловоохотливый город, охотящийся за словами, твердой рукой,\nИзмолчалил допросами, штрафами, гайками, сроками. И не спит конвой.\nСмотрят в рот, не давая его раскрыть, лишь разинуть (для пайки, питья, смеха, и «пой, песню, пой»),\nПресекая воздушно-капельную рот в рот заразу словоизвержения за свержение — у пикета\nвключенной трубой выхлопной.\nВразнобой город, проигравший бой\nМолоткам курантов, бьющих стране «отбой»,\nТолько у колокола не прикушен язык бедой,\nОтливающей (едино)кровным по стене крепостной, глухой.\nМощёный город, схоронивший свой голос под мостовой.\nЗаспанный — заживо в насыпи — растет нерасчлененный доход валовой.\nЛик обезличен. Лица — по заграницам. Спешит закрыться контрольно-(не)пропускной.\nНа границе столицы инквизиция долго не наглядится на страницы в паспорте и в очереди на\nвозвращение из заморских теплиц к гробницам — хоть волком вой.\nТяжелый город, наседающий головной\nБолью от запаха, невымываемого поганой метлой,\nТолкают зачатые за здравие и конченые за упокой,\nВстречают такси цвета запаха, дорог перегной, и черный по белому шрифт повестки. В лучшем\nслучае, новостной.',
#  'Author': 'Эмилия Деменцова',
#  'Before or after': 'After',
#  'Source': 'ROAR V2',
#  'Date posted': 'None',
#  'UniqueIndex': 0,
#  'cleanedText': 'НА «–ОЙ»\nНемой город, или просто уже не мой.\nВяжущей глаз окантовкой по центровой:\nБарьеры, ограды, решетки. Иду домой.\nМолча. И город безмолвствует. Как понятой.\nРодной город или антигерой,\nВырастающий тенью (за прямой спиной\nМоей, в четвертом поклонении коренной),\nСтиснутой колумбарными плитами прифронтовой Тверской.\nСловоохотливый город, охотящийся за словами, твердой рукой,\nИзмолчалил допросами, штрафами, гайками, сроками. И не спит конвой.\nСмотрят в рот, не давая его раскрыть, лишь разинуть (для пайки, питья, смеха, и «пой, песню, пой»),\nПресекая воздушно-капельную рот в рот заразу словоизвержения за свержение — у пикета\nвключенной трубой выхлопной.\nВразнобой город, проигравший бой\nМолоткам курантов, бьющих стране «отбой»,\nТолько у колокола не прикушен язык бедой,\nОтливающей (едино)кровным по стене крепостной, глухой.\nМощёный город, схоронивший свой голос под мостовой.\nЗаспанный — заживо в насыпи — растет нерасчлененный доход валовой.\nЛик обезличен. Лица — по заграницам. Спешит закрыться контрольно-(не)пропускной.\nНа границе столицы инквизиция долго не наглядится на страницы в паспорте и в очереди на\nвозвращение из заморских теплиц к гробницам — хоть волком вой.\nТяжелый город, наседающий головной\nБолью от запаха, невымываемого поганой метлой,\nТолкают зачатые за здравие и конченые за упокой,\nВстречают такси цвета запаха, дорог перегной, и черный по белому шрифт повестки. В лучшем\nслучае, новостной.',
#  'doc': НА «–ОЙ»
#  Немой город, или просто уже не мой.
#  Вяжущей глаз окантовкой по центровой:
#  Барьеры, ограды, решетки. Иду домой.
#  Молча. И город безмолвствует. Как понятой.
#  Родной город или антигерой,
#  Вырастающий тенью (за прямой спиной
#  Моей, в четвертом поклонении коренной),
#  Стиснутой колумбарными плитами прифронтовой Тверской.
#  Словоохотливый город, охотящийся за словами, твердой рукой,
#  Измолчалил допросами, штрафами, гайками, сроками. И не спит конвой.
#  Смотрят в рот, не давая его раскрыть, лишь разинуть (для пайки, питья, смеха, и «пой, песню, пой»),
#  Пресекая воздушно-капельную рот в рот заразу словоизвержения за свержение — у пикета
#  включенной трубой выхлопной.
#  Вразнобой город, проигравший бой
#  Молоткам курантов, бьющих стране «отбой»,
#  Только у колокола не прикушен язык бедой,
#  Отливающей (едино)кровным по стене крепостной, глухой.
#  Мощёный город, схоронивший свой голос под мостовой.
#  Заспанный — заживо в насыпи — растет нерасчлененный доход валовой.
#  Лик обезличен. Лица — по заграницам. Спешит закрыться контрольно-(не)пропускной.
#  На границе столицы инквизиция долго не наглядится на страницы в паспорте и в очереди на
#  возвращение из заморских теплиц к гробницам — хоть волком вой.
#  Тяжелый город, наседающий головной
#  Болью от запаха, невымываемого поганой метлой,
#  Толкают зачатые за здравие и конченые за упокой,
#  Встречают такси цвета запаха, дорог перегной, и черный по белому шрифт повестки. В лучшем
#  случае, новостной.}

# %% [markdown]
# ### Over individual lemmas

# %%
# %%time
infodict = dict()
infodict['Russian'] = dict()

wordlsts = dict()
poemct = dict()
wordct = dict()
lemmas = dict()
lemmas['Russian'] = set()

for lang in infodict:
    poemct[lang] = dict()
    wordct[lang] = dict()
    for period in ['Before','After']:
        poemct[lang][period]=0
        wordct[lang][period] = 0
        infodict[lang][period] = dict()

random.shuffle(records)
for rec in tqdm(records):
    lang = 'Russian'
    period = rec['Before or after']
    if pd.isna(period):
        period = 'After'
    poemct[lang][period] += 1
    doc = rec['doc']
    lemmaAdded = []
    
    if wordct[lang][period] >= 260000:
        continue
    
    for token in doc:
        wordct[lang][period] += 1

        if token.text.isalpha() and token.text not in rustops and token.text not in ukstops:
            lemma = token.lemma_.lower()
            
            lemmas[lang].add(lemma)
            for p in ['Before', 'After']:
                if lemma not in infodict[lang][p]:
                    infodict[lang][p][lemma] = dict()
                    infodict[lang][p][lemma]['count'] = 0
                    infodict[lang][p][lemma]['examples'] = []
            if lemma in lemmaAdded:
                continue
            else:
                infodict[lang][period][lemma]['count'] += 1
                infodict[lang][period][lemma]['examples'].append({
                    'lineText' : doc.text,
                    'rec' : rec
                })
                lemmaAdded.append(lemma)
# Out:
# 100%|██████████████████████████████████████| 3289/3289 [00:27<00:00, 120.16it/s]

# %% [markdown]
# ### now adding translated labels

# %%
# %%time
freqdatalist = []
allxvals = set()
allyvals = set()
yvals4SD = []
lang = 'Russian'

validlemmas = []
for lemma in lemmas[lang]:
    s_1 = infodict[lang]['Before'][lemma]['count']
    s_2 = infodict[lang]['After'][lemma]['count']

    if s_1 != 0 and s_2 != 0 and s_1 + s_2 >= 10:
        validlemmas.append(lemma)

for lemma in tqdm(validlemmas):
        
    s_1 = infodict[lang]['Before'][lemma]['count']
    s_2 = infodict[lang]['After'][lemma]['count']

    if s_1*s_2!= 0 and s_1 + s_2 >= 0:

        sx_ylog = ((math.log(s_1,2)+math.log(s_2,2))/2, math.log(s_2,2) - math.log(s_1,2))
        # sx_yreg = ((s_1+s_2)/2, s_2 - s_1)

        sx_y = sx_ylog
        try:
            translatedLabel = ts.google(lemma, from_language='ru', to_language='en')
        except:
            try:
                time.sleep(3)
                translatedLabel = ts.google(lemma, from_language='ru', to_language='en')
            except:
                print('problem translating',lemma)
                translatedLabel = lemma
        
        freqdatalist.append({
            'label' : lemma,
            'translatedLabel' : translatedLabel,
            'lemma' : lemma,
            's_x' : sx_y[0],
            's_y' : sx_y[1],
            'before' : s_1,
            'after' : s_2,
        })

        allxvals.add(sx_y[0])
        allyvals.add(sx_y[1])
        yvals4SD.append(sx_y[1])
# Out:
#   0%|▏                                      | 15/3491 [00:28<2:06:06,  2.18s/it]
# problem translating девка
#   0%|▏                                      | 16/3491 [00:29<1:48:52,  1.88s/it]
# problem translating возможный
#   0%|▏                                      | 17/3491 [00:32<2:12:55,  2.30s/it]
# problem translating продать
#   1%|▏                                      | 18/3491 [00:35<2:17:16,  2.37s/it]

# %% [markdown]
# #### Shake up the data

# %%
# shake up the data
for f in freqdatalist:
    f['s_x'] = f['s_x'] + [-1,1][random.randrange(2)]*random.random()/2
    f['s_y'] = f['s_y'] + [-1,1][random.randrange(2)]*random.random()/2

# %%
pwd
# Out:
# '/Users/paigelee/Desktop/fall2022/thesis/thesis-code/meandiff'

# %%
with open(f'shakenLogData10-16.json', 'w', encoding='utf-8') as f:
    json.dump(freqdatalist, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Over SynSets

# %% [markdown]
# #### Download RUWordNet

# %%
# pip install ruwordnet

# %%
# !ruwordnet download
# Out:
# downloading a ruwordnet model from https://github.com/avidale/python-ruwordnet/releases/download/0.0.4/ruwordnet-2021.db

# %%
from ruwordnet import RuWordNet
wn = RuWordNet()

# %%
# test out synsets
for sense in wn.get_senses('небо'):
    print(sense.synset)
print()
for sense in wn.get_senses('небеса'):
    print(sense.synset)
# hypernyms
wn.get_senses('тело')[0].synset.hypernyms
# and hyponyms
for hyps in wn.get_senses('тело')[0].synset.hypernyms:
    for hypo in hyps.hyponyms:
        print(hypo)
# Out:
# Synset(id="111119-N", title="НЕБО ВО РТУ")
# Synset(id="112832-N", title="НЕБО, НЕБЕСНЫЙ СВОД")
#
# Synset(id="112832-N", title="НЕБО, НЕБЕСНЫЙ СВОД")
# Synset(id="107716-N", title="СТОПА НОГИ")
# Synset(id="112433-N", title="ПРОМЕЖНОСТЬ")
# Synset(id="108125-N", title="ШЕЯ (ЧАСТЬ ТЕЛА)")
# Synset(id="113348-N", title="ЩУПАЛЬЦЕ")
# Synset(id="107718-N", title="ГОЛЕНЬ")
# Synset(id="112889-N", title="ЖИВОТ (ЧАСТЬ ТЕЛА)")
# Synset(id="107724-N", title="БЕДРО НОГИ")
# Synset(id="113650-N", title="КРЕСТЕЦ")
# Synset(id="109289-N", title="СПИНА (ЧАСТЬ ТУЛОВИЩА)")
# Synset(id="107732-N", title="ГОЛОВА (ЧАСТЬ ТЕЛА)")
# Synset(id="109613-N", title="ВЕКО")
# Synset(id="112885-N", title="ХВОСТ ЖИВОТНОГО")
# Synset(id="107068-N", title="ТУЛОВИЩЕ")
# Synset(id="118107-N", title="КОНЕЧНОСТЬ (ОРГАН ДВИЖЕНИЯ)")

# %% [markdown]
# #### Run calc

# %%
# %%time
infodict = dict()
infodict['Russian'] = dict()

wordlsts = dict()
poemct = dict()
wordct = dict()
synsets = set()
synsetTokens = dict()

for lang in infodict:
    poemct[lang] = dict()
    wordct[lang] = dict()
    for period in ['Before','After']:
        poemct[lang][period]=0
        wordct[lang][period] = 0
        infodict[lang][period] = dict()

random.shuffle(records)

for recidx, rec in enumerate(records):
    if recidx % 500 == 0:
        print(f'{recidx}/{len(records)} done.')
    lang = 'Russian'
    period = rec['Before or after']
    poemct[lang][period] += 1
    doc = rec['doc']
    synsetAdded = []
    
    if wordct[lang][period] >= 100000:
        continue
    
    # for sent in doc.sentences:
    #     for token in sent.words:
    for token in doc:
        wordct[lang][period] += 1

        if token.text.isalpha() and token.text not in rustops and token.text not in ukstops:
            lemma = token.lemma_.lower()
            for sense in wn.get_senses(lemma):

                lemmaSynset = sense.synset
                synsets.add(lemmaSynset)
                synsetTokens.setdefault(lemmaSynset, dict())
                synsetTokens[lemmaSynset].setdefault(lemma, 0)
                synsetTokens[lemmaSynset][lemma]+=1

                for p in ['Before', 'After']:
                    if lemmaSynset not in infodict[lang][p]:
                        infodict[lang][p][lemmaSynset] = dict()
                        infodict[lang][p][lemmaSynset]['count'] = 0
                        infodict[lang][p][lemmaSynset]['examples'] = []
                if lemmaSynset in synsetAdded:
                    continue
                else:
                    infodict[lang][period][lemmaSynset]['count'] += 1
                    infodict[lang][period][lemmaSynset]['examples'].append({
                        'lemma' : lemma,
                        'token' : token.text,
                        'lineText' : sent.text,
                        'rec' : rec
                    })
                    synsetAdded.append(lemmaSynset)
        
freqdatalist = []
allxvals = set()
allyvals = set()
yvals4SD = []
lang = 'Russian'

validsynsets = []
for synset in synsets:
    s_1 = infodict[lang]['Before'][synset]['count']
    s_2 = infodict[lang]['After'][synset]['count']

    if s_1 != 0 and s_2 != 0 and s_1 + s_2 >= 10:
        validsynsets.append(synset)

titleAddedAlready = set()
lemma2synset = dict()
for s, synset in enumerate(validsynsets):
    if s % 250 == 0:
        print(f'{s}/{len(validsynsets)} synsets parsed.')
        
    # check if title already added
    title = synset.title
    # change synset label to lemma label if only one lemma mentioned
    if len(synsetTokens[synset]) == 1:
        title = list(synsetTokens[synset].keys())[0]
        
    # if title already added, skip entry, else continue
    if title in titleAddedAlready:
        print('OLD:',title, synset.title)
        print('NEW:',title, lemma2synset[title])
        continue
    else:
        lemma2synset[title] = synset.title
        titleAddedAlready.add(title)
    
    s_1 = infodict[lang]['Before'][synset]['count']
    s_2 = infodict[lang]['After'][synset]['count']
    
    sx_ylog = ((math.log(s_1,2)+math.log(s_2,2))/2, math.log(s_2,2) - math.log(s_1,2))
    # sx_yreg = ((s_1+s_2)/2, s_2 - s_1)
    sx_y = sx_ylog

    try:
        translatedLabel = ts.google(title, from_language='ru', to_language='en')
    except:
        try:
            time.sleep(3)
            translatedLabel = ts.google(title, from_language='ru', to_language='en')
        except:
            print('problem translating',title)
            translatedLabel = title

    freqdatalist.append({
        'label' : title,
        'translatedLabel' : translatedLabel,
        'synsetTitle' : title,
        'synsetID' : synset.id,
        'synsetTokens' : synsetTokens[synset],
        's_x' : sx_y[0],
        's_y' : sx_y[1],
        'before' : s_1,
        'after' : s_2,
    })

    allxvals.add(sx_y[0])
    allyvals.add(sx_y[1])
    yvals4SD.append(sx_y[1])
# Out:
# 0/3141 done.
# 500/3141 done.
# 1000/3141 done.
# 1500/3141 done.
# 2000/3141 done.
# 2500/3141 done.
# 3000/3141 done.
# 0/2866 synsets parsed.
# OLD: соль СОЛЬ (ХИМИЧЕСКОЕ СОЕДИНЕНИЕ)
# NEW: соль ПИЩЕВАЯ СОЛЬ
# OLD: слабый СЛАБЫЙ ПО КАЧЕСТВУ
# NEW: слабый СЛАБЫЙ ПО СИЛЕ, МОЩНОСТИ
# OLD: слабый СЛАБЫЙ, НЕТУГОЙ
# NEW: слабый СЛАБЫЙ ПО СИЛЕ, МОЩНОСТИ
# OLD: пух РАСТИТЕЛЬНЫЙ ПУХ
# NEW: пух ПУХ ПТИЦЫ
# OLD: пух ПУШОК НА ТЕЛЕ
# NEW: пух ПУХ ПТИЦЫ
# OLD: танец ТАНЕЦ
# NEW: танец ХОРЕОГРАФИЧЕСКОЕ ИСКУССТВО
# OLD: нежность НЕЖНИЧАТЬ, ГОВОРИТЬ НЕЖНОСТИ
# NEW: нежность ЛАСКОВЫЙ
# OLD: секунда СЕКУНДА (МУЗЫКАЛЬНЫЙ ИНТЕРВАЛ)
# NEW: секунда УГЛОВАЯ СЕКУНДА
# OLD: замок СРЕДНЕВЕКОВЫЙ ЗАМОК
# NEW: замок ЗАМОК ДЛЯ ЗАПИРАНИЯ
# OLD: пустота ОПУСТОШЕННОСТЬ
# NEW: пустота ПУСТОЕ ПРОСТРАНСТВО
# OLD: номер НОМЕР (ЧАСТЬ ПРЕДСТАВЛЕНИЯ)
# NEW: номер НОМЕР (ОТДЕЛЬНОЕ ПОМЕЩЕНИЕ)
# OLD: пустота БЕССОДЕРЖАТЕЛЬНЫЙ
# NEW: пустота ПУСТОЕ ПРОСТРАНСТВО
# OLD: мир СООБЩЕСТВО (СОВОКУПНОСТЬ ЛЮДЕЙ)
# NEW: мир МИР, ОТСУТСТВИЕ ВОЙНЫ
# OLD: пустота ПУСТОГОЛОВЫЙ
# NEW: пустота ПУСТОЕ ПРОСТРАНСТВО
# OLD: форма ФОРМА, НАРУЖНЫЙ ВИД
# NEW: форма ФОРМА ДЛЯ ИЗГОТОВЛЕНИЯ
# OLD: звезда ЗВЕЗДНОСТЬ ГОСТИНИЦЫ
# NEW: звезда ЗВЕЗДА (ФИГУРА)
# OLD: номер НОМЕР ПО ПОРЯДКУ
# NEW: номер НОМЕР (ОТДЕЛЬНОЕ ПОМЕЩЕНИЕ)
# OLD: звезда ЗВЕЗДА (НЕБЕСНОЕ ТЕЛО)
# NEW: звезда ЗВЕЗДА (ФИГУРА)
# OLD: пустота ПУСТОЙ, НЕЗАПОЛНЕННЫЙ
# NEW: пустота ПУСТОЕ ПРОСТРАНСТВО
# OLD: мягкий МЯГКИЙ, НЕСТРОГИЙ
# NEW: мягкий МЯГКИЙ ПО ХАРАКТЕРУ
# OLD: рождение РОДИТЬ (ДАТЬ НАЧАЛО)
# NEW: рождение РОЖДЕНИЕ РЕБЕНКА
# OLD: рождение РОДИТЬСЯ НА СВЕТ
# NEW: рождение РОЖДЕНИЕ РЕБЕНКА
# OLD: запах ЗАПАХ
# NEW: запах ЗАПАХНУТЬ ПОЛЫ
# OLD: мягкий МЯГКИЙ, НЕЧЕРСТВЫЙ
# NEW: мягкий МЯГКИЙ ПО ХАРАКТЕРУ
# OLD: мягкий МЯГКИЙ, НЕРЕЗКИЙ
# NEW: мягкий МЯГКИЙ ПО ХАРАКТЕРУ
# OLD: мягкий МЯГКИЙ ПРИ НАДАВЛИВАНИИ
# NEW: мягкий МЯГКИЙ ПО ХАРАКТЕРУ
# OLD: открытый ОТКРЫТЫЙ (ИСКРЕННИЙ, ОТКРОВЕННЫЙ)
# NEW: открытый ОТКРЫТЫЙ ДЛЯ ЖЕЛАЮЩИХ
# OLD: звезда ЗВЕЗДА (ЗНАМЕНИТОСТЬ)
# NEW: звезда ЗВЕЗДА (ФИГУРА)
# OLD: пустота ПУСТОТА В ПОРОДЕ, В МАТЕРИАЛЕ
# NEW: пустота ПУСТОЕ ПРОСТРАНСТВО
# OLD: ядерный ЯДЕРНАЯ РЕАКЦИЯ
# NEW: ядерный ЯДЕРНОЕ ОРУЖИЕ
# OLD: засыпать ЗАСЫПАТЬ (НАПРАВИТЬ В ИЗОБИЛИИ)
# NEW: засыпать ЗАСЫПАТЬ ДОВЕРХУ
# OLD: ядерный ЯДРО (СЕРДЦЕВИНА)
# NEW: ядерный ЯДЕРНОЕ ОРУЖИЕ
# OLD: земля ПЛАНЕТА ЗЕМЛЯ
# NEW: земля ЗЕМЕЛЬНЫЕ РЕСУРСЫ
# OLD: открытый ОТКРЫТЫЙ, С БОЛЬШИМ ВЫРЕЗОМ
# NEW: открытый ОТКРЫТЫЙ ДЛЯ ЖЕЛАЮЩИХ
# OLD: палец ПАЛЕЦ ПЕРЧАТКИ
# NEW: палец ПАЛЕЦ МЕХАНИЗМА
# 250/2866 synsets parsed.
# OLD: ядерный АТОМНОЕ ОБОРУДОВАНИЕ
# NEW: ядерный ЯДЕРНОЕ ОРУЖИЕ
# OLD: смешной СМЕШНОЙ (ВЫЗЫВАЮЩИЙ СМЕХ)
# NEW: смешной СМЕШНОЙ, СМЕХОТВОРНЫЙ
# OLD: золотой ЗОЛОТОЙ (ОЧЕНЬ ХОРОШИЙ)
# NEW: золотой ЗОЛОТО
# OLD: сладкий СЛАДКИЙ (ПРИЯТНЫЙ)
# NEW: сладкий СЛАДКИЙ ВКУС
# OLD: рождение ЗАРОДИТЬСЯ
# NEW: рождение РОЖДЕНИЕ РЕБЕНКА
# OLD: рождение РАЗМНОЖИТЬСЯ, РАСПЛОДИТЬСЯ
# NEW: рождение РОЖДЕНИЕ РЕБЕНКА
# OLD: кожа КОЖА (МАТЕРИАЛ)
# NEW: кожа КОЖА (НАРУЖНЫЙ ПОКРОВ)
# OLD: облако ОБЛАКО ЧАСТИЦ
# NEW: облако ОБЛАКО В АТМОСФЕРЕ
# OLD: кровавый КРОВАВЫЙ ЦВЕТ
# NEW: кровавый КРОВОПРОЛИТИЕ (МАССОВОЕ УБИЙСТВО)
# OLD: бег СПОРТИВНЫЙ БЕГ
# NEW: бег БЕЖАТЬ (ДВИГАТЬСЯ НА НОГАХ)
# OLD: чай ЧАЙ (ПИЩЕВОЙ ПРОДУКТ)
# NEW: чай ЧАЙ (НАПИТОК)
# OLD: старый ОПЫТНЫЙ, ОБЛАДАЮЩИЙ ОПЫТОМ
# NEW: старый СТАРЫЙ (НЕГОДНЫЙ)
# OLD: чай ЧАЙ (РАСТЕНИЕ)
# NEW: чай ЧАЙ (НАПИТОК)
# OLD: лишний ЛИШНИЙ (ДОБАВОЧНЫЙ, ДОПОЛНИТЕЛЬНЫЙ)
# NEW: лишний ЛИШНИЙ (НЕНУЖНЫЙ, БЕСПОЛЕЗНЫЙ)
# OLD: школа ШКОЛА
# NEW: школа ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА
# OLD: лишний ИЗБЫТОЧНЫЙ, ИЗЛИШНИЙ
# NEW: лишний ЛИШНИЙ (НЕНУЖНЫЙ, БЕСПОЛЕЗНЫЙ)
# OLD: вид ВИД ГЛАГОЛА
# NEW: вид БИОЛОГИЧЕСКИЙ ВИД
# OLD: имя ИМЯ ЧЕЛОВЕКА
# NEW: имя ЛИЧНОЕ ИМЯ
# OLD: имя ИЗВЕСТНЫЙ ЧЕЛОВЕК
# NEW: имя ЛИЧНОЕ ИМЯ
# OLD: вид ВИД ОКРУЖАЮЩЕЙ МЕСТНОСТИ
# NEW: вид БИОЛОГИЧЕСКИЙ ВИД
# OLD: ручка РУЧКА ДЛЯ ДЕРЖАНИЯ
# NEW: ручка РУЧКА ДЛЯ ПИСЬМА
# OLD: ручка РУКОЯТКА УПРАВЛЕНИЯ
# NEW: ручка РУЧКА ДЛЯ ПИСЬМА
# OLD: телефон ТЕЛЕФОННЫЙ АППАРАТ
# NEW: телефон ТЕЛЕФОННАЯ СВЯЗЬ
# OLD: телефон ТЕЛЕФОННЫЙ НОМЕР
# NEW: телефон ТЕЛЕФОННАЯ СВЯЗЬ
# OLD: прямой НЕПОСРЕДСТВЕННЫЙ, НЕПОСРЕДСТВЕННО СЛЕДУЮЩИЙ
# NEW: прямой ПРЯМОЙ, БЕЗ ИЗГИБОВ
# OLD: очередь ОЧЕРЕДЬ СТРОИТЕЛЬСТВА
# NEW: очередь ОЧЕРЕДЬ, МЕСТО В ОЧЕРЕДИ
# OLD: улица УЛИЦА, ОТКРЫТЫЙ ВОЗДУХ
# NEW: улица УЛИЦА В НАСЕЛЕННОМ ПУНКТЕ
# OLD: очередь АВТОМАТНЫЙ ОГОНЬ
# NEW: очередь ОЧЕРЕДЬ, МЕСТО В ОЧЕРЕДИ
# OLD: часть СОСТАВНАЯ ЧАСТЬ
# NEW: часть ВОИНСКАЯ ЧАСТЬ
# OLD: очередь ОЧЕРЕДЬ, ОЧЕРЕДНОСТЬ
# NEW: очередь ОЧЕРЕДЬ, МЕСТО В ОЧЕРЕДИ
# OLD: очередь ЖИВАЯ ОЧЕРЕДЬ
# NEW: очередь ОЧЕРЕДЬ, МЕСТО В ОЧЕРЕДИ
# OLD: корона МОНАРХИЯ (ГОСУДАРСТВО)
# NEW: корона КОРОНА НЕБЕСНОГО СВЕТИЛА
# OLD: улица УЛИЧНАЯ СРЕДА
# NEW: улица УЛИЦА В НАСЕЛЕННОМ ПУНКТЕ
# OLD: светлый СВЕТЛЫЙ ПО ЦВЕТУ
# NEW: светлый СВЕТЛЫЙ (РАДОСТНЫЙ, ПРИЯТНЫЙ)
# OLD: светлый СВЕТЛЫЙ, ХОРОШО ОСВЕЩЕННЫЙ
# NEW: светлый СВЕТЛЫЙ (РАДОСТНЫЙ, ПРИЯТНЫЙ)
# OLD: ХРУПКИЙ (СЛИШКОМ СЛАБЫЙ, НЕЖНЫЙ) ХРУПКИЙ (СЛИШКОМ СЛАБЫЙ, НЕЖНЫЙ)
# NEW: ХРУПКИЙ (СЛИШКОМ СЛАБЫЙ, НЕЖНЫЙ) ХРУПКИЙ (СЛИШКОМ СЛАБЫЙ, НЕЖНЫЙ)
# OLD: следовать СЛЕДОВАТЬ ПО ВРЕМЕНИ
# NEW: следовать СЛЕДОВАТЬ, РУКОВОДСТВОВАТЬСЯ
# OLD: встреча ВСТРЕТИТЬ НАСТУПЛЕНИЕ СОБЫТИЯ
# NEW: встреча ВСТРЕТИТЬ, УСТРОИТЬ ВСТРЕЧУ
# OLD: следовать СЛЕДОВАТЬ, ЯВЛЯТЬСЯ СЛЕДСТВИЕМ
# NEW: следовать СЛЕДОВАТЬ, РУКОВОДСТВОВАТЬСЯ
# 500/2866 synsets parsed.
# OLD: речь РЕЧЬ, РЕЧЕВОЕ ОБЩЕНИЕ
# NEW: речь РЕЧЬ, ДАР РЕЧИ
# OLD: следовать СЛЕДОВАТЬ, ДВИГАТЬСЯ СЛЕДОМ
# NEW: следовать СЛЕДОВАТЬ, РУКОВОДСТВОВАТЬСЯ
# OLD: свежий СВЕЖИЙ, НЕ УСТАВШИЙ
# NEW: свежий СВЕЖИЙ (НЕДАВНО ДОБЫТЫЙ ИЛИ ПРИГОТОВЛЕННЫЙ)
# OLD: свежий СВЕЖИЙ (НОВЫЙ)
# NEW: свежий СВЕЖИЙ (НЕДАВНО ДОБЫТЫЙ ИЛИ ПРИГОТОВЛЕННЫЙ)
# OLD: встреча ВСТРЕЧА (СОБРАНИЕ)
# NEW: встреча ВСТРЕТИТЬ, УСТРОИТЬ ВСТРЕЧУ
# OLD: свежий СВЕЖИЙ (ЧИСТЫЙ)
# NEW: свежий СВЕЖИЙ (НЕДАВНО ДОБЫТЫЙ ИЛИ ПРИГОТОВЛЕННЫЙ)
# OLD: речь РЕЧЬ (ТО, ЧТО ГОВОРЯТ)
# NEW: речь РЕЧЬ, ДАР РЕЧИ
# OLD: заяц ЗАЙЧАТИНА
# NEW: заяц БЕЗБИЛЕТНИК
# OLD: глубина ГЛУБОКИЙ (СИЛЬНЫЙ)
# NEW: глубина ГЛУБИНА, ОСНОВАТЕЛЬНОСТЬ
# OLD: глубина ГЛУБИНА, ГЛУБОКОЕ МЕСТО
# NEW: глубина ГЛУБИНА, ОСНОВАТЕЛЬНОСТЬ
# OLD: победа ПОБЕДА В ВОЙНЕ
# NEW: победа ПОБЕДА В СОРЕВНОВАНИИ
# OLD: срок СРОК, ОПРЕДЕЛЕННЫЙ ПРОМЕЖУТОК ВРЕМЕНИ
# NEW: срок СРОК (МОМЕНТ ВРЕМЕНИ)
# OLD: встреча ВСТРЕТИТЬ, УВИДЕТЬСЯ
# NEW: встреча ВСТРЕТИТЬ, УСТРОИТЬ ВСТРЕЧУ
# OLD: глубина ГЛУБИНА (ПРОСТРАНСТВО)
# NEW: глубина ГЛУБИНА, ОСНОВАТЕЛЬНОСТЬ
# OLD: близкий БЛИЗКИЙ ПО ВРЕМЕНИ
# NEW: близкий БЛИЗОСТЬ (СХОДСТВО)
# OLD: полный ПОЛНЫЙ (ЗАНЯТЫЙ ЦЕЛИКОМ)
# NEW: полный ПОЛНЫЙ (ВПОЛНЕ ЗАКОНЧЕННЫЙ)
# OLD: глубина ГЛУБИНА (РАССТОЯНИЕ)
# NEW: глубина ГЛУБИНА, ОСНОВАТЕЛЬНОСТЬ
# OLD: победа ПОБЕДА (УСПЕХ)
# NEW: победа ПОБЕДА В СОРЕВНОВАНИИ
# OLD: воронка ВОРОНКА ДЛЯ ПЕРЕЛИВАНИЯ
# NEW: воронка ВОРОНКА ОТ ВЗРЫВА
# OLD: власть ОРГАН ВЛАСТИ
# NEW: власть ПУБЛИЧНАЯ ВЛАСТЬ
# OLD: площадь ПЛОЩАДЬ В ГОРОДЕ, СЕЛЕ
# NEW: площадь ПЛОЩАДЬ (ПАРАМЕТР)
# OLD: почта ЭЛЕКТРОННАЯ ПОЧТА
# NEW: почта ПОЧТОВОЕ ОТПРАВЛЕНИЕ
# OLD: детский НЕСОВЕРШЕННОЛЕТНИЕ ДЕТИ
# NEW: детский ДЕТСКИЙ, КАК У РЕБЕНКА
# OLD: следовать СЛЕДОВАТЬ (ПРИМЫКАТЬ)
# NEW: следовать СЛЕДОВАТЬ, РУКОВОДСТВОВАТЬСЯ
# OLD: знак ЗНАК РУКОЙ
# NEW: знак ЗНАК, ОБОЗНАЧЕНИЕ
# OLD: корабль ПИЛОТИРУЕМЫЙ ЛЕТАТЕЛЬНЫЙ АППАРАТ
# NEW: корабль БОЛЬШОЙ КОРАБЛЬ
# OLD: виться ВИТЬСЯ (ЛЕТАТЬ, КРУЖАСЬ)
# NEW: виться ВИТЬСЯ (РАСТИ ЗАВИТКАМИ)
# OLD: ожидание ЖДАТЬ ПОЯВЛЕНИЯ, ПРИБЫТИЯ
# NEW: ожидание ЖДАТЬ ТОГО, ЧТО ПРОИЗОЙДЕТ
# OLD: виться УВЯЗАТЬСЯ, УВИВАТЬСЯ
# NEW: виться ВИТЬСЯ (РАСТИ ЗАВИТКАМИ)
# OLD: знак ЗНАК (ПРЕДМЕТ)
# NEW: знак ЗНАК, ОБОЗНАЧЕНИЕ
# OLD: лес ДЕЛОВАЯ ДРЕВЕСИНА
# NEW: лес ЛЕС (МНОЖЕСТВО ЧЕГО-Н. ПОДНЯТОГО)
# OLD: сторона СТОРОНА МНОГОУГОЛЬНИКА
# NEW: сторона СТОРОНА (ГРУППА ЛИЦ)
# OLD: туча ТУЧА (МНОЖЕСТВО)
# NEW: туча ДОЖДЕВОЕ ОБЛАКО
# OLD: сторона СТОРОНА (БОКОВАЯ ЧАСТЬ)
# NEW: сторона СТОРОНА (ГРУППА ЛИЦ)
# OLD: гроза ГРОЗА (О ТОМ, ЧТО ВНУШАЕТ СТРАХ, УЖАС)
# NEW: гроза ГРОЗА
# OLD: душа ДУША (БЕССМЕРТНАЯ СУЩНОСТЬ)
# NEW: душа ДУША (ВНУТРЕННИЙ МИР)
# OLD: душа ДУША КОМПАНИИ
# NEW: душа ДУША (ВНУТРЕННИЙ МИР)
# OLD: сок СОК В ОРГАНИЗМЕ
# NEW: сок СОК (НАПИТОК)
# OLD: свет СВЕТ (ЛУЧИСТАЯ ЭНЕРГИЯ)
# NEW: свет СВЕТ ГЛАЗ
# OLD: свет ИСТОЧНИК ОСВЕЩЕНИЯ
# NEW: свет СВЕТ ГЛАЗ
# OLD: СХОДСТВО СХОДСТВО
# NEW: СХОДСТВО СХОДСТВО
# OLD: свет ВЫСШИЙ СВЕТ
# NEW: свет СВЕТ ГЛАЗ
# OLD: мука МУКА (МЕЛКИЙ ПОРОШОК)
# NEW: мука МУКА
# OLD: конь ШАХМАТНЫЙ КОНЬ
# NEW: конь ГИМНАСТИЧЕСКИЙ КОНЬ
# OLD: потолок ПОТОЛОК ПОМЕЩЕНИЯ
# NEW: потолок ПОТОЛОК, ВЕРХНИЙ ПРЕДЕЛ
# 750/2866 synsets parsed.
# OLD: армия АРМИЯ (ВОЙСКОВОЕ СОЕДИНЕНИЕ)
# NEW: армия СУХОПУТНЫЕ ВОЙСКА
# OLD: воля СИЛА ВОЛИ
# NEW: воля ВОЛЯ (СВОБОДА В ПРОЯВЛЕНИИ)
# OLD: воля ВОЛЯ (СТРЕМЛЕНИЕ К ОСУЩЕСТВЛЕНИЮ)
# NEW: воля ВОЛЯ (СВОБОДА В ПРОЯВЛЕНИИ)
# OLD: тряпка НЕРЕШИТЕЛЬНЫЙ ЧЕЛОВЕК
# NEW: тряпка ТРЯПКА, ТРЯПЬЕ
# OLD: бабочка ГАЛСТУК-БАБОЧКА
# NEW: бабочка БАБОЧКА
# OLD: чай ФИТОЧАЙ
# NEW: чай ЧАЙ (НАПИТОК)
# OLD: тряпка ТРЯПКА ДЛЯ УБОРКИ
# NEW: тряпка ТРЯПКА, ТРЯПЬЕ
# OLD: газ ГАЗООБРАЗНОЕ ВЕЩЕСТВО
# NEW: газ ГОРЬКОВСКИЙ АВТОМОБИЛЬНЫЙ ЗАВОД
# OLD: круг ОКРУЖНОСТЬ (ГЕОМЕТРИЧЕСКАЯ ФИГУРА)
# NEW: круг КРУГ, КРУГЛАЯ ПЛОЩАДКА
# OLD: дышать ДЫШАТЬ (ИСПУСКАТЬ)
# NEW: дышать ДЫХАНИЕ, ДЫХАТЕЛЬНЫЙ ПРОЦЕСС
# OLD: гость ГОСТЬ (ПОСТОРОННЕЕ ЛИЦО)
# NEW: гость ГОСТЬ (ТОТ, КТО ПОСЕЩАЕТ, НАВЕЩАЕТ)
# OLD: дышать ДЫШАТЬ (ПРОПУСКАТЬ ВОЗДУХ)
# NEW: дышать ДЫХАНИЕ, ДЫХАТЕЛЬНЫЙ ПРОЦЕСС
# OLD: крыло КРЫЛО ЛЕТАТЕЛЬНОГО АППАРАТА
# NEW: крыло КРЫЛО ПТИЦЫ, ЖИВОТНОГО
# OLD: история ИСТОРИЧЕСКИЕ НАУКИ
# NEW: история ИСТОРИЯ (ХОД РАЗВИТИЯ, ДВИЖЕНИЯ)
# OLD: кофе КОФЕ (НАПИТОК)
# NEW: кофе КОФЕЙНЫЕ ЗЕРНА
# OLD: адский АД, ПРЕИСПОДНЯЯ
# NEW: адский АДСКИЙ (НЕВЫНОСИМЫЙ)
# OLD: холодный ХОЛОДНЫЙ ПО ЦВЕТУ
# NEW: холодный ХОЛОДНЫЙ ПО ТЕМПЕРАТУРЕ
# OLD: военный ВОЕННОСЛУЖАЩИЙ
# NEW: военный ОБОРОНА ГОСУДАРСТВА
# OLD: железный ЖЕЛЕЗО
# NEW: железный ВОЛЕВОЙ, С СИЛОЙ ВОЛИ
# OLD: крыло КРЫЛО КОЛЕСА
# NEW: крыло КРЫЛО ПТИЦЫ, ЖИВОТНОГО
# OLD: медь МЕДЬ
# NEW: медь МЕДНЫЙ ДУХОВОЙ ИНСТРУМЕНТ
# OLD: течь ТЕЧЬ (ДЫРА, ЩЕЛЬ)
# NEW: течь ТЕЧЬ, ПРОПУСКАТЬ ЖИДКОСТЬ
# OLD: медь МЕДНЫЙ ЦВЕТ
# NEW: медь МЕДНЫЙ ДУХОВОЙ ИНСТРУМЕНТ
# OLD: военный ВОЙНА
# NEW: военный ОБОРОНА ГОСУДАРСТВА
# OLD: МОКРЫЙ, СЫРОЙ МОКРЫЙ, СЫРОЙ
# NEW: МОКРЫЙ, СЫРОЙ МОКРЫЙ, СЫРОЙ
# OLD: крыло КРЫЛО СТРОЕНИЯ
# NEW: крыло КРЫЛО ПТИЦЫ, ЖИВОТНОГО
# OLD: воздух ВОЗДУШНОЕ ПРОСТРАНСТВО
# NEW: воздух АТМОСФЕРНЫЙ ВОЗДУХ
# OLD: готовый ГОТОВНОСТЬ, СОСТОЯНИЕ ГОТОВНОСТИ
# NEW: готовый ГОТОВНОСТЬ К ДЕЙСТВИЮ
# OLD: готовый ГОТОВЫЙ, ГОДНЫЙ К УПОТРЕБЛЕНИЮ
# NEW: готовый ГОТОВНОСТЬ К ДЕЙСТВИЮ
# OLD: театр ТЕАТРАЛЬНАЯ ТРУППА
# NEW: театр ТЕАТР
# OLD: крыло ФЛАНГ ПОСТРОЕНИЯ
# NEW: крыло КРЫЛО ПТИЦЫ, ЖИВОТНОГО
# OLD: движение ДОРОЖНОЕ ДВИЖЕНИЕ
# NEW: движение ОБЩЕСТВЕННОЕ ДВИЖЕНИЕ
# OLD: висеть ВИСЕТЬ (ЛЕТАТЬ)
# NEW: висеть ВИСЕТЬ (ПРЕДСТОЯТЬ О НЕПРИЯТНОМ)
# OLD: ХОЛОДНЫЙ В ОТНОШЕНИЯХ ХОЛОДНЫЙ В ОТНОШЕНИЯХ
# NEW: ХОЛОДНЫЙ В ОТНОШЕНИЯХ ХОЛОДНЫЙ В ОТНОШЕНИЯХ
# 1000/2866 synsets parsed.
# OLD: пол ПОЛ (ПОКРЫТИЕ)
# NEW: пол ПОЛОВАЯ ПРИНАДЛЕЖНОСТЬ
# OLD: стать ВСТАТЬ, ПРИНЯТЬ СТОЯЧЕЕ ПОЛОЖЕНИЕ
# NEW: стать СТАТЬ (РАЗМЕСТИТЬСЯ СТОЯ)
# OLD: высота ВЫСОТА ГЕОМЕТРИЧЕСКОЙ ФИГУРЫ
# NEW: высота ВЫСОТА (ПРОСТРАНСТВО)
# OLD: высота ВЫСОТА (РАССТОЯНИЕ)
# NEW: высота ВЫСОТА (ПРОСТРАНСТВО)
# OLD: высота ВЫСОТА ЗВУКА
# NEW: высота ВЫСОТА (ПРОСТРАНСТВО)
# OLD: гнездо ГНЕЗДО (УГЛУБЛЕНИЕ)
# NEW: гнездо СЛОВООБРАЗОВАТЕЛЬНОЕ ГНЕЗДО
# OLD: инструмент МУЗЫКАЛЬНЫЙ ИНСТРУМЕНТ
# NEW: инструмент РУЧНОЙ ИНСТРУМЕНТ
# OLD: краска КРАСКА, КРАСЯЩИЙ СОСТАВ
# NEW: краска КРАСИТЬ, ПОКРЫВАТЬ КРАСКОЙ
# OLD: яйцо ЯЙЦО НАСЕКОМОГО
# NEW: яйцо ЯЙЦО (ПРЕДМЕТ)
# OLD: ПОСТУПОК ЧЕЛОВЕКА ПОСТУПОК ЧЕЛОВЕКА
# NEW: ПОСТУПОК ЧЕЛОВЕКА ПОСТУПОК ЧЕЛОВЕКА
# OLD: гнездо ГНЕЗДО ЖИВОТНОГО
# NEW: гнездо СЛОВООБРАЗОВАТЕЛЬНОЕ ГНЕЗДО
# OLD: огненный ОБЖИГАЮЩЕ ГОРЯЧИЙ
# NEW: огненный СТРАСТЬ (СИЛЬНОЕ ЧУВСТВО)
# OLD: играть ИГРАТЬ (ПРОЯВЛЯТЬСЯ С ЖИВОСТЬЮ, БЛЕСКОМ)
# NEW: играть ИГРАТЬ, ОБРАЩАТЬСЯ ЛЕГКОМЫСЛЕННО
# OLD: план ПЛАН (ЧЕРТЕЖ)
# NEW: план ПЛАН ИЗЛОЖЕНИЯ
# OLD: музыка МУЗЫКАЛЬНОЕ ИСКУССТВО
# NEW: музыка МУЗЫКАЛЬНЫЙ ЗВУК
# OLD: ПРОВАЛИТЬСЯ, ПОТЕРПЕТЬ ПРОВАЛ ПРОВАЛИТЬСЯ, ПОТЕРПЕТЬ ПРОВАЛ
# NEW: ПРОВАЛИТЬСЯ, ПОТЕРПЕТЬ ПРОВАЛ ПРОВАЛИТЬСЯ, ПОТЕРПЕТЬ ПРОВАЛ
# OLD: живой ЖИВОЙ, ЖИВУЩИЙ
# NEW: живой ЖИВОЙ (ВЫРАЗИТЕЛЬНЫЙ)
# OLD: гнать ТОРОПИТЬ, ПОДГОНЯТЬ
# NEW: гнать ГНАТЬ, ПОЛУЧАТЬ ПЕРЕГОНКОЙ
# OLD: ледяной ЛЕДЯНОЙ (ОЧЕНЬ ХОЛОДНЫЙ)
# NEW: ледяной ЛЕДЯНОЙ, ПОКРЫТЫЙ ЛЬДОМ
# OLD: волна ВОЛНА НА ВОДЕ
# NEW: волна ВОЛНА (КОЛЕБАТЕЛЬНОЕ ДВИЖЕНИЕ)
# OLD: письмо ПИСАТЬ, ИЗОБРАЖАТЬ ГРАФИЧЕСКИЕ ЗНАКИ
# NEW: письмо ПИСЬМО (ПОЧТОВОЕ ОТПРАВЛЕНИЕ)
# OLD: газ ГАЗОВОЕ ТОПЛИВО
# NEW: газ ГОРЬКОВСКИЙ АВТОМОБИЛЬНЫЙ ЗАВОД
# OLD: ледяной ЛЕД
# NEW: ледяной ЛЕДЯНОЙ, ПОКРЫТЫЙ ЛЬДОМ
# OLD: неизвестный НЕИЗВЕСТНЫЙ, МАЛОИЗВЕСТНЫЙ
# NEW: неизвестный НЕИЗВЕСТНЫЙ, НЕВЕДОМЫЙ
# OLD: СВЕТИТЬСЯ ЧУВСТВОМ СВЕТИТЬСЯ ЧУВСТВОМ
# NEW: СВЕТИТЬСЯ ЧУВСТВОМ СВЕТИТЬСЯ ЧУВСТВОМ
# OLD: сосна СОСНА (ДРЕВЕСИНА)
# NEW: сосна СОСНА
# OLD: пушка ПУШКА (УСТРОЙСТВО)
# NEW: пушка АРТИЛЛЕРИЙСКАЯ ПУШКА
# OLD: эфир ЭФИРНОЕ ВЕЩАНИЕ
# NEW: эфир ЭФИР (ОРГАНИЧЕСКОЕ СОЕДИНЕНИЕ)
# OLD: поколение ПОКОЛЕНИЕ ЛЮДЕЙ
# NEW: поколение ПОКОЛЕНИЕ СЕМЬИ
# OLD: слух СЛУХ (ВНЕШНЕЕ ЧУВСТВО)
# NEW: слух МУЗЫКАЛЬНЫЙ СЛУХ
# OLD: поколение ФРАНЧАЙЗИ
# NEW: поколение ПОКОЛЕНИЕ СЕМЬИ
# OLD: ледяной ЛЕДЯНОЙ (ПРЕЗРИТЕЛЬНО-ХОЛОДНЫЙ)
# NEW: ледяной ЛЕДЯНОЙ, ПОКРЫТЫЙ ЛЬДОМ
# OLD: тополь ТОПОЛЬ (ДРЕВЕСИНА)
# NEW: тополь ТОПОЛЬ
# OLD: конец КОНЕЦ В ПРОСТРАНСТВЕ
# NEW: конец КОНЕЦ ВО ВРЕМЕНИ
# OLD: знакомый ОСВЕДОМЛЕННЫЙ, ИНФОРМИРОВАННЫЙ
# NEW: знакомый ЗНАКОМЫЙ ЧЕЛОВЕК
# OLD: живой ЖИВОЙ (АКТИВНЫЙ, ДЕЯТЕЛЬНЫЙ)
# NEW: живой ЖИВОЙ (ВЫРАЗИТЕЛЬНЫЙ)
# OLD: план ПЛАН ИЗОБРАЖЕНИЯ
# NEW: план ПЛАН ИЗЛОЖЕНИЯ
# OLD: небесный НЕБЕСНЫЙ ЦВЕТ
# NEW: небесный НЕБО, НЕБЕСНЫЙ СВОД
# OLD: ангел АНГЕЛ (ЧЕЛОВЕК ПО ХАРАКТЕРУ)
# NEW: ангел АНГЕЛ (СЛУЖИТЕЛЬ БОГА)
# 1250/2866 synsets parsed.
# OLD: поколение ПОКОЛЕНИЕ ТОВАРОВ, ПРОДУКЦИИ
# NEW: поколение ПОКОЛЕНИЕ СЕМЬИ
# OLD: почта ПОЧТОВАЯ СВЯЗЬ
# NEW: почта ПОЧТОВОЕ ОТПРАВЛЕНИЕ
# OLD: почта ПОЧТОВОЕ ПРЕДПРИЯТИЕ
# NEW: почта ПОЧТОВОЕ ОТПРАВЛЕНИЕ
# OLD: дно СОЦИАЛЬНЫЕ НИЗЫ
# NEW: дно ДНО ВМЕСТИЛИЩА
# OLD: башня БАШНЯ (МНОГОЭТАЖНЫЙ ДОМ)
# NEW: башня ОРУДИЙНАЯ БАШНЯ
# OLD: сырой СЫРОЙ, НЕПРИГОТОВЛЕННЫЙ
# NEW: сырой СЫРОЙ (НЕДОРАБОТАННЫЙ)
# OLD: точка ТОЧИТЬ, ОТТАЧИВАТЬ
# NEW: точка ТОЧКА (ЗНАК ПРЕПИНАНИЯ)
# OLD: камера РЕЗИНОВАЯ КАМЕРА
# NEW: камера ВНУТРЕННЯЯ КАМЕРА УСТРОЙСТВА
# OLD: камера СЪЕМОЧНАЯ КАМЕРА
# NEW: камера ВНУТРЕННЯЯ КАМЕРА УСТРОЙСТВА
# OLD: камера ТЮРЕМНАЯ КАМЕРА
# NEW: камера ВНУТРЕННЯЯ КАМЕРА УСТРОЙСТВА
# OLD: время ГРАММАТИЧЕСКОЕ ВРЕМЯ
# NEW: время ВРЕМЯ, МОМЕНТ ВРЕМЕНИ
# OLD: дно ДНО УГЛУБЛЕНИЯ
# NEW: дно ДНО ВМЕСТИЛИЩА
# OLD: дух МОРАЛЬНЫЙ ДУХ
# NEW: дух ДУХ (СВЕРХЪЕСТЕСТВЕННОЕ СУЩЕСТВО)
# OLD: ключ КЛЮЧ ДЛЯ ПОНИМАНИЯ, ОВЛАДЕНИЯ
# NEW: ключ ГАЕЧНЫЙ КЛЮЧ
# OLD: ключ КЛЮЧ К ЗАМКУ
# NEW: ключ ГАЕЧНЫЙ КЛЮЧ
# OLD: башня БАШНЯ (СООРУЖЕНИЕ)
# NEW: башня ОРУДИЙНАЯ БАШНЯ
# OLD: ключ КЛЮЧ ШИФРОВАНИЯ
# NEW: ключ ГАЕЧНЫЙ КЛЮЧ
# OLD: ПЕРЕЙТИ В ДРУГОЕ СОСТОЯНИЕ, ПОЛОЖЕНИЕ ПЕРЕЙТИ В ДРУГОЕ СОСТОЯНИЕ, ПОЛОЖЕНИЕ
# NEW: ПЕРЕЙТИ В ДРУГОЕ СОСТОЯНИЕ, ПОЛОЖЕНИЕ ПЕРЕЙТИ В ДРУГОЕ СОСТОЯНИЕ, ПОЛОЖЕНИЕ
# OLD: ключ МУЗЫКАЛЬНЫЙ КЛЮЧ
# NEW: ключ ГАЕЧНЫЙ КЛЮЧ
# OLD: ОТВЕТИТЬ, ПОСТУПИТЬ В ОТВЕТ ОТВЕТИТЬ, ПОСТУПИТЬ В ОТВЕТ
# NEW: ОТВЕТИТЬ, ПОСТУПИТЬ В ОТВЕТ ОТВЕТИТЬ, ПОСТУПИТЬ В ОТВЕТ
# OLD: служба БОГОСЛУЖЕНИЕ
# NEW: служба СЛУЖИТЬ В АРМИИ
# OLD: резать РЕЗЬ
# NEW: резать РЕЗНЫЕ РАБОТЫ
# OLD: низкий НИЗКИЙ, МЕНЬШЕ НОРМЫ
# NEW: низкий НИЗКИЙ ПО ЗВУКУ
# OLD: двор КОРОЛЕВСКИЙ ДВОР
# NEW: двор УСАДЬБА
# OLD: ржавый РЖАВЫЙ (КРАСНО-БУРЫЙ)
# NEW: ржавый РЖАВЧИНА
# OLD: ответ ОТВЕТ (ВЫСКАЗЫВАНИЕ)
# NEW: ответ ОТВЕТ (РЕЗУЛЬТАТ РЕШЕНИЯ)
# OLD: магазин МАГАЗИН
# NEW: магазин МАГАЗИН ДЛЯ ПАТРОНОВ
# OLD: колоть КОЛОТЬ, УКОЛОТЬ
# NEW: колоть УКОЛОТЬ ЗАМЕЧАНИЕМ
# OLD: ПТИЦА ПТИЦА
# NEW: ПТИЦА ПТИЦА
# OLD: закат ЗАКАТ СОЛНЦА
# NEW: закат ВЕЧЕРНЯЯ ЗАРЯ
# OLD: осколок ОСКОЛОК ПРОШЛОГО
# NEW: осколок ОСКОЛОК (ОТКОЛОВШИЙСЯ КУСОК)
# OLD: бродить БРОДИТЬ ТУДА-СЮДА
# NEW: бродить БРОЖЕНИЕ (БИОЛОГИЧЕСКИЙ ПРОЦЕСС)
# OLD: грудь ГРУДЬ (ТУЛОВИЩЕ)
# NEW: грудь ГРУДНАЯ КЛЕТКА
# OLD: ПЕНИЕ ПТИЦЫ ПЕНИЕ ПТИЦЫ
# NEW: ПЕНИЕ ПТИЦЫ ПЕНИЕ ПТИЦЫ
# OLD: грудь ЖЕНСКАЯ ГРУДЬ
# NEW: грудь ГРУДНАЯ КЛЕТКА
# OLD: обед ОБЕДАТЬ, ЕСТЬ ОБЕД
# NEW: обед ОБЕДЕННЫЙ ПЕРЕРЫВ
# OLD: плечо ПЛЕЧО РЫЧАГА
# NEW: плечо ПЛЕЧО (ЧАСТЬ ТУЛОВИЩА)
# OLD: яркий ЯРКИЙ ПО ЦВЕТУ
# NEW: яркий ЯРКИЙ (ВЫРАЗИТЕЛЬНЫЙ)
# OLD: плечо ПЛЕЧО ОДЕЖДЫ
# NEW: плечо ПЛЕЧО (ЧАСТЬ ТУЛОВИЩА)
# OLD: широкий ШИРОКИЙ (СЛИШКОМ БОЛЬШОЙ ПО РАЗМЕРУ)
# NEW: широкий ШИРОКИЙ, БОЛЬШОЙ ПО ШИРИНЕ
# OLD: обед ОБЕД
# NEW: обед ОБЕДЕННЫЙ ПЕРЕРЫВ
# 1500/2866 synsets parsed.
# OLD: ВЕСТИ (СОПРОВОЖДАТЬ) ВЕСТИ (СОПРОВОЖДАТЬ)
# NEW: ВЕСТИ (СОПРОВОЖДАТЬ) ВЕСТИ (СОПРОВОЖДАТЬ)
# OLD: новый НЕИЗВЕСТНЫЙ, МАЛОИЗВЕСТНЫЙ
# NEW: новый НОВЫЙ, ВМЕСТО ПРЕЖНЕГО
# OLD: держаться ДЕРЖАТЬСЯ (СОХРАНЯТЬСЯ, НЕ ИСЧЕЗАТЬ)
# NEW: держаться ДЕРЖАТЬСЯ (ВЕСТИ СЕБЯ)
# OLD: взрыв БУРЯ ЭМОЦИЙ
# NEW: взрыв ВЗРЫВ
# OLD: вера ВЕРА (ГЛУБОКАЯ УБЕЖДЕННОСТЬ)
# NEW: вера ВЕРА В БОГА
# OLD: неделя НЕДЕЛЯ
# NEW: неделя НЕДЕЛЯ (МЕРОПРИЯТИЕ)
# OLD: мелкий МЕЛКИЙ ПО ГЛУБИНЕ
# NEW: мелкий МЕЛКИЙ (НЕБОЛЬШОЙ)
# OLD: перебирать ПЕРЕБРАТЬ (ПЕРЕСМОТРЕТЬ, РАЗОБРАТЬ)
# NEW: перебирать ПЕРЕБОРКА (РЕМОНТ)
# OLD: перебирать ПЕРЕБРАТЬ (ВЗЯТЬ СЛИШКОМ МНОГО)
# NEW: перебирать ПЕРЕБОРКА (РЕМОНТ)
# OLD: круг ТУР СОРЕВНОВАНИЙ
# NEW: круг КРУГ, КРУГЛАЯ ПЛОЩАДКА
# OLD: пятно ПЯТНО НА ПОВЕРХНОСТИ
# NEW: пятно ГРЯЗНОЕ ПЯТНО
# OLD: круглый КРУГЛЫЙ (ЦЕЛЫЙ О ВРЕМЕНИ)
# NEW: круглый КРУГЛАЯ ФОРМА
# OLD: ход ИДТИ (РАБОТА УСТРОЙСТВА)
# NEW: ход ХОД В ИГРЕ
# OLD: красивый БЛАГОЗВУЧНЫЙ
# NEW: красивый КРАСИВЫЙ НА ВИД
# OLD: круглый КРУГЛЫЙ (ПОЛНЫЙ, СОВЕРШЕННЫЙ)
# NEW: круглый КРУГЛАЯ ФОРМА
# OLD: пейзаж ПЕЙЗАЖ, ОПИСАНИЕ ПРИРОДЫ
# NEW: пейзаж ПЕЙЗАЖНОЕ ПОЛОТНО
# OLD: дальний ДАЛЕКИЙ ПО РАССТОЯНИЮ
# NEW: дальний ДАЛЕКИЙ ПО ВРЕМЕНИ
# OLD: фронт ФРОНТ (ВОИНСКИЙ СТРОЙ)
# NEW: фронт ФРОНТ (ОБЩЕСТВЕННОЕ ДВИЖЕНИЕ)
# OLD: горизонт ГОРИЗОНТ (ВИДИМОЕ ПРОСТРАНСТВО)
# NEW: горизонт ГОРИЗОНТ, ЛИНИЯ ГОРИЗОНТА
# OLD: фронт АТМОСФЕРНЫЙ ФРОНТ
# NEW: фронт ФРОНТ (ОБЩЕСТВЕННОЕ ДВИЖЕНИЕ)
# OLD: пейзаж ОКРУЖАЮЩИЙ ПЕЙЗАЖ
# NEW: пейзаж ПЕЙЗАЖНОЕ ПОЛОТНО
# OLD: фронт ЛИНИЯ ФРОНТА
# NEW: фронт ФРОНТ (ОБЩЕСТВЕННОЕ ДВИЖЕНИЕ)
# OLD: действие ДЕЙСТВИЕ ПРОИЗВЕДЕНИЯ
# NEW: действие ДЕЙСТВОВАТЬ (ВЛИЯТЬ, ВОЗДЕЙСТВОВАТЬ)
# OLD: болеть БОЛЕТЬ, БЫТЬ БОЛЬНЫМ
# NEW: болеть БОЛЕТЬ (БЕСПОКОИТЬСЯ)
# OLD: болеть БОЛЕТЬ ЗА СПОРТСМЕНА, КОМАНДУ
# NEW: болеть БОЛЕТЬ (БЕСПОКОИТЬСЯ)
# OLD: хвост ХВОСТ (ПРИЧЕСКА)
# NEW: хвост ХВОСТ ЛЕТАТЕЛЬНОГО АППАРАТА
# OLD: ВЗРОСЛАЯ ЖЕНЩИНА ВЗРОСЛАЯ ЖЕНЩИНА
# NEW: ВЗРОСЛАЯ ЖЕНЩИНА ВЗРОСЛАЯ ЖЕНЩИНА
# OLD: работать ТРУД
# NEW: работать СЛУЖБА, ЗАНЯТИЕ (ИСТОЧНИК ЗАРАБОТКА)
# OLD: РАБОТА, ФУНКЦИОНИРОВАНИЕ РАБОТА, ФУНКЦИОНИРОВАНИЕ
# NEW: РАБОТА, ФУНКЦИОНИРОВАНИЕ РАБОТА, ФУНКЦИОНИРОВАНИЕ
# OLD: ШАГНУТЬ, СДЕЛАТЬ ШАГ ШАГНУТЬ, СДЕЛАТЬ ШАГ
# NEW: ШАГНУТЬ, СДЕЛАТЬ ШАГ ШАГНУТЬ, СДЕЛАТЬ ШАГ
# OLD: парад ВОЕННЫЙ ПАРАД
# NEW: парад ПАРАД (ШЕСТВИЕ)
# OLD: танк ТАНК
# NEW: танк ТАНК (РЕЗЕРВУАР)
# OLD: русский РУССКИЙ ЯЗЫК
# NEW: русский РУССКИЕ
# OLD: губа ГУБЫ ИНСТРУМЕНТА
# NEW: губа ГАУПТВАХТА
# OLD: рост РОСТ ЖИВОГО ОРГАНИЗМА
# NEW: рост РОСТ ЧЕЛОВЕКА, ЖИВОТНОГО
# OLD: вина ВИНА (ПРИЧИНА НЕБЛАГОПРИЯТНОГО)
# NEW: вина ВИНА
# OLD: рост РАСТИ (СОВЕРШЕНСТВОВАТЬСЯ)
# NEW: рост РОСТ ЧЕЛОВЕКА, ЖИВОТНОГО
# OLD: крыло КРЫЛО ПАРТИИ
# NEW: крыло КРЫЛО ПТИЦЫ, ЖИВОТНОГО
# OLD: воевать ВОЕННЫЕ ДЕЙСТВИЯ
# NEW: воевать ВОЕВАТЬ (БОРОТЬСЯ)
# OLD: ПЛАКАТЬ, ПРОЛИВАТЬ СЛЕЗЫ ПЛАКАТЬ, ПРОЛИВАТЬ СЛЕЗЫ
# NEW: ПЛАКАТЬ, ПРОЛИВАТЬ СЛЕЗЫ ПЛАКАТЬ, ПРОЛИВАТЬ СЛЕЗЫ
# 1750/2866 synsets parsed.
# OLD: запад ЗАПАДНАЯ МЕСТНОСТЬ
# NEW: запад ЗАПАД (МАКРОРЕГИОН)
# OLD: воевать ВОЕВАТЬ, УЧАСТВОВАТЬ В ВОЙНЕ
# NEW: воевать ВОЕВАТЬ (БОРОТЬСЯ)
# OLD: книга КНИГА ДЛЯ ЗАПИСИ
# NEW: книга КНИГА (ЧАСТЬ РОМАНА)
# OLD: клык КЛЫК (ЗУБ)
# NEW: клык КЛЫК ЖИВОТНОГО
# OLD: огненный ОГНЕННЫЙ ЦВЕТ
# NEW: огненный СТРАСТЬ (СИЛЬНОЕ ЧУВСТВО)
# OLD: рост УВЕЛИЧИТЬСЯ
# NEW: рост РОСТ ЧЕЛОВЕКА, ЖИВОТНОГО
# OLD: центр ЦЕНТР (ОРГАНИЗАЦИЯ)
# NEW: центр ЦЕНТР (МЕСТО СРЕДОТОЧЕНИЯ)
# OLD: мирный МИРНЫЙ (СПОКОЙНЫЙ, ЧУЖДЫЙ ВОЛНЕНИЙ)
# NEW: мирный МИРНОЕ НАСЕЛЕНИЕ
# OLD: центр ЦЕНТР, ЦЕНТРАЛЬНАЯ ТОЧКА
# NEW: центр ЦЕНТР (МЕСТО СРЕДОТОЧЕНИЯ)
# OLD: центр ЦЕНТР, ЦЕНТРАЛЬНАЯ ЧАСТЬ
# NEW: центр ЦЕНТР (МЕСТО СРЕДОТОЧЕНИЯ)
# OLD: мирный МИРОЛЮБИЕ
# NEW: мирный МИРНОЕ НАСЕЛЕНИЕ
# OLD: ОГОНЬ, ПЛАМЯ ОГОНЬ, ПЛАМЯ
# NEW: ОГОНЬ, ПЛАМЯ ОГОНЬ, ПЛАМЯ
# OLD: цель ЦЕЛЬ, ПРЕДМЕТ СТРЕМЛЕНИЯ
# NEW: цель ЦЕЛЬ ДЛЯ ПОПАДАНИЯ
# OLD: любовь ЛЮБОВЬ, СЕРДЕЧНОЕ ВЛЕЧЕНИЕ
# NEW: любовь ЛЮБОВЬ (ПРИВЯЗАННОСТЬ)
# OLD: церковь ПРАВОСЛАВНЫЙ ХРАМ
# NEW: церковь ЦЕРКОВЬ (РЕЛИГИОЗНАЯ ОРГАНИЗАЦИЯ)
# OLD: остаток ОСТАТОК, ОСТАВШАЯСЯ ЧАСТЬ
# NEW: остаток ОСТАТОК ВРЕМЕНИ
# OLD: остаток ОСТАТОК ОТ ДЕЛЕНИЯ
# NEW: остаток ОСТАТОК ВРЕМЕНИ
# OLD: плач ОБРЯДОВОЕ ПРИЧИТАНИЕ
# NEW: плач ПЛАЧ (ЗВУК)
# OLD: род РОД ЖИВОТНЫХ, РАСТЕНИЙ
# NEW: род ГРАММАТИЧЕСКИЙ РОД
# OLD: ПЫТАТЬСЯ, СТАРАТЬСЯ ПЫТАТЬСЯ, СТАРАТЬСЯ
# NEW: ПЫТАТЬСЯ, СТАРАТЬСЯ ПЫТАТЬСЯ, СТАРАТЬСЯ
# OLD: бомба АВИАЦИОННАЯ БОМБА
# NEW: бомба ТЕРРОРИСТИЧЕСКАЯ БОМБА
# OLD: уверенный УВЕРЕННЫЙ
# NEW: уверенный УВЕРЕННОСТЬ В СЕБЕ
# OLD: воскресение ВОСКРЕСНУТЬ, ВОСПРЯНУТЬ ДУХОМ
# NEW: воскресение ВОСКРЕСЕНИЕ УМЕРШЕГО
# OLD: род РОД (РЯД ПОКОЛЕНИЙ)
# NEW: род ГРАММАТИЧЕСКИЙ РОД
# OLD: род РОД (ГРУППА ЛЮДЕЙ)
# NEW: род ГРАММАТИЧЕСКИЙ РОД
# OLD: МЫСЛИТЕЛЬНЫЙ ПРОЦЕСС МЫСЛИТЕЛЬНЫЙ ПРОЦЕСС
# NEW: МЫСЛИТЕЛЬНЫЙ ПРОЦЕСС МЫСЛИТЕЛЬНЫЙ ПРОЦЕСС
# OLD: строчка МАШИННОЕ ШИТЬЕ
# NEW: строчка МАШИННЫЙ ШОВ
# OLD: ухо УШНАЯ РАКОВИНА
# NEW: ухо УХО ШАПКИ
# OLD: крутой КРУТОЙ (ГУСТОЙ)
# NEW: крутой КРУТОЙ (МОДНЫЙ)
# OLD: карта КАРТА (БЛАНК)
# NEW: карта КАРТА (ЧЕРТЕЖ)
# OLD: крутой КРУТОЙ (ОТВЕСНЫЙ, ОБРЫВИСТЫЙ)
# NEW: крутой КРУТОЙ (МОДНЫЙ)
# OLD: дверь ДВЕРНОЙ ПРОЕМ
# NEW: дверь ДВЕРЬ (ВХОД)
# OLD: тюрьма ТЮРЬМА
# NEW: тюрьма ТЮРЬМА (МЕСТО ОТБЫВАНИЯ НАКАЗАНИЯ)
# OLD: вход ВОЙТИ ВНУТРЬ
# NEW: вход ВОЙТИ В СОСТАВ
# OLD: карта ИГРАЛЬНАЯ КАРТА
# NEW: карта КАРТА (ЧЕРТЕЖ)
# OLD: вход ВХОД, МЕСТО ВХОДА
# NEW: вход ВОЙТИ В СОСТАВ
# OLD: вечность БЕССРОЧНЫЙ, ВЕЧНЫЙ
# NEW: вечность ВЕЧНЫЙ, ВЕЧНО СУЩЕСТВУЮЩИЙ
# OLD: зуб ЗУБЕЦ (ОСТРЫЙ ВЫСТУП)
# NEW: зуб ЗУБ (ОРГАН ДЛЯ ЖЕВАНИЯ)
# OLD: ТЕЧЕНИЕ ВРЕМЕНИ ТЕЧЕНИЕ ВРЕМЕНИ
# NEW: ТЕЧЕНИЕ ВРЕМЕНИ ТЕЧЕНИЕ ВРЕМЕНИ
# OLD: ядерный АТОМНОЕ ЯДРО
# NEW: ядерный ЯДЕРНОЕ ОРУЖИЕ
# OLD: карта КАРТОЧНАЯ ИГРА
# NEW: карта КАРТА (ЧЕРТЕЖ)
# OLD: крутой КРУТОЙ (СУРОВЫЙ)
# NEW: крутой КРУТОЙ (МОДНЫЙ)
# OLD: бить БИТЬ РУЧЬЕМ
# NEW: бить НЕГАТИВНОЕ ВОЗДЕЙСТВИЕ
# OLD: карта ПЛАСТИКОВАЯ КАРТА
# NEW: карта КАРТА (ЧЕРТЕЖ)
# OLD: свободный СВОБОДНЫЙ, НЕЗАНЯТЫЙ
# NEW: свободный СВОБОДНЫЙ (ПРОСТОРНЫЙ)
# OLD: опыт ОПЫТ (ПОПЫТКА)
# NEW: опыт ОПЫТ (СОВОКУПНОСТЬ ЗНАНИЙ И УМЕНИЙ)
# OLD: БЕДНОСТЬ, НУЖДА БЕДНОСТЬ, НУЖДА
# NEW: БЕДНОСТЬ, НУЖДА БЕДНОСТЬ, НУЖДА
# OLD: равный РАВНЫЙ
# NEW: равный РАВНОПРАВИЕ, РАВЕНСТВО
# 2000/2866 synsets parsed.
# OLD: ПОМОЩЬ, ПОДДЕРЖКА ПОМОЩЬ, ПОДДЕРЖКА
# NEW: ПОМОЩЬ, ПОДДЕРЖКА ПОМОЩЬ, ПОДДЕРЖКА
# OLD: жертва ЖЕРТВА, ПОСТРАДАВШЕЕ ЛИЦО
# NEW: жертва ПРИНЕСТИ В ЖЕРТВУ (ДОБРОВОЛЬНО ОТКАЗАТЬСЯ В ПОЛЬЗУ)
# OLD: ОСТАНОВКА ПРИ ДВИЖЕНИИ ОСТАНОВКА ПРИ ДВИЖЕНИИ
# NEW: ОСТАНОВКА ПРИ ДВИЖЕНИИ ОСТАНОВКА ПРИ ДВИЖЕНИИ
# OLD: вкус ВКУС (ВНЕШНЕЕ ЧУВСТВО)
# NEW: вкус ВКУС, ЧУВСТВО ПРЕКРАСНОГО
# OLD: вкус ВКУС, ОЩУЩЕНИЕ НА ЯЗЫКЕ
# NEW: вкус ВКУС, ЧУВСТВО ПРЕКРАСНОГО
# OLD: сила ФИЗИЧЕСКАЯ СИЛА
# NEW: сила СИЛА ВЛИЯНИЯ
# OLD: сила СИЛА (ФИЗИЧЕСКАЯ ВЕЛИЧИНА)
# NEW: сила СИЛА ВЛИЯНИЯ
# OLD: сила СИЛА, ЖИЗНЕННАЯ СИЛА
# NEW: сила СИЛА ВЛИЯНИЯ
# OLD: кухня КУХНЯ (ПОМЕЩЕНИЕ)
# NEW: кухня ВНУТРЕННЯЯ КУХНЯ
# OLD: кухня КУХОННАЯ МЕБЕЛЬ
# NEW: кухня ВНУТРЕННЯЯ КУХНЯ
# OLD: просить ХОДАТАЙСТВОВАТЬ
# NEW: просить ПРОСИТЬ (НУЖДАТЬСЯ )
# OLD: герой ГЕРОЙ, ГЕРОИЧЕСКИЙ ЧЕЛОВЕК
# NEW: герой ГЕРОЙ (ОБРАЗЕЦ ДЛЯ ПОДРАЖАНИЯ)
# OLD: тень ТЕНЕВАЯ ЭКОНОМИКА
# NEW: тень ТЕНЬ НА ИЗОБРАЖЕНИИ
# OLD: ПРИГОТОВЛЕНИЕ ПИЩИ ПРИГОТОВЛЕНИЕ ПИЩИ
# NEW: ПРИГОТОВЛЕНИЕ ПИЩИ ПРИГОТОВЛЕНИЕ ПИЩИ
# OLD: тень ТЕНЬ (ТЕМНОЕ ОТРАЖЕНИЕ)
# NEW: тень ТЕНЬ НА ИЗОБРАЖЕНИИ
# OLD: герой ГЛАВНЫЙ ГЕРОЙ
# NEW: герой ГЕРОЙ (ОБРАЗЕЦ ДЛЯ ПОДРАЖАНИЯ)
# OLD: жертва ЖЕРТВА БОГАМ
# NEW: жертва ПРИНЕСТИ В ЖЕРТВУ (ДОБРОВОЛЬНО ОТКАЗАТЬСЯ В ПОЛЬЗУ)
# OLD: чистый ЧИСТЫЙ, БЕЗ ПРИМЕСЕЙ
# NEW: чистый ЧИСТЫЙ (НЕТРОНУТЫЙ)
# OLD: тень ТЕНЬ, ТЕНИСТОЕ МЕСТО
# NEW: тень ТЕНЬ НА ИЗОБРАЖЕНИИ
# OLD: тень ТЕНИ ДЛЯ ВЕК
# NEW: тень ТЕНЬ НА ИЗОБРАЖЕНИИ
# OLD: ЧЕЛОВЕК ЧЕЛОВЕК
# NEW: ЧЕЛОВЕК ЧЕЛОВЕК
# OLD: власть ВЛАСТЬ, БРАЗДЫ ПРАВЛЕНИЯ
# NEW: власть ПУБЛИЧНАЯ ВЛАСТЬ
# OLD: вопрос ВОПРОС (ОБРАЩЕНИЕ)
# NEW: вопрос ВОПРОСИТЕЛЬНЫЙ ЗНАК
# OLD: реальность ВЫПОЛНИМЫЙ, ИСПОЛНИМЫЙ, ОСУЩЕСТВИМЫЙ
# NEW: реальность РЕАЛЬНО СУЩЕСТВУЮЩИЙ
# OLD: спокойный СПОКОЙСТВИЕ (РАСПОЛОЖЕНИЕ ДУХА)
# NEW: спокойный СПОКОЙНОЕ ПОВЕДЕНИЕ
# OLD: спокойный СПОКОЙНЫЙ (ИСПОЛНЕННЫЙ СПОКОЙСТВИЯ)
# NEW: спокойный СПОКОЙНОЕ ПОВЕДЕНИЕ
# OLD: спокойный СПОКОЙНЫЙ (ПРИЯТНЫЙ ДЛЯ ГЛАЗ)
# NEW: спокойный СПОКОЙНОЕ ПОВЕДЕНИЕ
# OLD: память ПАМЯТЬ (ЧАСТЬ СОЗНАНИЯ)
# NEW: память ЗАПОМИНАЮЩЕЕ УСТРОЙСТВО
# OLD: МЯГКИЙ, НЕЖНЫЙ НА ОЩУПЬ МЯГКИЙ, НЕЖНЫЙ НА ОЩУПЬ
# NEW: МЯГКИЙ, НЕЖНЫЙ НА ОЩУПЬ МЯГКИЙ, НЕЖНЫЙ НА ОЩУПЬ
# OLD: УБИЙСТВО ЧЕЛОВЕКА УБИЙСТВО ЧЕЛОВЕКА
# NEW: УБИЙСТВО ЧЕЛОВЕКА УБИЙСТВО ЧЕЛОВЕКА
# OLD: поле ПОЛЕ СИЛ
# NEW: поле СПОРТИВНОЕ ПОЛЕ
# OLD: поле ПОЛЕ (ПЛОЩАДКА)
# NEW: поле СПОРТИВНОЕ ПОЛЕ
# OLD: число ЧИСЛО (ПОНЯТИЕ МАТЕМАТИКИ)
# NEW: число ЧИСЛО МЕСЯЦА
# OLD: боль ДУШЕВНОЕ СТРАДАНИЕ
# NEW: боль БОЛЬ, БОЛЕВОЕ ОЩУЩЕНИЕ
# OLD: глубокий ГЛУБОКИЙ (СИЛЬНЫЙ)
# NEW: глубокий ГЛУБОКИЙ, БОЛЬШОЙ ПО ГЛУБИНЕ
# OLD: число ГРАММАТИЧЕСКОЕ ЧИСЛО
# NEW: число ЧИСЛО МЕСЯЦА
# OLD: колонна ДВИЖУЩАЯСЯ КОЛОННА
# NEW: колонна КОЛОННА (СООРУЖЕНИЕ)
# OLD: поле СЕЛЬСКОХОЗЯЙСТВЕННОЕ ПОЛЕ
# NEW: поле СПОРТИВНОЕ ПОЛЕ
# OLD: след СЛЕД (ОСТАТОК)
# NEW: след СЛЕД НОГИ
# 2250/2866 synsets parsed.
# OLD: молчание МОЛЧАТЬ, СОБЛЮДАТЬ В ТАЙНЕ
# NEW: молчание МОЛЧАТЬ, НЕ ИЗДАВАТЬ ЗВУКОВ
# OLD: сирена СИРЕНА (МОРСКОЕ ЛАСТОНОГОЕ ЖИВОТНОЕ)
# NEW: сирена СИРЕНА (МИФОЛОГИЧЕСКОЕ СУЩЕСТВО)
# OLD: ЗАМЕНИТЬ, НАЙТИ ЗАМЕНУ ЗАМЕНИТЬ, НАЙТИ ЗАМЕНУ
# NEW: ЗАМЕНИТЬ, НАЙТИ ЗАМЕНУ ЗАМЕНИТЬ, НАЙТИ ЗАМЕНУ
# OLD: порядок ПОРЯДОК СЛЕДОВАНИЯ
# NEW: порядок ПОРЯДОК (СОСТОЯНИЕ)
# OLD: игра ИГРАТЬ (ПРОЯВЛЯТЬСЯ С ЖИВОСТЬЮ, БЛЕСКОМ)
# NEW: игра ИГРАТЬ, ОБРАЩАТЬСЯ ЛЕГКОМЫСЛЕННО
# OLD: УДАРИТЬ, НАНЕСТИ УДАР УДАРИТЬ, НАНЕСТИ УДАР
# NEW: УДАРИТЬ, НАНЕСТИ УДАР УДАРИТЬ, НАНЕСТИ УДАР
# OLD: экран ЗАЩИТНЫЙ ЭКРАН
# NEW: экран ДЕМОНСТРАЦИОННЫЙ ЭКРАН
# OLD: след СЛЕД НА ПОВЕРХНОСТИ
# NEW: след СЛЕД НОГИ
# OLD: игра ИГРАТЬ (ИСПОЛНЯТЬ)
# NEW: игра ИГРАТЬ, ОБРАЩАТЬСЯ ЛЕГКОМЫСЛЕННО
# OLD: перо ПЕРО ПТИЦ
# NEW: перо ПИСАТЕЛЬСТВО
# OLD: любимый ЛЮБИМЫЙ, ИЗЛЮБЛЕННЫЙ
# NEW: любимый ЛЮБИМЫЙ (ТАКОЙ, КОТ. ЛЮБЯТ)
# OLD: кошка КОШАЧЬИ
# NEW: кошка КОШКИ ДЛЯ ЛАЗАНИЯ
# OLD: игра ИГРА (РАЗВЛЕЧЕНИЕ)
# NEW: игра ИГРАТЬ, ОБРАЩАТЬСЯ ЛЕГКОМЫСЛЕННО
# OLD: сильный ФИЗИЧЕСКИ СИЛЬНЫЙ
# NEW: сильный СИЛЬНЫЙ (ЗНАЧИТЕЛЬНЫЙ ПО ВЕЛИЧИНЕ, СТЕПЕНИ)
# OLD: ракета РАКЕТА
# NEW: ракета ПИРОТЕХНИЧЕСКАЯ РАКЕТА
# OLD: БИТЬСЯ (ДРАТЬСЯ, СРАЖАТЬСЯ) БИТЬСЯ (ДРАТЬСЯ, СРАЖАТЬСЯ)
# NEW: БИТЬСЯ (ДРАТЬСЯ, СРАЖАТЬСЯ) БИТЬСЯ (ДРАТЬСЯ, СРАЖАТЬСЯ)
# OLD: масло МАСЛЯНАЯ КРАСКА
# NEW: масло МАСЛЯНАЯ ЖИВОПИСЬ
# OLD: песок САХАРНЫЙ ПЕСОК
# NEW: песок ПЕСОК
# OLD: порядок ПОРЯДОК ДЕЯТЕЛЬНОСТИ
# NEW: порядок ПОРЯДОК (СОСТОЯНИЕ)
# OLD: экран ЭКРАН (ЭЛЕКТРОННОЕ УСТРОЙСТВО)
# NEW: экран ДЕМОНСТРАЦИОННЫЙ ЭКРАН
# OLD: экран КИНОЭКРАН
# NEW: экран ДЕМОНСТРАЦИОННЫЙ ЭКРАН
# OLD: масло СЛИВОЧНОЕ МАСЛО
# NEW: масло МАСЛЯНАЯ ЖИВОПИСЬ
# OLD: масло МАСЛО (ЖИДКИЙ ЖИР)
# NEW: масло МАСЛЯНАЯ ЖИВОПИСЬ
# OLD: прозрачный ПРОЗРАЧНЫЙ НА ВИД
# NEW: прозрачный ПРОЗРАЧНЫЙ ДЛЯ ПОНИМАНИЯ
# OLD: неверный ГЯУР (ИНОВЕРЕЦ)
# NEW: неверный ИЗМЕНИТЬ (НАРУШИТЬ ВЕРНОСТЬ)
# OLD: язык ЯЗЫК
# NEW: язык ЯЗЫК (МЯСО)
# OLD: минута УГЛОВАЯ МИНУТА
# NEW: минута МИНУТА (ЕДИНИЦА ВРЕМЕНИ)
# OLD: сирена СИРЕНА (СИГНАЛЬНОЕ УСТРОЙСТВО)
# NEW: сирена СИРЕНА (МИФОЛОГИЧЕСКОЕ СУЩЕСТВО)
# OLD: кошка ДОМАШНЯЯ КОШКА
# NEW: кошка КОШКИ ДЛЯ ЛАЗАНИЯ
# OLD: правый ПРАВАЯ ПОЛИТИЧЕСКАЯ ОРИЕНТАЦИЯ
# NEW: правый РАСПОЛОЖЕНИЕ СПРАВА
# OLD: сирена СИРЕНА (ЗВУК)
# NEW: сирена СИРЕНА (МИФОЛОГИЧЕСКОЕ СУЩЕСТВО)
# OLD: РАСПАСТЬСЯ НА СОСТАВНЫЕ ЧАСТИ РАСПАСТЬСЯ НА СОСТАВНЫЕ ЧАСТИ
# NEW: РАСПАСТЬСЯ НА СОСТАВНЫЕ ЧАСТИ РАСПАСТЬСЯ НА СОСТАВНЫЕ ЧАСТИ
# OLD: случайный СЛУЧАЙНЫЙ, ОТ СЛУЧАЯ К СЛУЧАЮ
# NEW: случайный СЛУЧАЙНЫЙ (НЕОЖИДАННЫЙ И НЕПРОИЗВОЛЬНЫЙ)
# OLD: служить СЛУЖИТЬ В АРМИИ
# NEW: служить СЛУЖИТЬ, ИМЕТЬ СВОИМ НАЗНАЧЕНИЕМ
# OLD: снаряд СПОРТИВНЫЙ ИНВЕНТАРЬ
# NEW: снаряд СНАРЯД
# OLD: кофе КОФЕЙНОЕ ДЕРЕВО
# NEW: кофе КОФЕЙНЫЕ ЗЕРНА
# OLD: струна СТРУНА (ТУГО НАТЯН. НИТЬ)
# NEW: струна СТРУНА МУЗЫКАЛЬНОГО ИНСТРУМЕНТА
# OLD: фон ЦВЕТ ФОНА
# NEW: фон ЗАДНИЙ ПЛАН ИЗОБРАЖЕНИЯ
# OLD: бой БОЙ (БИТЫЙ МАТЕРИАЛ)
# NEW: бой РАЗБИТЬ НА ЧАСТИ
# OLD: язык ЯЗЫК (ОРГАН ВКУСА)
# NEW: язык ЯЗЫК (МЯСО)
# OLD: игра ИГРАЛЬНЫЙ КОМПЛЕКТ
# NEW: игра ИГРАТЬ, ОБРАЩАТЬСЯ ЛЕГКОМЫСЛЕННО
# OLD: служить СЛУЖИТЬ (ПОСВЯТИТЬ СЕБЯ)
# NEW: служить СЛУЖИТЬ, ИМЕТЬ СВОИМ НАЗНАЧЕНИЕМ
# OLD: оружие ОРУЖИЕ
# NEW: оружие ОРУЖИЕ ДЛЯ ДОСТИЖЕНИЯ ЦЕЛИ
# OLD: бумага ПИСЧАЯ БУМАГА
# NEW: бумага ЦЕННАЯ БУМАГА
# OLD: пьяный ПЬЯНЫЙ ЧЕЛОВЕК
# NEW: пьяный УПОЕНИЕ
# OLD: ДВИЖЕНИЕ, ПЕРЕМЕЩЕНИЕ ДВИЖЕНИЕ, ПЕРЕМЕЩЕНИЕ
# NEW: ДВИЖЕНИЕ, ПЕРЕМЕЩЕНИЕ ДВИЖЕНИЕ, ПЕРЕМЕЩЕНИЕ
# OLD: свидетель СВИДЕТЕЛЬ ПО ДЕЛУ
# NEW: свидетель СВИДЕТЕЛЬ (ЛИЦО, ПРИСУТСТВУЮЩЕЕ ДЛЯ УДОСТОВЕРЕНИЯ)
# OLD: бумага БУМАЖНАЯ ПРОДУКЦИЯ
# NEW: бумага ЦЕННАЯ БУМАГА
# OLD: история ИСТОРИЧЕСКОЕ РАЗВИТИЕ
# NEW: история ИСТОРИЯ (ХОД РАЗВИТИЯ, ДВИЖЕНИЯ)
# OLD: честь ЧЕСТЬ (МОРАЛЬНЫЙ ПРИНЦИП)
# NEW: честь ПОЧТЕНИЕ
# OLD: лицо ГРАММАТИЧЕСКОЕ ЛИЦО
# NEW: лицо ЛИЦЕВАЯ СТОРОНА
# 2500/2866 synsets parsed.
# OLD: РАЗГОВОР, БЕСЕДА РАЗГОВОР, БЕСЕДА
# NEW: РАЗГОВОР, БЕСЕДА РАЗГОВОР, БЕСЕДА
# OLD: СМЕРТЬ СМЕРТЬ
# NEW: СМЕРТЬ СМЕРТЬ
# OLD: почка ПОЧКА РАСТЕНИЯ
# NEW: почка ПОЧКИ
# OLD: общий ОБЩИЙ, НЕКОНКРЕТНЫЙ
# NEW: общий СОВОКУПНЫЙ
# OLD: ЦВЕТЕНИЕ РАСТЕНИЯ ЦВЕТЕНИЕ РАСТЕНИЯ
# NEW: ЦВЕТЕНИЕ РАСТЕНИЯ ЦВЕТЕНИЕ РАСТЕНИЯ
# OLD: ОСТАНОВИТЬ ДВИЖЕНИЕ ОСТАНОВИТЬ ДВИЖЕНИЕ
# NEW: ОСТАНОВИТЬ ДВИЖЕНИЕ ОСТАНОВИТЬ ДВИЖЕНИЕ
# OLD: сухой СУХОЙ, НЕМОКРЫЙ
# NEW: сухой СУХАЯ ПОГОДА
# OLD: БОЕВЫЕ ДЕЙСТВИЯ БОЕВЫЕ ДЕЙСТВИЯ
# NEW: БОЕВЫЕ ДЕЙСТВИЯ БОЕВЫЕ ДЕЙСТВИЯ
# OLD: станция КОСМИЧЕСКАЯ СТАНЦИЯ
# NEW: станция СТАНЦИЯ ТЕХНИЧЕСКОГО ОБСЛУЖИВАНИЯ
# OLD: голос ГОЛОС, ВОКАЛЬНАЯ ПАРТИЯ
# NEW: голос ГОЛОС, ПРАВО ГОЛОСА
# OLD: сухой СУХОЙ (СКУПОЙ, ЛАКОНИЧНЫЙ)
# NEW: сухой СУХАЯ ПОГОДА
# OLD: сеть РЫБОЛОВНАЯ СЕТЬ
# NEW: сеть СЕТЬ ОРГАНИЗАЦИЙ
# OLD: станция СТАНЦИЯ НАБЛЮДЕНИЯ
# NEW: станция СТАНЦИЯ ТЕХНИЧЕСКОГО ОБСЛУЖИВАНИЯ
# OLD: северный СЕВЕР
# NEW: северный СЕВЕРНАЯ МЕСТНОСТЬ
# OLD: насилие НАСИЛИЕ (ПРИНУДИТЕЛЬНОЕ ВОЗДЕЙСТВИЕ)
# NEW: насилие ФИЗИЧЕСКОЕ НАСИЛИЕ
# OLD: молоко МОЛОКО (ПРОДУКЦИЯ)
# NEW: молоко МОЛОКО МЛЕКОПИТАЮЩИХ
# OLD: станция СТАНЦИЯ (МЕСТО ОСТАНОВКИ)
# NEW: станция СТАНЦИЯ ТЕХНИЧЕСКОГО ОБСЛУЖИВАНИЯ
# OLD: стекло СТЕКЛЯННОЕ ИЗДЕЛИЕ
# NEW: стекло СТЕКЛО
# OLD: бег БЕЖАТЬ (БЫСТРО ДВИГАТЬСЯ)
# NEW: бег БЕЖАТЬ (ДВИГАТЬСЯ НА НОГАХ)
# OLD: сухой СУХОЙ СЧЕТ
# NEW: сухой СУХАЯ ПОГОДА
# OLD: плод ЗАРОДЫШ ЧЕЛОВЕКА
# NEW: плод ПЛОД РАСТЕНИЯ
# OLD: молоко МЛЕЧНЫЙ СОК
# NEW: молоко МОЛОКО МЛЕКОПИТАЮЩИХ
# OLD: ПРОПАСТЬ КУДА-ТО ПРОПАСТЬ КУДА-ТО
# NEW: ПРОПАСТЬ КУДА-ТО ПРОПАСТЬ КУДА-ТО
# OLD: война ВОЙНА
# NEW: война ВОЕВАТЬ (БОРОТЬСЯ)
# OLD: БУДУЩЕЕ (ПЕРИОД ВРЕМЕНИ) БУДУЩЕЕ (ПЕРИОД ВРЕМЕНИ)
# NEW: БУДУЩЕЕ (ПЕРИОД ВРЕМЕНИ) БУДУЩЕЕ (ПЕРИОД ВРЕМЕНИ)
# OLD: домашний ДОМ (СВОЕ ЖИЛЬЕ)
# NEW: домашний ДОМАШНИЙ (НЕ ДИКИЙ)
# OLD: тянуться ПОТЯНУТЬСЯ ДРУГ ЗА ДРУГОМ
# NEW: тянуться СКЛОННОСТЬ (ПОСТОЯННОЕ ВЛЕЧЕНИЕ)
# OLD: домашний ДОМАШНИЙ СТАДИОН
# NEW: домашний ДОМАШНИЙ (НЕ ДИКИЙ)
# OLD: тихий ТИХИЙ, НЕ ОЖИВЛЕННЫЙ
# NEW: тихий ТИХИЙ, НЕГРОМКИЙ
# OLD: право ПРАВОВАЯ СИСТЕМА
# NEW: право ПРАВО (ВОЗМОЖНОСТЬ)
# OLD: корень ПРОИСХОЖДЕНИЕ (ВОЗНИКНОВЕНИЕ, ПОЯВЛЕНИЕ)
# NEW: корень ПЕРВОИСТОЧНИК
# OLD: журнал ЖУРНАЛ
# NEW: журнал ЖУРНАЛ ДЛЯ ЗАПИСИ
# OLD: карман МАТЕРИАЛЬНОЕ ПОЛОЖЕНИЕ
# NEW: карман КАРМАН ОДЕЖДЫ
# OLD: корень КОРЕНЬ СЛОВА
# NEW: корень ПЕРВОИСТОЧНИК
# OLD: тянуться РАСТЯЖИМОСТЬ (МЕХАНИЧЕСКОЕ СВОЙСТВО)
# NEW: тянуться СКЛОННОСТЬ (ПОСТОЯННОЕ ВЛЕЧЕНИЕ)
# OLD: тянуться ТЯНУТЬСЯ, ЧТОБЫ ДОСТАТЬ
# NEW: тянуться СКЛОННОСТЬ (ПОСТОЯННОЕ ВЛЕЧЕНИЕ)
# OLD: корень КОРЕНЬ ЧИСЛА
# NEW: корень ПЕРВОИСТОЧНИК
# OLD: ТРЕВОГА, БЕСПОКОЙСТВО ТРЕВОГА, БЕСПОКОЙСТВО
# NEW: ТРЕВОГА, БЕСПОКОЙСТВО ТРЕВОГА, БЕСПОКОЙСТВО
# OLD: тянуться ТЯНУТЬСЯ, ПОТЯГИВАТЬСЯ
# NEW: тянуться СКЛОННОСТЬ (ПОСТОЯННОЕ ВЛЕЧЕНИЕ)
# OLD: карман КАРМАН (ВЫЕМКА)
# NEW: карман КАРМАН ОДЕЖДЫ
# OLD: лук ЗЕЛЕНЫЙ ЛУК
# NEW: лук ЛУК (РАСТЕНИЕ)
# OLD: домашний ДОМАШНЕЕ ИЗГОТОВЛЕНИЕ
# NEW: домашний ДОМАШНИЙ (НЕ ДИКИЙ)
# OLD: лук ЛУК (ОРУЖИЕ)
# NEW: лук ЛУК (РАСТЕНИЕ)
# OLD: потеря ТЕРЯТЬ, УТЕРЯТЬ
# NEW: потеря ТЕРЯТЬ, ТРАТИТЬ ЗРЯ
# OLD: тихий СМИРНЫЙ, ТИХИЙ
# NEW: тихий ТИХИЙ, НЕГРОМКИЙ
# OLD: УТРАТИТЬ УТРАТИТЬ
# NEW: УТРАТИТЬ УТРАТИТЬ
# OLD: ДРОЖАТЬ (КОЛЕБАТЬСЯ) ДРОЖАТЬ (КОЛЕБАТЬСЯ)
# NEW: ДРОЖАТЬ (КОЛЕБАТЬСЯ) ДРОЖАТЬ (КОЛЕБАТЬСЯ)
# OLD: маска КОСМЕТИЧЕСКАЯ МАСКА
# NEW: маска МАСКА, СКРЫВАЮЩАЯ ЛИЦО
# OLD: СТРЕЛЬБА СТРЕЛЬБА
# NEW: СТРЕЛЬБА СТРЕЛЬБА
# OLD: маска МАСКА (НАКЛАДКА)
# NEW: маска МАСКА, СКРЫВАЮЩАЯ ЛИЦО
# OLD: рукав РУКАВ ОДЕЖДЫ
# NEW: рукав РУКАВ (ШЛАНГ)
# OLD: мужчина МУЖЧИНА, ЧЕЛОВЕК МУЖСКОГО ПОЛА
# NEW: мужчина НАСТОЯЩИЙ МУЖЧИНА
# OLD: гимн ГИМН
# NEW: гимн ГОСУДАРСТВЕННЫЙ ГИМН
# OLD: воздушный ВОЗДУШНОЕ ПРОСТРАНСТВО
# NEW: воздушный АТМОСФЕРНЫЙ ВОЗДУХ
# OLD: рукав РУКАВ РЕКИ
# NEW: рукав РУКАВ (ШЛАНГ)
# 2750/2866 synsets parsed.
# OLD: держаться ДЕРЖАТЬСЯ (СОХРАНЯТЬ ПОЛОЖЕНИЕ)
# NEW: держаться ДЕРЖАТЬСЯ (ВЕСТИ СЕБЯ)
# OLD: держаться ДЕРЖАТЬСЯ, НЕ СДАВАТЬСЯ
# NEW: держаться ДЕРЖАТЬСЯ (ВЕСТИ СЕБЯ)
# OLD: нож НОЖ (КУХОННАЯ УТВАРЬ)
# NEW: нож НОЖ (ХОЛОДНОЕ ОРУЖИЕ)
# OLD: взрослый СОВЕРШЕННОЛЕТНИЙ, ВЗРОСЛЫЙ ЧЕЛОВЕК
# NEW: взрослый ВЗРОСЛЫЙ ПО ВОЗРАСТУ
# OLD: ОБНЯТЬ, ЗАКЛЮЧИТЬ В ОБЪЯТИЯ ОБНЯТЬ, ЗАКЛЮЧИТЬ В ОБЪЯТИЯ
# NEW: ОБНЯТЬ, ЗАКЛЮЧИТЬ В ОБЪЯТИЯ ОБНЯТЬ, ЗАКЛЮЧИТЬ В ОБЪЯТИЯ
# OLD: ствол СТВОЛ ДЕРЕВА
# NEW: ствол СТВОЛ (СТЕРЖЕНЬ ИЛИ ТРУБА)
# OLD: ЖИТЬ (СУЩЕСТВОВАТЬ) ЖИТЬ (СУЩЕСТВОВАТЬ)
# NEW: ЖИТЬ (СУЩЕСТВОВАТЬ) ЖИТЬ (СУЩЕСТВОВАТЬ)
# OLD: личный ЛИЧНОЕ ОСУЩЕСТВЛЕНИЕ
# NEW: личный ЛИЧНЫЙ, ПЕРСОНАЛЬНЫЙ
# OLD: ствол СТВОЛ КОЛОННЫ
# NEW: ствол СТВОЛ (СТЕРЖЕНЬ ИЛИ ТРУБА)
# OLD: ствол СТВОЛ ОРУЖИЯ
# NEW: ствол СТВОЛ (СТЕРЖЕНЬ ИЛИ ТРУБА)
# OLD: ЕСТЬ, ПРИНИМАТЬ ПИЩУ ЕСТЬ, ПРИНИМАТЬ ПИЩУ
# NEW: ЕСТЬ, ПРИНИМАТЬ ПИЩУ ЕСТЬ, ПРИНИМАТЬ ПИЩУ
# OLD: парк ПАРК, ПАРКОВАЯ ЗОНА
# NEW: парк ПАРК ТЕХНИЧЕСКИХ СРЕДСТВ
# OLD: ИСТИННЫЙ, ВЕРНЫЙ ИСТИННЫЙ, ВЕРНЫЙ
# NEW: ИСТИННЫЙ, ВЕРНЫЙ ИСТИННЫЙ, ВЕРНЫЙ
# OLD: шум ШУМИХА (ОЖИВЛЕННЫЕ ТОЛКИ, РАЗГОВОРЫ)
# NEW: шум ТЕХНОГЕННЫЙ ШУМ
# OLD: ДЕЙСТВИЕ, ЦЕЛЕНАПРАВЛЕННОЕ ДЕЙСТВИЕ ДЕЙСТВИЕ, ЦЕЛЕНАПРАВЛЕННОЕ ДЕЙСТВИЕ
# NEW: ДЕЙСТВИЕ, ЦЕЛЕНАПРАВЛЕННОЕ ДЕЙСТВИЕ ДЕЙСТВИЕ, ЦЕЛЕНАПРАВЛЕННОЕ ДЕЙСТВИЕ
# OLD: пустой ПУСТОЙ, НЕЗАПОЛНЕННЫЙ
# NEW: пустой ПУСТОГОЛОВЫЙ
# OLD: балкон БАЛКОН ЗДАНИЯ
# NEW: балкон БАЛКОН ЗРИТЕЛЬНОГО ЗАЛА
# OLD: парк ПАРК (ТРАНСПОРТНОЕ ПРЕДПРИЯТИЕ)
# NEW: парк ПАРК ТЕХНИЧЕСКИХ СРЕДСТВ
# OLD: общий ОБЩИЙ (ПРОИЗВОДИМЫЙ ИЛИ ИСПОЛЬЗУЕМЫЙ СОВМЕСТНО)
# NEW: общий СОВОКУПНЫЙ
# OLD: трамвай ТРАМВАЙНЫЙ ВАГОН
# NEW: трамвай ТРАМВАЙНЫЙ ТРАНСПОРТ
# OLD: дочка ДОЧКА (ОБРАЩЕНИЕ К МОЛОДОЙ ЖЕНЩИНЕ, ДЕВОЧКЕ)
# NEW: дочка ДОЧЕРНЯЯ КОМПАНИЯ
# OLD: восток ВОСТОК (МАКРОРЕГИОН)
# NEW: восток ВОСТОЧНАЯ МЕСТНОСТЬ
# OLD: восток ВОСТОК
# NEW: восток ВОСТОЧНАЯ МЕСТНОСТЬ

# %%
filename = 'synsetMeanDiff10-20_Fixed'
with open(f'{filename}.json', 'w', encoding='utf-8') as f:
    json.dump(freqdatalist, f, ensure_ascii=False, indent=4)

# %%
# shake up the data
for f in freqdatalist:
    f['s_x'] = f['s_x'] + [-1,1][random.randrange(2)]*random.random()/2
    f['s_y'] = f['s_y'] + [-1,1][random.randrange(2)]*random.random()/2

# %%
filename = 'shakenSynsetMeanDiff10-20_Fixed'
with open(f'{filename}.json', 'w', encoding='utf-8') as f:
    json.dump(freqdatalist, f, ensure_ascii=False, indent=4)

# %%
\
