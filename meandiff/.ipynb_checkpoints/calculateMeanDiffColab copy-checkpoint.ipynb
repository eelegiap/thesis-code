# %%
import pandas as pd
import random
import json
import math
import statistics
import re
import time
import numpy as np

# %% [markdown]
# ### Stanza doesn't work fuck

# %%
# pip uninstall stanza -y

# %%
# pip install stanza

# %%
import stanza
# stanza.download('uk')
stanza.download('ru')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-00dca8679235> in <module>
# ----> 1 import stanza
#       2 # stanza.download('uk')
#       3 stanza.download('ru')
#
# ModuleNotFoundError: No module named 'stanza'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
nlp = stanza.Pipeline('ru',processors='tokenize,pos,lemma')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8f5774fdea8b> in <module>
# ----> 1 nlp = stanza.Pipeline('ru',processors='tokenize,pos,lemma')
#
# NameError: name 'stanza' is not defined

# %% [markdown]
# ### Does Spacy work?

# %%
# pip install spacy

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# !python -m spacy download ru_core_news_lg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ru-core-news-lg==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_lg-3.4.0/ru_core_news_lg-3.4.0-py3-none-any.whl (513.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.4/513.4 MB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from ru-core-news-lg==3.4.0) (3.4.4)
# Collecting pymorphy2>=0.9
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 KB 5.5 MB/s eta 0:00:00
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 24.5 MB/s eta 0:00:00
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (4.64.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (1.0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (3.0.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2.25.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (1.0.9)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (1.10.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (1.21.6)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (6.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (8.1.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (21.3)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (0.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2.11.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (1.24.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->ru-core-news-lg==3.4.0) (2.0.1)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=3fb5ca6524239de04681d7f8d1be02edb572c72e7d31c7c431011c93fc3d018e
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2, ru-core-news-lg
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844 ru-core-news-lg-3.4.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_lg')

# %%
import spacy 
nlp = spacy.load("ru_core_news_lg")

# %% [markdown]
# ### Install other pacakges

# %%
# pip install nltk

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
from nltk.corpus import stopwords

rustops = set(stopwords.words('russian'))
ukstops = ['а', 'аби', 'абиде', 'абиким', 'абикого', 'абиколи', 'абикому', 'абикуди', 'абихто', 'абичий', 'абичийого', 'абичийому', 'абичим', 'абичию', 'абичия', 'абичиє', 'абичиєму', 'абичиєю', 'абичиєї', 'абичиї', 'абичиїй', 'абичиїм', 'абичиїми', 'абичиїх', 'абичого', 'абичому', 'абищо', 'абияка', 'абияке', 'абиякий', 'абияким', 'абиякими', 'абияких', 'абиякого', 'абиякому', 'абиякою', 'абиякої', 'абияку', 'абиякі', 'абиякій', 'абиякім', 'або', 'абощо', 'авжеж', 'авось', 'ага', 'ад', 'адже', 'аж', 'ажень', 'аз', 'ай', 'але', 'ало', 'амінь', 'ант', 'ану', 'ані', 'аніде', 'аніж', 'анізащо', 'аніким', 'анікого', 'анікогісінько', 'аніколи', 'анікому', 'аніскільки', 'аніхто', 'анічим', 'анічого', 'анічогісінько', 'анічому', 'аніщо', 'аніяка', 'аніяке', 'аніякий', 'аніяким', 'аніякими', 'аніяких', 'аніякого', 'аніякому', 'аніякою', 'аніякої', 'аніяку', 'аніякі', 'аніякій', 'аніякім', 'аніякісенька', 'аніякісеньке', 'аніякісенький', 'аніякісеньким', 'аніякісенькими', 'аніякісеньких', 'аніякісенького', 'аніякісенькому', 'аніякісенькою', 'аніякісенької', 'аніякісеньку', 'аніякісенькі', 'аніякісенькій', 'аніякісенькім', 'аніякісінька', 'аніякісіньке', 'аніякісінький', 'аніякісіньким', 'аніякісінькими', 'аніякісіньких', 'аніякісінького', 'аніякісінькому', 'аніякісінькою', 'аніякісінької', 'аніякісіньку', 'аніякісінькі', 'аніякісінькій', 'аніякісінькім', 'ат', 'ато', 'атож', 'ау', 'ах', 'ач', 'ачей', 'аякже', 'б', 'ба', 'багато', 'багатьма', 'багатьом', 'багатьох', 'баз', 'бай', 'бат', 'бах', 'бац', 'баш', 'бе', 'беж', 'без', 'безперервно', 'бел', 'бер', 'би', 'бир', 'бич', 'близько', 'близько від', 'бо', 'бов', 'бод', 'бодай', 'боз', 'бош', 'був', 'буває', 'буде', 'будем', 'будемо', 'будете', 'будеш', 'буду', 'будуть', 'будь', 'будь ласка', 'будьмо', 'будьте', 'була', 'були', 'було', 'бути', 'бух', 'буц', 'буцім', 'буцімто', 'бі', 'біб', 'більш', 'більше', 'біля', 'в', 'в бік', 'в залежності від', 'в міру', 'в напрямі до', 'в порівнянні з', 'в процесі', 'в результаті', 'в ролі', 'в силу', 'в сторону', 'в супроводі', 'в ході', "в ім'я", 'в інтересах', 'вад', 'важлива', 'важливе', 'важливий', 'важливі', 'вак', 'вам', 'вами', 'ван', 'вас', 'ват', 'ваш', 'ваша', 'ваше', 'вашим', 'вашими', 'ваших', 'вашого', 'вашому', 'вашою', 'вашої', 'вашу', 'ваші', 'вашій', 'вашім', 'ввесь', 'вві', 'вгору', 'вдалині', 'вед', 'верх', 'весь', 'вех', 'вже', 'вздовж', 'ви', 'виз', 'вис', 'височині', 'вище ', 'вйо', 'власне', 'властиво', 'вміти', 'внаслідок', 'вниз', 'внизу', 'во', 'вон', 'вона', 'вони', 'воно', 'восьмий', 'вперед', 'вподовж', 'впоперек', 'впритиск', 'впритул', 'впродовж', 'впрост', 'все', 'всередині', 'всею', 'вслід', 'всупереч', 'всього', 'всьому', 'всю', 'всюди', 'вся', 'всяк', 'всяка', 'всяке', 'всякий', 'всяким', 'всякими', 'всяких', 'всякого', 'всякому', 'всякою', 'всякої', 'всяку', 'всякі', 'всякій', 'всякім', 'всі', 'всій', 'всіляка', 'всіляке', 'всілякий', 'всіляким', 'всілякими', 'всіляких', 'всілякого', 'всілякому', 'всілякою', 'всілякої', 'всіляку', 'всілякі', 'всілякій', 'всілякім', 'всім', 'всіма', 'всіх', 'всією', 'всієї', 'втім', 'ві', 'віг', 'від', 'від імені', 'віддалік від', 'відколи', 'відносно', 'відповідно', 'відповідно до', 'відсотків', 'відтепер', 'відтоді', 'він', 'вісім', 'вісімнадцятий', 'вісімнадцять', 'віт', 'віф', 'віх', 'віц', 'віщо', 'віщось', 'г', 'га', 'гав', 'гаразд', 'ге', 'гез', 'гем', 'геп', 'гет', 'геть', 'гех', 'ги', 'гик', 'гир', 'гич', 'гм', 'го', 'говорив', 'гог', 'гоп', 'гоц', 'гу', 'гуп', 'д', 'да', 'давай', 'давати', 'давно', 'далеко', 'далеко від', 'далі', 'даром', 'два', 'двадцятий', 'двадцять', 'дванадцятий', 'дванадцять', 'двох', 'дві', 'де', "дев'ятий", "дев'ятнадцятий", "дев'ятнадцять", "дев'ять", 'дедалі', 'деким', 'декого', 'деколи', 'декому', 'декотра', 'декотре', 'декотрий', 'декотрим', 'декотрими', 'декотрих', 'декотрого', 'декотрому', 'декотрою', 'декотрої', 'декотру', 'декотрі', 'декотрій', 'декотрім', 'декілька', 'декільком', 'декількома', 'декількох', 'декім', 'десь', 'десятий', 'десять', 'дехто', 'дечий', 'дечийого', 'дечийому', 'дечим', 'дечию', 'дечия', 'дечиє', 'дечиєму', 'дечиєю', 'дечиєї', 'дечиї', 'дечиїй', 'дечиїм', 'дечиїми', 'дечиїх', 'дечого', 'дечому', 'дечім', 'дещо', 'деяка', 'деяке', 'деякий', 'деяким', 'деякими', 'деяких', 'деякого', 'деякому', 'деякою', 'деякої', 'деяку', 'деякі', 'деякій', 'деякім', 'деінде', 'для', 'до', 'добре', 'довго', 'довкола', 'довкіл', 'дог', 'доки', 'допоки', 'допіру', 'досить', 'досі', 'дотепер', 'доти', 'другий', 'друго', 'дуже', 'дякую', 'дійсно', 'діл', 'е', 'еге', 'еж', 'ей', 'ерг', 'ест', 'ет', 'ех', 'еч', 'ж', 'же', 'жоден', 'жодна', 'жодне', 'жодний', 'жодним', 'жодними', 'жодних', 'жодного', 'жодному', 'жодною', 'жодної', 'жодну', 'жодні', 'жодній', 'жоднім', 'жоднісінька', 'жоднісіньке', 'жоднісінький', 'жоднісіньким', 'жоднісінькими', 'жоднісіньких', 'жоднісінького', 'жоднісінькому', 'жоднісінькою', 'жоднісінької', 'жоднісіньку', 'жоднісінькі', 'жоднісінькій', 'жоднісінькім', 'жуз', 'з', 'з метою', 'з нагоди', 'з приводу', 'з розрахунку на', 'з-за', 'з-над', 'з-перед', 'з-поза', 'з-поміж', 'з-понад', 'з-поперед', 'з-посеред', 'з-проміж', 'з-під', 'з-серед', 'за', 'за винятком', 'за допомогою', 'за посередництвом', 'за рахунок', 'завгодно', 'завдяки', 'завжди', 'завше', 'задля', 'зазвичай', 'зайнята', 'зайнятий', 'зайнято', 'зайняті', 'залежно', 'залежно від', 'замість', 'занадто', 'заради', 'зараз', 'зас', 'зате', 'збоку', 'збоку від', 'зважаючи на', 'зверх ', 'зверху', 'звичайно', 'звиш', 'звідки', 'звідкилясь', 'звідкись', 'звідкіль', 'звідкіля', 'звідкілясь', 'звідси', 'звідсіль', 'звідсіля', 'звідти', 'звідтіль', 'звідтіля', 'звідусюди', 'звідусіль', 'звідціля', 'згідно з', 'здається', 'здовж', 'зем', 'зет', 'ззаду', 'зиз', 'зик', 'значить', 'знову', 'зо', 'зовсім', 'зсередини', 'зух', 'зі', 'зіс', 'и', 'ич', 'й', 'ймовірно', 'йно', 'йо', 'його', 'йой', 'йол', 'йому', 'йор', 'йот', 'йох', 'к', 'каже', 'каз', 'кар', 'каф', 'ках', 'ке', 'кед', 'кет', 'кеш', 'кив', 'кий', 'кил', 'ким', 'кимось', 'кимсь', 'ких', 'киш', 'коб', 'коби', 'кого', 'когось', 'кожен', 'кожна', 'кожне', 'кожний', 'кожним', 'кожними', 'кожних', 'кожного', 'кожному', 'кожною', 'кожної', 'кожну', 'кожні', 'кожній', 'кожнім', 'кожнісінька', 'кожнісіньке', 'кожнісінький', 'кожнісіньким', 'кожнісінькими', 'кожнісіньких', 'кожнісінького', 'кожнісінькому', 'кожнісінькою', 'кожнісінької', 'кожнісіньку', 'кожнісінькі', 'кожнісінькій', 'кожнісінькім', 'коли', 'колись', 'коло', 'кому', 'комусь', 'котра', 'котрась', 'котре', 'котресь', 'котрий', 'котрийсь', 'котрим', 'котрими', 'котримись', 'котримось', 'котримсь', 'котрих', 'котрихось', 'котрихсь', 'котрого', 'котрогось', 'котрому', 'котромусь', 'котрою', 'котроюсь', 'котрої', 'котроїсь', 'котру', 'котрусь', 'котрі', 'котрій', 'котрійсь', 'котрім', 'котрімсь', 'котрісь', 'коц', 'коч', 'коштом', 'край', 'краще', 'кру', 'круг', 'кругом', 'крю', 'кря', 'крізь', 'крім', 'куди', 'кудись', 'кудою', 'кілька', 'кільком', 'кількома', 'кількох', 'кім', 'кімось', 'кімсь', 'кінець', 'л', 'лаж', 'лап', 'лас', 'лат', 'ле', 'ледве', 'ледь', 'лет', 'лиш', 'лише', 'лишень', 'лум', 'луп', 'лут', 'льє', 'люди', 'людина', 'ля', 'лі', 'ліворуч від', 'лік', 'лім', 'м', 'мабуть', 'майже', 'мало', 'мати', 'мац', 'ме', 'меж', 'мене', 'менше', 'мені', 'мерсі', 'мет', 'мжа', 'ми', 'мимо ', 'миру', 'мит', 'мною', 'мо', 'мов', 'мовби', 'мовбито', 'могла', 'могли', 'могло', 'мого', 'могти', 'мож', 'може', 'можем', 'можемо', 'можете', 'можеш', 'можна', 'можу', 'можуть', 'можіть', 'мой', 'мол', 'мою', 'моя', 'моє', 'моєму', 'моєю', 'моєї', 'мої', 'моїй', 'моїм', 'моїми', 'моїх', 'му', 'мі', 'міг', 'між', 'мій', 'мільйонів', 'н', 'на', 'на адресу', 'на базі', 'на благо', 'на випадок', 'на відміну від', 'на засадах', 'на знак', 'на зразок', 'на користь', 'на кшталт', 'на межі', 'на основі', 'на противагу', 'на підставі', 'на честь', 'на чолі', 'на ґрунті', 'навколо', 'навкруг', 'навкруги ', 'навкіл', 'навпаки', 'навперейми', 'навпроти', 'навіть', 'навіщо', 'навіщось', 'нагорі', 'над', 'надо', 'надовкола', 'надокола', 'наді', 'назавжди', 'назад', 'назустріч', 'най', 'найбільш', 'нам', 'нами', 'наоколо ', 'наокруг ', 'наокруги ', 'наокіл', 'наперед', 'напередодні', 'напереді', 'наперекір', 'напереріз', 'наприкінці', 'напроти', 'нарешті', 'нарівні з', 'нас', 'насеред', 'насподі', 'наспід', 'настрічу', 'насупроти', 'насупротив ', 'нате', 'наче', 'начеб', 'начебто', 'наш', 'наша', 'наше', 'нашим', 'нашими', 'наших', 'нашого', 'нашому', 'нашою', 'нашої', 'нашу', 'наші', 'нашій', 'нашім', 'не', 'не до', 'не можна', 'неабичим', 'неабичого', 'неабичому', 'неабищо', 'небагато', 'небагатьма', 'небагатьом', 'небагатьох', 'небудь', 'невважаючи', 'невже', 'недалеко', 'недалеко від', 'неж', 'незалежно від', 'незважаючи', 'незважаючи на', 'ней', 'немає', 'немов', 'немовби', 'немовбито', 'неначе', 'неначебто', 'неподалеку', 'неподалеку від', 'неподалечку', 'неподалечку від', 'неподалік', 'неподалік від', 'нерідко', 'нех', 'нехай', 'нещодавно', 'нею', 'неї', 'нижче', 'низько', 'ник', 'ним', 'ними', 'них', 'нич', 'но', 'ну', 'нуг', 'нуд', 'нум', 'нумо', 'нумте', 'ньо', 'нього', 'ньому', 'ню', 'нюх', 'ня', 'няв', 'ні', 'ніби', 'ніби-то', 'нібито', 'ніде', 'ніж', 'нізащо', 'нізвідки', 'нізвідкіля', 'ній', 'ніким', 'нікого', 'нікогісінько', 'ніколи', 'нікому', 'нікотра', 'нікотре', 'нікотрий', 'нікотрим', 'нікотрими', 'нікотрих', 'нікотрого', 'нікотрому', 'нікотрою', 'нікотрої', 'нікотру', 'нікотрі', 'нікотрій', 'нікотрім', 'нікуди', 'нім', 'нінащо', 'ніскільки', 'ніт', 'ніхто', 'нічий', 'нічийна', 'нічийне', 'нічийний', 'нічийним', 'нічийними', 'нічийних', 'нічийного', 'нічийному', 'нічийною', 'нічийної', 'нічийну', 'нічийні', 'нічийній', 'нічийнім', 'нічийого', 'нічийому', 'нічим', 'нічию', 'нічия', 'нічиє', 'нічиєму', 'нічиєю', 'нічиєї', 'нічиї', 'нічиїй', 'нічиїм', 'нічиїми', 'нічиїх', 'нічого', 'нічому', 'ніщо', 'ніяк', 'ніяка', 'ніяке', 'ніякий', 'ніяким', 'ніякими', 'ніяких', 'ніякого', 'ніякому', 'ніякою', 'ніякої', 'ніяку', 'ніякі', 'ніякій', 'ніякім', 'ніякісінька', 'ніякісіньке', 'ніякісінький', 'ніякісіньким', 'ніякісінькими', 'ніякісіньких', 'ніякісінького', 'ніякісінькому', 'ніякісінькою', 'ніякісінької', 'ніякісіньку', 'ніякісінькі', 'ніякісінькій', 'ніякісінькім', 'о', 'об', 'обабіч', 'обаполи', 'обидва', 'обр', 'обік', 'обіруч', 'обіч', 'ов', 'од', 'один', 'одинадцятий', 'одинадцять', 'одна', 'однак', 'одначе', 'одне', 'одним', 'одними', 'одних', 'одно', 'одного', 'одного разу', 'одному', 'одною', 'одної', 'одну', 'одні', 'одній', 'однім', 'однією', 'однієї', 'ож', 'ой', 'окрай', 'окроме', 'округ', 'округи', 'окрім', 'окіл', 'ом', 'он', 'онде', 'онно', 'оно', 'оподаль', 'оподаль від', 'оподалік', 'оподалік від', 'опостін', 'опостінь', 'опроче', 'опріч', 'опріче', 'опісля', 'осе', 'оскільки', 'особливо', 'осторонь', 'ось', 'осісьо', 'от', 'ота', 'отак', 'отака', 'отаке', 'отакий', 'отаким', 'отакими', 'отаких', 'отакого', 'отакому', 'отакою', 'отакої', 'отаку', 'отакі', 'отакій', 'отакім', 'отакісінька', 'отакісіньке', 'отакісінький', 'отакісіньким', 'отакісінькими', 'отакісіньких', 'отакісінького', 'отакісінькому', 'отакісінькою', 'отакісінької', 'отакісіньку', 'отакісінькі', 'отакісінькій', 'отакісінькім', 'отам', 'оте', 'отже', 'отим', 'отими', 'отих', 'ото', 'отого', 'отож', 'отой', 'отому', 'отою', 'отої', 'отсе', 'оттак', 'отто', 'оту', 'отут', 'оті', 'отій', 'отім', 'отією', 'отієї', 'ох', 'оце', 'оцей', 'оцим', 'оцими', 'оцих', 'оцього', 'оцьому', 'оцю', 'оця', 'оці', 'оцій', 'оцім', 'оцією', 'оцієї', 'п', "п'я", "п'ятий", "п'ятнадцятий", "п'ятнадцять", "п'ять", 'па', 'пад', 'пак', 'пек', 'перед', 'передо', 'переді', 'перетака', 'перетаке', 'перетакий', 'перетаким', 'перетакими', 'перетаких', 'перетакого', 'перетакому', 'перетакою', 'перетакої', 'перетаку', 'перетакі', 'перетакій', 'перетакім', 'перший', 'пиж', 'плі', 'по', 'поблизу', 'побік', 'побіля', 'побіч', 'поверх', 'повз', 'повздовж', 'повинно', 'повище', 'повсюди', 'повсюдно', 'подаль від', 'подалі від', 'подекуди', 'подеяка', 'подеяке', 'подеякий', 'подеяким', 'подеякими', 'подеяких', 'подеякого', 'подеякому', 'подеякою', 'подеякої', 'подеяку', 'подеякі', 'подеякій', 'подеякім', 'подовж', 'подібно до', 'поз', 'поза', 'позад', 'позаду', 'позата', 'позате', 'позатим', 'позатими', 'позатих', 'позатого', 'позатой', 'позатому', 'позатою', 'позатої', 'позату', 'позаті', 'позатій', 'позатім', 'позатією', 'позатієї', 'позаяк', 'поздовж', 'поки', 'покрай', 'покіль', 'помежи', 'помимо', 'поміж', 'помість', 'понад', 'понадо', 'понаді', 'понижче', 'пообіч', 'поодаль від', 'поодалік від', 'поперед', 'попереду', 'поперек', 'попліч', 'попри', 'попросту', 'попід', 'пора', 'поруч', 'поряд', 'поряд з', 'порівняно з', 'посеред', 'посередині', 'потрібно', 'потім', 'поуз', 'початку', 'почерез', 'праворуч від', 'пред', 'предо', 'преді', 'прекрасно', 'прецінь', 'при', 'притому', 'причому', 'причім', 'про', 'проз', 'промеж', 'проміж', 'просто', 'проте', 'проти', 'против', 'противно', 'протягом', 'пря', 'пріч', 'пхе', 'пху', 'пі', 'пів', 'півперек', 'під', 'під знаком', 'під приводом', 'під час', 'підо', 'пізніше', 'пім', 'пір', 'після', 'р', 'ради', 'раз', 'разом з', 'разу', 'рано', 'раніш', 'раніш від', 'раніше', 'раніше від', 'раптом', 'ре', 'рет', 'риж', 'рим', 'рип', 'роб', 'року', 'років', 'рос', 'рох', 'році', 'рус', 'рух', 'руч', 'рік', 'с', 'саж', 'саз', 'сак', 'сам', 'сама', 'саме', 'сами', 'самий', 'самим', 'самими', 'самих', 'само', 'самого', 'самому', 'самою', 'самої', 'саму', 'самі', 'самій', 'самім', 'сап', 'сас', 'свого', 'свою', 'своя', 'своє', 'своєму', 'своєю', 'своєї', 'свої', 'своїй', 'своїм', 'своїми', 'своїх', 'свій', 'се', 'себе', 'себто', 'сей', 'сен', 'серед', 'середи', 'середу', 'сеч', 'си', 'сив', 'сиг', 'сиз', 'сик', 'сиріч', 'сих', 'сказав', 'сказала', 'сказати', 'скрізь', 'скільки', 'скільки-то', 'скількись', 'скільком', 'скількома', 'скількомась', 'скількомось', 'скількомсь', 'скількох', 'скількохось', 'скількохсь', 'сли', 'слідом за', 'соб', 'собою', 'собі', 'соп', 'спасибі', 'спереду', 'спочатку', 'справ', 'справді', 'став', 'стосовно', 'стільки', 'стільком', 'стількома', 'стількох', 'су', 'судячи з', 'супроти', 'супротив', 'суть', 'суч', 'суш', 'сьогодні', 'сьомий', 'сюди', 'ся', 'сяг', 'сяк', 'сяка', 'сяке', 'сякий', 'сяким', 'сякими', 'сяких', 'сякого', 'сякому', 'сякою', 'сякої', 'сяку', 'сякі', 'сякій', 'сякім', 'сям', 'сі', 'сім', 'сімнадцятий', 'сімнадцять', 'сіп', 'т', 'та', 'таж', 'так', 'така', 'таке', 'такенна', 'такенне', 'такенний', 'такенним', 'такенними', 'такенних', 'такенного', 'такенному', 'такенною', 'такенної', 'такенну', 'такенні', 'такенній', 'такеннім', 'таки', 'такий', 'таким', 'такими', 'таких', 'такого', 'також', 'такому', 'такою', 'такої', 'таку', 'такі', 'такій', 'такім', 'такісінька', 'такісіньке', 'такісінький', 'такісіньким', 'такісінькими', 'такісіньких', 'такісінького', 'такісінькому', 'такісінькою', 'такісінької', 'такісіньку', 'такісінькі', 'такісінькій', 'такісінькім', 'тал', 'там', 'тамки', 'тамта', 'тамте', 'тамтим', 'тамтими', 'тамтих', 'тамтого', 'тамтой', 'тамтому', 'тамтою', 'тамтої', 'тамту', 'тамті', 'тамтій', 'тамтім', 'тамтією', 'тамтієї', 'тар', 'тат', 'таш', 'тва', 'твого', 'твою', 'твоя', 'твоє', 'твоєму', 'твоєю', 'твоєї', 'твої', 'твоїй', 'твоїм', 'твоїми', 'твоїх', 'твій', 'те', 'тебе', 'тег', 'теж', 'тем', 'тепер', 'теперечки', 'тес', 'теф', 'теє', 'ти', 'тик', 'тил', 'тим', 'тими', 'тисяч', 'тих', 'то', 'тобою', 'тобто', 'тобі', 'того', 'тоді', 'тож', 'той', 'тол', 'тому', 'тому що', 'тот', 'тощо', 'тою', 'тої', 'тра', 'тре', 'треба', 'третій', 'три', 'тринадцятий', 'тринадцять', 'трохи', 'тс', 'тсс', 'ту', 'туди', 'тудою', 'туп', 'тут', 'тутеньки', 'тутечки', 'тутки', 'туф', 'туц', 'тю', 'тюг', 'тюп', 'тяг', 'тяж', 'тям', 'тяп', 'ті', 'тій', 'тільки', 'тім', 'тією', 'у', 'у бік', 'у вигляді', 'у випадку', 'у відповідності до', 'у відповідь на', 'у залежності від', "у зв'язку з", 'у міру', 'у напрямі до', 'у порівнянні з', 'у процесі', 'у результаті', 'у ролі', 'у силу', 'у сторону', 'у супроводі', 'у ході', 'ув', 'увесь', 'уві', 'угу', 'уже', 'узбіч', 'уздовж', 'укр', 'ум', 'унаслідок', 'униз', 'унизу', 'унт', 'уперед', 'уподовж', 'упоперек', 'упритиск до', 'упритул до', 'упродовж', 'упрост', 'ус', 'усе', 'усередині', 'услід', 'услід за', 'усупереч', 'усього', 'усьому', 'усю', 'усюди', 'уся', 'усяк', 'усяка', 'усяке', 'усякий', 'усяким', 'усякими', 'усяких', 'усякого', 'усякому', 'усякою', 'усякої', 'усяку', 'усякі', 'усякій', 'усякім', 'усі', 'усій', 'усіляка', 'усіляке', 'усілякий', 'усіляким', 'усілякими', 'усіляких', 'усілякого', 'усілякому', 'усілякою', 'усілякої', 'усіляку', 'усілякі', 'усілякій', 'усілякім', 'усім', 'усіма', 'усіх', 'усією', 'усієї', 'утім', 'ух', 'ф', "ф'ю", 'фа', 'фаг', 'фай', 'фат', 'фе', 'фед', 'фез', 'фес', 'фет', 'фзн', 'фоб', 'фот', 'фра', 'фру', 'фу', 'фук', 'фур', 'фус', 'фіш', 'х', 'ха', 'хаз', 'хай', 'хап', 'хат', 'хащ', 'хе', 'хет', 'хи', 'хиб', 'хм', 'хо', 'хов', 'хол', 'хон', 'хоп', 'хор', 'хотіти', 'хоч', 'хоча', 'хочеш', 'хро', 'хрю', 'хто', 'хтось', 'ху', 'хуз', 'хук', 'хух', 'хху', 'хіба', 'ц', 'це', 'цебто', 'цей', 'цеп', 'ци', 'цим', 'цими', 'цир', 'цих', 'цло', 'цоб', 'цок', 'цоп', 'цор', 'цс', 'цсс', 'цуг', 'цур', 'цуц', 'цього', 'цьому', 'цю', 'цюк', 'ця', 'цяв', 'цяп', 'ці', 'цід', 'цій', 'цім', 'ціною', 'цією', 'цієї', 'ч', 'чал', 'чар', 'час', 'часто', 'частіше', 'часу', 'чах', 'чей', 'чень', 'через', 'четвертий', 'чи', 'чий', 'чийого', 'чийогось', 'чийому', 'чийомусь', 'чийсь', 'чик', 'чим', 'чимось', 'чимсь', 'чир', 'численна', 'численне', 'численний', 'численним', 'численними', 'численних', 'численні', 'чию', 'чиюсь', 'чия', 'чиясь', 'чиє', 'чиєму', 'чиємусь', 'чиєсь', 'чиєю', 'чиєюсь', 'чиєї', 'чиєїсь', 'чиї', 'чиїй', 'чиїйсь', 'чиїм', 'чиїми', 'чиїмись', 'чиїмось', 'чиїмсь', 'чиїсь', 'чиїх', 'чиїхось', 'чиїхсь', 'чля', 'чого', 'чогось', 'чом', 'чому', 'чомусь', 'чон', 'чоп', 'чортзна', 'чос', 'чотири', 'чотирнадцятий', 'чотирнадцять', 'чу', 'чум', 'чур', 'чш', 'чім', 'чімось', 'чімсь', 'чіт', 'ш', 'ша', 'шаг', 'шал', 'шам', 'шво', 'шед', 'шен', 'шиз', 'шир', 'шляхом', 'шостий', 'шістнадцятий', 'шістнадцять', 'шість', 'щ', 'ще', 'щем', 'щеп', 'щип', 'щир', 'що', 'щоб', 'щоби', 'щодо', 'щойно', 'щоправда', 'щось', 'щі', 'ь', 'ю', 'юз', 'юн', 'юнь', 'юс', 'ют', 'юхт', 'я', 'яв', 'яд', 'яз', 'язь', 'як', 'яка', 'якась', 'якби', 'яке', 'якесь', 'який', 'якийсь', 'яким', 'якими', 'якимись', 'якимось', 'якимсь', 'яких', 'якихось', 'якихсь', 'якого', 'якогось', 'якому', 'якомусь', 'якось', 'якою', 'якоюсь', 'якої', 'якоїсь', 'якраз', 'яку', 'якусь', 'якщо', 'які', 'якій', 'якійсь', 'якім', 'якімсь', 'якісь', 'ял', 'ям', 'ян', 'янь', 'яо', 'яп', 'ярл', 'ясь', 'ять', 'є', 'єр', 'єси', 'і', 'ібн', 'ід', 'із', 'із-за', 'із-під', 'іззаду', 'ізм', 'ізсередини', 'ік', 'ікс', 'ікт', "ім'я", 'імовірно', 'інакша', 'інакше', 'інакший', 'інакшим', 'інакшими', 'інакших', 'інакшого', 'інакшому', 'інакшою', 'інакшої', 'інакшу', 'інакші', 'інакшій', 'інакшім', 'інколи', 'іноді', 'інша', 'інше', 'інший', 'іншим', 'іншими', 'інших', 'іншого', 'іншому', 'іншою', 'іншої', 'іншу', 'інші', 'іншій', 'іншім', 'інь', 'іч', 'іще', 'ї', 'їдь', 'їй', 'їм', 'їх', 'їхнього', 'їхньому', 'їхньою', 'їхньої', 'їхню', 'їхня', 'їхнє', 'їхні', 'їхній', 'їхнім', 'їхніми', 'їхніх', 'її', 'ґ']

# %%
def initializeRec(recText):
    if isinstance(recText, str):
        return recText.strip()
    else:
        return False

def skipLine(line, idx):
    if len(line.strip()) == 0:
        return False
    
    # throw hashtag line
    if line.strip()[0] == '#':
        return True
    
    # throw attribution line
    for attr in ['из личного','личный блог','источник:','авторский блог']:
        if attr in line.lower():
            return True
        
    # dots at the beginning
    matches = re.search("[\*\+\^-_][*+^-_= ]+", line.strip()) 
    if matches:
        return True
    
    # is none of it alphanumeric
    containsAlpha = False
    for char in line:
        if char.isalpha():
            containsAlpha = True
            break
    if not containsAlpha:
        return True
    
    return False


def processRec(rec):
    recText = initializeRec(rec['Text'])
    cleanLines = []
    if recText:
        # decide which lines to keep
        lines = recText.split('\n')
        for i, line in enumerate(lines):
            if skipLine(line, i):
                continue
            cleanLines.append(line)
    return '\n'.join(cleanLines)

# %%
# # https://pypi.org/project/translate-api/
# # !pip install translate-api
# !pip3 install translators --upgrade
# import translators as ts

# %%
# !pip install -U deep-translator
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deep-translator
#   Downloading deep_translator-1.9.1-py3-none-any.whl (30 kB)
# Collecting beautifulsoup4<5.0.0,>=4.9.1
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 KB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.8/dist-packages (from deep-translator) (2.25.1)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2022.12.7)
# Installing collected packages: soupsieve, beautifulsoup4, deep-translator
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.11.1 deep-translator-1.9.1 soupsieve-2.3.2.post1

# %%
from deep_translator import GoogleTranslator
lemma='собака'
GoogleTranslator(source='ru', target='en').translate(lemma)
# Out:
# 'dog'

# %% [markdown]
# ### Parse records into docs

# %%
# pip install openpyxl

# %%
# df = pd.read_excel('../Excel_files/Full_Poem_Dataset_12-17.xlsx')
df = pd.read_excel('Full_Poem_Dataset_12-17.xlsx')
records = df.to_dict('records')

# %%
doc = nlp(random.choice(records)['Text'][:100])
for token in doc:
    print(token.text, token.lemma_)
# Out:
# * *
# * *
# * *
#
#
#
#
#
# На на
# пятом пятый
# месяце месяц
# война война
#
#
#
# Стучится стучится
# в в
# рёбра ребро
# , ,
#
#
#
# Жизнь жизнь
# с с
# февраля февраль
# беременна беременный
# , ,
#
#
#
# Скорей скорей
# бы бы
# роды род
# , ,
#
#
#
#
#
# Скорей скорей
# кон кон

# %%
from tqdm import tqdm

# %%
# %%time
for rec in tqdm(records):
    # if i % 250 == 0:
    #     print(f'{i}/{len(records)} parsed')
    cleanedText = processRec(rec)
    rec['cleanedText'] = cleanedText
    rec['doc'] = nlp(cleanedText)
# Out:
# 100%|██████████| 3289/3289 [03:00<00:00, 18.22it/s]
# CPU times: user 2min 55s, sys: 1.48 s, total: 2min 57s
# Wall time: 3min

# %%
# wrote pickle
import pickle

with open('recsWithSpacyDocs1-9.pickle', 'wb') as handle:
    pickle.dump(records, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# !pip3 install pickle5
# import pickle5 as pickle

# %% [markdown]
# ### Load Pickle with Docs

# %%
# read pickle
import pickle

with open('recs3502WithSpacyDocs10-23.pickle', 'rb') as handle:
    records = pickle.load(handle)

# %%
records[10]
# Out:
# {'Unnamed: 0': 10,
#  'Text': '* * * \nПисатель Владимир Шаров был типичным провокатором.\nДадут ему понюхать духовную книжку, допустим «отца-арсения»\nон и начнет имяречить.\nНо не так чтобы ерничает,\nи без полной деконструкции дискурса,\nа просто договаривает за автора\nдо самого что ни на есть дна.\nЭто у него по материнской линии по бабке началось,\nи дальше, почти что до пророка Изикииля,\nпотому что национальность, сами-понимаете-какая.\nНа почве этого он стакнулся во время трипа\nс шаманом Саней Габышевым, который, как известно,\nкурит сейчас мох над гнездом кукушки.\n— Скажи и поведай русскому народу, — сказал ему Шаров,\nкоторый теперь выражал смысл исключительно паузами\nи произносил каждое слово как будто первый раз в жизни, —\nчто он и мать и мачеха,\nмистер Джекил, а также доктор Хайд,\nи что с одной стороны он вроде бы понемногу везде,\nа с другой стороны нигде,\nчто было бы почти божественно,\nесли б не было так говняно.\nПоэтому слышит русский народ одно только молчание.\nДа ты и сам знаешь, Саня, что с ним надо сделать,\nпотому что вошел в силу\nи словил почти что Черное Буратино.\n— Мин ыарыйдым, — отвечал Габышев, — вообще не вопрос,\nно с условием, что каждый трудодень зачтется мне\nпо тарифной сетке, как у Саваофа при сотворении мира.\n— Заметано, — ответил ему Володя Шаров, — потому что я как раз туда.\nИ затворился Габышев в своей якутской психиатрии,\nи сказал в день первый «Шесть» —\nв день второй «Пять» —\nв день третий «Четыре» —\nв день четвертый «Три» —\nв день пятый «Два» —\nв день шестой «Один» —\nИ добавил тотчас «Поехали!»',
#  'Author': 'Стас Серебряков',
#  'Before or after': 'After',
#  'Source': 'ROAR V2',
#  'Date posted': 'None',
#  'UniqueIndex': 10,
#  'cleanedText': 'Писатель Владимир Шаров был типичным провокатором.\nДадут ему понюхать духовную книжку, допустим «отца-арсения»\nон и начнет имяречить.\nНо не так чтобы ерничает,\nи без полной деконструкции дискурса,\nа просто договаривает за автора\nдо самого что ни на есть дна.\nЭто у него по материнской линии по бабке началось,\nи дальше, почти что до пророка Изикииля,\nпотому что национальность, сами-понимаете-какая.\nНа почве этого он стакнулся во время трипа\nс шаманом Саней Габышевым, который, как известно,\nкурит сейчас мох над гнездом кукушки.\n— Скажи и поведай русскому народу, — сказал ему Шаров,\nкоторый теперь выражал смысл исключительно паузами\nи произносил каждое слово как будто первый раз в жизни, —\nчто он и мать и мачеха,\nмистер Джекил, а также доктор Хайд,\nи что с одной стороны он вроде бы понемногу везде,\nа с другой стороны нигде,\nчто было бы почти божественно,\nесли б не было так говняно.\nПоэтому слышит русский народ одно только молчание.\nДа ты и сам знаешь, Саня, что с ним надо сделать,\nпотому что вошел в силу\nи словил почти что Черное Буратино.\n— Мин ыарыйдым, — отвечал Габышев, — вообще не вопрос,\nно с условием, что каждый трудодень зачтется мне\nпо тарифной сетке, как у Саваофа при сотворении мира.\n— Заметано, — ответил ему Володя Шаров, — потому что я как раз туда.\nИ затворился Габышев в своей якутской психиатрии,\nи сказал в день первый «Шесть» —\nв день второй «Пять» —\nв день третий «Четыре» —\nв день четвертый «Три» —\nв день пятый «Два» —\nв день шестой «Один» —\nИ добавил тотчас «Поехали!»',
#  'doc': Писатель Владимир Шаров был типичным провокатором.
#  Дадут ему понюхать духовную книжку, допустим «отца-арсения»
#  он и начнет имяречить.
#  Но не так чтобы ерничает,
#  и без полной деконструкции дискурса,
#  а просто договаривает за автора
#  до самого что ни на есть дна.
#  Это у него по материнской линии по бабке началось,
#  и дальше, почти что до пророка Изикииля,
#  потому что национальность, сами-понимаете-какая.
#  На почве этого он стакнулся во время трипа
#  с шаманом Саней Габышевым, который, как известно,
#  курит сейчас мох над гнездом кукушки.
#  — Скажи и поведай русскому народу, — сказал ему Шаров,
#  который теперь выражал смысл исключительно паузами
#  и произносил каждое слово как будто первый раз в жизни, —
#  что он и мать и мачеха,
#  мистер Джекил, а также доктор Хайд,
#  и что с одной стороны он вроде бы понемногу везде,
#  а с другой стороны нигде,
#  что было бы почти божественно,
#  если б не было так говняно.
#  Поэтому слышит русский народ одно только молчание.
#  Да ты и сам знаешь, Саня, что с ним надо сделать,
#  потому что вошел в силу
#  и словил почти что Черное Буратино.
#  — Мин ыарыйдым, — отвечал Габышев, — вообще не вопрос,
#  но с условием, что каждый трудодень зачтется мне
#  по тарифной сетке, как у Саваофа при сотворении мира.
#  — Заметано, — ответил ему Володя Шаров, — потому что я как раз туда.
#  И затворился Габышев в своей якутской психиатрии,
#  и сказал в день первый «Шесть» —
#  в день второй «Пять» —
#  в день третий «Четыре» —
#  в день четвертый «Три» —
#  в день пятый «Два» —
#  в день шестой «Один» —
#  И добавил тотчас «Поехали!»}

# %% [markdown]
# ### Over individual lemmas

# %%
# %%time
infodict = dict()
infodict['Russian'] = dict()

wordlsts = dict()
poemct = dict()
wordct = dict()
lemmas = dict()
lemmas['Russian'] = set()

for lang in infodict:
    poemct[lang] = dict()
    wordct[lang] = dict()
    for period in ['Before','After']:
        poemct[lang][period]=0
        wordct[lang][period] = 0
        infodict[lang][period] = dict()

random.shuffle(records)
for rec in tqdm(records):
    lang = 'Russian'
    period = rec['Before or after']
    if pd.isna(period):
        period = 'After'
    poemct[lang][period] += 1
    doc = rec['doc']
    lemmaAdded = []
    
    if wordct[lang][period] >= 260000:
        continue
    
    for token in doc:
        wordct[lang][period] += 1

        if token.text.isalpha() and token.text not in rustops and token.text not in ukstops:
            lemma = token.lemma_.lower()
            
            lemmas[lang].add(lemma)
            for p in ['Before', 'After']:
                if lemma not in infodict[lang][p]:
                    infodict[lang][p][lemma] = dict()
                    infodict[lang][p][lemma]['count'] = 0
                    infodict[lang][p][lemma]['examples'] = []
            if lemma in lemmaAdded:
                continue
            else:
                infodict[lang][period][lemma]['count'] += 1
                infodict[lang][period][lemma]['examples'].append({
                    'lineText' : doc.text,
                    'rec' : rec
                })
                lemmaAdded.append(lemma)
# Out:
# 100%|██████████| 3289/3289 [00:39<00:00, 82.97it/s]

# %%
lemma = random.choice(list(lemmas['Russian']))

GoogleTranslator(source='ru', target='en').translate(lemma)
# Out:
# 'push out'

# %%
lemma
# Out:
# 'вскарабкаться'

# %% [markdown]
# ### now adding translated labels

# %%
# %%time
freqdatalist = []
allxvals = set()
allyvals = set()
yvals4SD = []
lang = 'Russian'

validlemmas = []
for lemma in lemmas[lang]:
    s_1 = infodict[lang]['Before'][lemma]['count']
    s_2 = infodict[lang]['After'][lemma]['count']

    if s_1 != 0 and s_2 != 0 and s_1 + s_2 >= 10:
        validlemmas.append(lemma)

for lemma in tqdm(validlemmas):
        
    s_1 = infodict[lang]['Before'][lemma]['count']
    s_2 = infodict[lang]['After'][lemma]['count']

    if s_1*s_2!= 0 and s_1 + s_2 >= 0:

        sx_ylog = ((math.log(s_1,2)+math.log(s_2,2))/2, math.log(s_2,2) - math.log(s_1,2))
        # sx_yreg = ((s_1+s_2)/2, s_2 - s_1)

        sx_y = sx_ylog
        try:
            translatedLabel = GoogleTranslator(source='ru', target='en').translate(lemma) 
        except:
            try:
                time.sleep(3)
                translatedLabel = GoogleTranslator(source='ru', target='en').translate(lemma)
            except:
                print('problem translating',lemma)
                translatedLabel = lemma
        
        freqdatalist.append({
            'label' : lemma,
            'translatedLabel' : translatedLabel,
            'lemma' : lemma,
            's_x' : sx_y[0],
            's_y' : sx_y[1],
            'before' : s_1,
            'after' : s_2,
        })

        allxvals.add(sx_y[0])
        allyvals.add(sx_y[1])
        yvals4SD.append(sx_y[1])
# Out:
# 100%|██████████| 3510/3510 [14:11<00:00,  4.12it/s]
# CPU times: user 49.8 s, sys: 3 s, total: 52.8 s
# Wall time: 14min 11s

# %% [markdown]
# #### Shake up the data

# %%
# shake up the data
for f in freqdatalist:
    f['s_x'] = f['s_x'] + [-1,1][random.randrange(2)]*random.random()/2
    f['s_y'] = f['s_y'] + [-1,1][random.randrange(2)]*random.random()/2

# %%
pwd
# Out:
# '/Users/paigelee/Desktop/fall2022/thesis/thesis-code/meandiff'

# %%
with open(f'lemmas_shakenLogData1-9.json', 'w', encoding='utf-8') as f:
    json.dump(freqdatalist, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Over SynSets

# %% [markdown]
# #### Download RUWordNet

# %%
pip install ruwordnet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ruwordnet
#   Downloading ruwordnet-0.0.5.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.8/dist-packages (from ruwordnet) (1.4.45)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from sqlalchemy->ruwordnet) (2.0.1)
# Building wheels for collected packages: ruwordnet
#   Building wheel for ruwordnet (setup.py) ... done
#   Created wheel for ruwordnet: filename=ruwordnet-0.0.5-py3-none-any.whl size=12645 sha256=d360233a64b4d7eba29ae4076579e29c3abbb184ac1e75e59788ca12dacf41cd
#   Stored in directory: /root/.cache/pip/wheels/1a/8f/87/368fccb66c06c5ce100b0985a7d0727fc1f2b97d24b6474c69
# Successfully built ruwordnet
# Installing collected packages: ruwordnet
# Successfully installed ruwordnet-0.0.5

# %%
# !ruwordnet download
# Out:
# downloading a ruwordnet model from https://github.com/avidale/python-ruwordnet/releases/download/0.0.4/ruwordnet-2021.db

# %%
from ruwordnet import RuWordNet
wn = RuWordNet()

# %%
# test out synsets
for sense in wn.get_senses('небо'):
    print(sense.synset)
print()
for sense in wn.get_senses('небеса'):
    print(sense.synset)
# hypernyms
wn.get_senses('тело')[0].synset.hypernyms
# and hyponyms
for hyps in wn.get_senses('тело')[0].synset.hypernyms:
    for hypo in hyps.hyponyms:
        print(hypo)
# Out:
# Synset(id="111119-N", title="НЕБО ВО РТУ")
# Synset(id="112832-N", title="НЕБО, НЕБЕСНЫЙ СВОД")
#
# Synset(id="112832-N", title="НЕБО, НЕБЕСНЫЙ СВОД")
# Synset(id="107716-N", title="СТОПА НОГИ")
# Synset(id="112433-N", title="ПРОМЕЖНОСТЬ")
# Synset(id="108125-N", title="ШЕЯ (ЧАСТЬ ТЕЛА)")
# Synset(id="113348-N", title="ЩУПАЛЬЦЕ")
# Synset(id="107718-N", title="ГОЛЕНЬ")
# Synset(id="112889-N", title="ЖИВОТ (ЧАСТЬ ТЕЛА)")
# Synset(id="107724-N", title="БЕДРО НОГИ")
# Synset(id="113650-N", title="КРЕСТЕЦ")
# Synset(id="109289-N", title="СПИНА (ЧАСТЬ ТУЛОВИЩА)")
# Synset(id="107732-N", title="ГОЛОВА (ЧАСТЬ ТЕЛА)")
# Synset(id="109613-N", title="ВЕКО")
# Synset(id="112885-N", title="ХВОСТ ЖИВОТНОГО")
# Synset(id="107068-N", title="ТУЛОВИЩЕ")
# Synset(id="118107-N", title="КОНЕЧНОСТЬ (ОРГАН ДВИЖЕНИЯ)")

# %% [markdown]
# #### Run calc

# %%
# %%time
infodict = dict()
infodict['Russian'] = dict()

wordlsts = dict()
poemct = dict()
wordct = dict()
synsets = set()
synsetTokens = dict()

for lang in infodict:
    poemct[lang] = dict()
    wordct[lang] = dict()
    for period in ['Before','After']:
        poemct[lang][period]=0
        wordct[lang][period] = 0
        infodict[lang][period] = dict()

random.shuffle(records)

for rec in tqdm(records):
    lang = 'Russian'
    period = rec['Before or after']
    poemct[lang][period] += 1
    doc = rec['doc']
    synsetAdded = []
    
    if wordct[lang][period] >= 260000:
        continue
    
    # for sent in doc.sentences:
    #     for token in sent.words:
    for token in doc:
        wordct[lang][period] += 1

        if token.text.isalpha() and token.text not in rustops and token.text not in ukstops:
            lemma = token.lemma_.lower()
            for sense in wn.get_senses(lemma):

                lemmaSynset = sense.synset
                synsets.add(lemmaSynset)
                synsetTokens.setdefault(lemmaSynset, dict())
                synsetTokens[lemmaSynset].setdefault(lemma, 0)
                synsetTokens[lemmaSynset][lemma]+=1

                for p in ['Before', 'After']:
                    if lemmaSynset not in infodict[lang][p]:
                        infodict[lang][p][lemmaSynset] = dict()
                        infodict[lang][p][lemmaSynset]['count'] = 0
                        infodict[lang][p][lemmaSynset]['examples'] = []
                if lemmaSynset in synsetAdded:
                    continue
                else:
                    infodict[lang][period][lemmaSynset]['count'] += 1
                    infodict[lang][period][lemmaSynset]['examples'].append({
                        'lemma' : lemma,
                        'token' : token.text,
                        'lineText' : doc.text,
                        'rec' : rec
                    })
                    synsetAdded.append(lemmaSynset)
        
freqdatalist = []
allxvals = set()
allyvals = set()
yvals4SD = []
lang = 'Russian'

validsynsets = []
for synset in synsets:
    s_1 = infodict[lang]['Before'][synset]['count']
    s_2 = infodict[lang]['After'][synset]['count']

    if s_1 != 0 and s_2 != 0 and s_1 + s_2 >= 10:
        validsynsets.append(synset)

titleAddedAlready = set()
lemma2synset = dict()
for s, synset in enumerate(validsynsets):
    if s % 250 == 0:
        print(f'{s}/{len(validsynsets)} synsets parsed.')
        
    # check if title already added
    title = synset.title
    # change synset label to lemma label if only one lemma mentioned
    if len(synsetTokens[synset]) == 1:
        title = list(synsetTokens[synset].keys())[0]
        
    # if title already added, skip entry, else continue
    if title in titleAddedAlready:
        print('OLD:',title, synset.title)
        print('NEW:',title, lemma2synset[title])
        continue
    else:
        lemma2synset[title] = synset.title
        titleAddedAlready.add(title)
    
    s_1 = infodict[lang]['Before'][synset]['count']
    s_2 = infodict[lang]['After'][synset]['count']
    
    sx_ylog = ((math.log(s_1,2)+math.log(s_2,2))/2, math.log(s_2,2) - math.log(s_1,2))
    # sx_yreg = ((s_1+s_2)/2, s_2 - s_1)
    sx_y = sx_ylog

    try:
        translatedLabel = GoogleTranslator(source='ru', target='en').translate(title)
    except:
        try:
            time.sleep(3)
            translatedLabel = GoogleTranslator(source='ru', target='en').translate(title)
        except:
            print('problem translating',title)
            translatedLabel = title

    freqdatalist.append({
        'label' : title,
        'translatedLabel' : translatedLabel,
        'synsetTitle' : title,
        'synsetID' : synset.id,
        'synsetTokens' : synsetTokens[synset],
        's_x' : sx_y[0],
        's_y' : sx_y[1],
        'before' : s_1,
        'after' : s_2,
    })

    allxvals.add(sx_y[0])
    allyvals.add(sx_y[1])
    yvals4SD.append(sx_y[1])
# Out:
# 100%|██████████| 3289/3289 [03:17<00:00, 16.62it/s]
# 0/5877 synsets parsed.
# OLD: читатель ЧИТАТЕЛЬ
# NEW: читатель ЧИТАТЕЛЬ БИБЛИОТЕКИ
# OLD: стекло СТЕКЛО
# NEW: стекло СТЕКЛЯННОЕ ИЗДЕЛИЕ
# OLD: основа ОСНОВЫ (ОСНОВНЫЕ ПОЛОЖЕНИЯ)
# NEW: основа ГРАММАТИЧЕСКАЯ ОСНОВА
# OLD: бабочка ГАЛСТУК-БАБОЧКА
# NEW: бабочка БАБОЧКА
# OLD: волна ВОЛНА (КОЛЕБАТЕЛЬНОЕ ДВИЖЕНИЕ)
# NEW: волна ВОЛНА НА ВОДЕ
# OLD: слепить СЛЕПИТЬ (СОЕДИНИТЬ ЛИПКОЕ)
# NEW: слепить СЛЕПИТЬ (СКРЕПИТЬ)
# OLD: венец ВЕНЕЦ СРУБА
# NEW: венец КОРОНА МОНАРХА
# OLD: плечо ПЛЕЧО (ЧАСТЬ ТУЛОВИЩА)
# NEW: плечо ПЛЕЧО ОДЕЖДЫ
# OLD: вопрос ВОПРОСИТЕЛЬНЫЙ ЗНАК
# NEW: вопрос ВОПРОС (ОБРАЩЕНИЕ)
# OLD: плечо ПЛЕЧО РЫЧАГА
# NEW: плечо ПЛЕЧО ОДЕЖДЫ
# OLD: слабый СЛАБЫЙ ПО СИЛЕ, МОЩНОСТИ
# NEW: слабый СЛАБЫЙ, НЕТУГОЙ
# 250/5877 synsets parsed.
# OLD: ядерный ЯДЕРНОЕ ОРУЖИЕ
# NEW: ядерный АТОМНОЕ ОБОРУДОВАНИЕ
# OLD: ткань ТКАНЬ ОРГАНИЗМА
# NEW: ткань ТЕКСТИЛЬНАЯ ТКАНЬ
# OLD: ангел АНГЕЛ (СЛУЖИТЕЛЬ БОГА)
# NEW: ангел АНГЕЛ (ЧЕЛОВЕК ПО ХАРАКТЕРУ)
# OLD: ПТИЦА ПТИЦА
# NEW: ПТИЦА ПТИЦА
# OLD: яйцо ЯЙЦО НАСЕКОМОГО
# NEW: яйцо ЯЙЦО (ПРЕДМЕТ)
# OLD: победа ПОБЕДА В ВОЙНЕ
# NEW: победа ПОБЕДА В СОРЕВНОВАНИИ
# OLD: взрослый СОВЕРШЕННОЛЕТНИЙ, ВЗРОСЛЫЙ ЧЕЛОВЕК
# NEW: взрослый ВЗРОСЛЫЙ ПО ВОЗРАСТУ
# OLD: сезон КЛИМАТИЧЕСКИЙ СЕЗОН
# NEW: сезон СЕЗОН РАБОТ
# OLD: скользкий СКОЛЬЗКИЙ (ГЛАДКИЙ)
# NEW: скользкий ДВУСМЫСЛЕННЫЙ (НЕПРИЛИЧНЫЙ)
# OLD: состав СОСТОЯТЬ, ИМЕТЬ В СОСТАВЕ
# NEW: состав СОСТАВ (ПРОДУКТ СОЕДИНЕНИЯ)
# OLD: ракета РАКЕТА
# NEW: ракета ПИРОТЕХНИЧЕСКАЯ РАКЕТА
# OLD: ПАДАТЬ, РЕЗКО ПОНИЖАТЬСЯ ПАДАТЬ, РЕЗКО ПОНИЖАТЬСЯ
# NEW: ПАДАТЬ, РЕЗКО ПОНИЖАТЬСЯ ПАДАТЬ, РЕЗКО ПОНИЖАТЬСЯ
# OLD: президент ПРЕЗИДЕНТ ОРГАНИЗАЦИИ
# NEW: президент ПРЕЗИДЕНТ ГОСУДАРСТВА
# OLD: перевод ПЕРЕВОД НА ДРУГОЙ ЯЗЫК
# NEW: перевод ПЕРЕХОД НА ДРУГУЮ ДОЛЖНОСТЬ, РАБОТУ
# OLD: перевод ПЕРЕВОД НА СЛЕДУЮЩИЙ КУРС, В СЛЕДУЮЩИЙ КЛАСС
# NEW: перевод ПЕРЕХОД НА ДРУГУЮ ДОЛЖНОСТЬ, РАБОТУ
# OLD: слабый СЛАБЫЙ ПО КАЧЕСТВУ
# NEW: слабый СЛАБЫЙ, НЕТУГОЙ
# OLD: перевод ПЕРЕВЕСТИ В ДРУГОЕ МЕСТО
# NEW: перевод ПЕРЕХОД НА ДРУГУЮ ДОЛЖНОСТЬ, РАБОТУ
# OLD: переход ПЕРЕЙТИ НА ДРУГУЮ СТОРОНУ
# NEW: переход ПЕРЕЙТИ (СМЕНИТЬ РОД ДЕЯТЕЛЬНОСТИ, ПРОФЕССИЮ)
# OLD: перевод ПЕРЕВЕСТИ (ПОСТАВИТЬ В ДРУГИЕ УСЛОВИЯ)
# NEW: перевод ПЕРЕХОД НА ДРУГУЮ ДОЛЖНОСТЬ, РАБОТУ
# OLD: тарелка ПАРАБОЛИЧЕСКАЯ АНТЕННА
# NEW: тарелка МУЗЫКАЛЬНАЯ ТАРЕЛКА
# OLD: перевод ПЕРЕВОД, ТЕКСТ ПЕРЕВОДА
# NEW: перевод ПЕРЕХОД НА ДРУГУЮ ДОЛЖНОСТЬ, РАБОТУ
# OLD: корабль БОЛЬШОЙ КОРАБЛЬ
# NEW: корабль ПИЛОТИРУЕМЫЙ ЛЕТАТЕЛЬНЫЙ АППАРАТ
# OLD: план ПЛАН (ЧЕРТЕЖ)
# NEW: план ПЛАН ИЗЛОЖЕНИЯ
# 500/5877 synsets parsed.
# OLD: падение НРАВСТВЕННОЕ ПАДЕНИЕ
# NEW: падение ПАДАТЬ (ДВИГАТЬСЯ ВНИЗ)
# OLD: крыло КРЫЛО ЛЕТАТЕЛЬНОГО АППАРАТА
# NEW: крыло КРЫЛО КОЛЕСА
# OLD: северный СЕВЕРНАЯ МЕСТНОСТЬ
# NEW: северный СЕВЕР
# OLD: ядерный ЯДРО (СЕРДЦЕВИНА)
# NEW: ядерный АТОМНОЕ ОБОРУДОВАНИЕ
# OLD: глубокий ГЛУБОКИЙ, БОЛЬШОЙ ПО ГЛУБИНЕ
# NEW: глубокий ГЛУБОКИЙ (СИЛЬНЫЙ)
# OLD: точка ТОЧКА (ЗНАК ПРЕПИНАНИЯ)
# NEW: точка ТОЧИТЬ, ОТТАЧИВАТЬ
# OLD: тень ТЕНЬ НА ИЗОБРАЖЕНИИ
# NEW: тень ТЕНИ ДЛЯ ВЕК
# OLD: тень ТЕНЬ, ТЕНИСТОЕ МЕСТО
# NEW: тень ТЕНИ ДЛЯ ВЕК
# OLD: ржавый РЖАВЫЙ (КРАСНО-БУРЫЙ)
# NEW: ржавый РЖАВЧИНА
# OLD: тень ТЕНЕВАЯ ЭКОНОМИКА
# NEW: тень ТЕНИ ДЛЯ ВЕК
# OLD: слизь СЛИЗЬ, СЛИЗИСТЫЙ НАЛЕТ
# NEW: слизь СЛИЗЬ (ВЫДЕЛЕНИЯ)
# OLD: выход ВЫЙТИ (ПОКИНУТЬ МЕСТО)
# NEW: выход ВЫЙТИ (ПОКАЗАТЬСЯ, ПОЯВИТЬСЯ)
# OLD: выход ВЫЙТИ ИЗ СОСТАВА
# NEW: выход ВЫЙТИ (ПОКАЗАТЬСЯ, ПОЯВИТЬСЯ)
# OLD: завод ЗАВОДНОЙ МЕХАНИЗМ
# NEW: завод ЗАВЕСТИ МЕХАНИЗМ, УСТРОЙСТВО
# OLD: балкон БАЛКОН ЗДАНИЯ
# NEW: балкон БАЛКОН ЗРИТЕЛЬНОГО ЗАЛА
# OLD: поход ВОЕННЫЙ ПОХОД
# NEW: поход СПОРТИВНЫЙ ПОХОД
# OLD: глубина ГЛУБИНА (РАССТОЯНИЕ)
# NEW: глубина ГЛУБОКИЙ (СИЛЬНЫЙ)
# OLD: прозрачный ПРОЗРАЧНЫЙ НА ВИД
# NEW: прозрачный ПРОЗРАЧНЫЙ ДЛЯ ПОНИМАНИЯ
# OLD: тяжесть ТЯЖЕЛЫЙ (СУРОВЫЙ)
# NEW: тяжесть ТЯЖЕЛЫЙ (ОПАСНЫЙ)
# OLD: глубина ГЛУБИНА, ОСНОВАТЕЛЬНОСТЬ
# NEW: глубина ГЛУБОКИЙ (СИЛЬНЫЙ)
# OLD: завод ЗАВОД
# NEW: завод ЗАВЕСТИ МЕХАНИЗМ, УСТРОЙСТВО
# OLD: венец ВЕНЧАНИЕ (ЦЕРКОВНЫЙ ОБРЯД)
# NEW: венец КОРОНА МОНАРХА
# OLD: водиться ВОДИТЬСЯ (ИМЕТЬСЯ, БЫВАТЬ)
# NEW: водиться ВОДИТЬСЯ (ОБИТАТЬ)
# OLD: перевод ПЕРЕВЕСТИ В ДРУГИЕ ЗНАКИ, ВЕЛИЧИНЫ
# NEW: перевод ПЕРЕХОД НА ДРУГУЮ ДОЛЖНОСТЬ, РАБОТУ
# 750/5877 synsets parsed.
# OLD: неделя НЕДЕЛЯ
# NEW: неделя НЕДЕЛЯ (МЕРОПРИЯТИЕ)
# OLD: слух МУЗЫКАЛЬНЫЙ СЛУХ
# NEW: слух СЛУХ (ВНЕШНЕЕ ЧУВСТВО)
# OLD: север РАЙОНЫ КРАЙНЕГО СЕВЕРА
# NEW: север СЕВЕР
# OLD: пункт ПУНКТ (РАЗДЕЛ)
# NEW: пункт ПУНКТ (УЧРЕЖДЕНИЕ ИЛИ ОТДЕЛ)
# OLD: тень ТЕНЬ (ТЕМНОЕ ОТРАЖЕНИЕ)
# NEW: тень ТЕНИ ДЛЯ ВЕК
# OLD: военный ВОЕННОСЛУЖАЩИЙ
# NEW: военный ОБОРОНА ГОСУДАРСТВА
# OLD: миф МИФ МАССОВОГО СОЗНАНИЯ
# NEW: миф МИФ (НАРОДНОЕ СКАЗАНИЕ)
# OLD: полоса ПОЛОСА ЖИЗНИ
# NEW: полоса ПОЛОСА ГАЗЕТЫ
# OLD: строчка МАШИННЫЙ ШОВ
# NEW: строчка МАШИННОЕ ШИТЬЕ
# OLD: секунда УГЛОВАЯ СЕКУНДА
# NEW: секунда СЕКУНДА (МУЗЫКАЛЬНЫЙ ИНТЕРВАЛ)
# OLD: улица УЛИЦА, ОТКРЫТЫЙ ВОЗДУХ
# NEW: улица УЛИЧНАЯ СРЕДА
# OLD: газ ГАЗООБРАЗНОЕ ВЕЩЕСТВО
# NEW: газ ГОРЬКОВСКИЙ АВТОМОБИЛЬНЫЙ ЗАВОД
# OLD: карман КАРМАН (ВЫЕМКА)
# NEW: карман МАТЕРИАЛЬНОЕ ПОЛОЖЕНИЕ
# OLD: ядерный ЯДЕРНАЯ РЕАКЦИЯ
# NEW: ядерный АТОМНОЕ ОБОРУДОВАНИЕ
# OLD: дружба ДРУЖЕСТВЕННЫЕ СВЯЗИ
# NEW: дружба ДРУЖБА
# OLD: коробка КОРОБКА (ВМЕСТИЛИЩЕ)
# NEW: коробка КОРОБКА ЗДАНИЯ
# OLD: принцип ПРИНЦИП, ОСНОВНОЕ ПОЛОЖЕНИЕ
# NEW: принцип ПРИНЦИП УСТРОЙСТВА
# OLD: поиск ИСКАТЬ (СТАРАТЬСЯ ПОЛУЧИТЬ)
# NEW: поиск ПОИСК
# OLD: урожай БОЛЬШОЙ УРОЖАЙ
# NEW: урожай УРОЖАЙ
# OLD: камера РЕЗИНОВАЯ КАМЕРА
# NEW: камера ТЮРЕМНАЯ КАМЕРА
# OLD: план ПЛАН ИЗОБРАЖЕНИЯ
# NEW: план ПЛАН ИЗЛОЖЕНИЯ
# OLD: спирт ЭТИЛОВЫЙ СПИРТ
# NEW: спирт СПИРТ (ХИМИЧЕСКОЕ СОЕДИНЕНИЕ)
# OLD: трепетать ТРЕПЕТАТЬ ОТ ВОЛНЕНИЯ
# NEW: трепетать ТРЕПЕТАТЬ (КОЛЕБАТЬСЯ, ДРОЖАТЬ)
# OLD: медь МЕДНЫЙ ЦВЕТ
# NEW: медь МЕДЬ
# OLD: медь МЕДНЫЙ ДУХОВОЙ ИНСТРУМЕНТ
# NEW: медь МЕДЬ
# OLD: трасса СПОРТИВНАЯ ТРАССА
# NEW: трасса ТРАССА ПУЛИ, СНАРЯДА
# OLD: проект ПРОЕКТ (ЧЕРТЕЖ, ПЛАН)
# NEW: проект ПРОЕКТ (КОМПЛЕКС ВЗАИМОСВЯЗАННЫХ РАБОТ)
# OLD: проект ПРОЕКТ ДОКУМЕНТА
# NEW: проект ПРОЕКТ (КОМПЛЕКС ВЗАИМОСВЯЗАННЫХ РАБОТ)
# OLD: гость ГОСТЬ (ТОТ, КТО ПОСЕЩАЕТ, НАВЕЩАЕТ)
# NEW: гость ГОСТЬ (ПОСТОРОННЕЕ ЛИЦО)
# OLD: полный ПОЛНЫЙ (ЗАНЯТЫЙ ЦЕЛИКОМ)
# NEW: полный ПОЛНЫЙ (ВПОЛНЕ ЗАКОНЧЕННЫЙ)
# OLD: марш ЛЕСТНИЧНЫЙ МАРШ
# NEW: марш МАРШ (КОМАНДА)
# OLD: марш МАРШ (МУЗЫКАЛЬНОЕ ПРОИЗВЕДЕНИЕ)
# NEW: марш МАРШ (КОМАНДА)
# OLD: свинцовый СВИНЕЦ
# NEW: свинцовый СВИНЦОВЫЙ (ТЯЖЕЛЫЙ)
# OLD: свинцовый СВИНЦОВЫЙ ЦВЕТ
# NEW: свинцовый СВИНЦОВЫЙ (ТЯЖЕЛЫЙ)
# 1000/5877 synsets parsed.
# OLD: частный ЧАСТНАЯ СОБСТВЕННОСТЬ
# NEW: частный ЧАСТНЫЙ, ПРИВАТНЫЙ
# OLD: сиреневый СИРЕНЬ
# NEW: сиреневый СИРЕНЕВЫЙ ЦВЕТ
# OLD: пример РЕАЛЬНЫЙ ПРИМЕР
# NEW: пример МАТЕМАТИЧЕСКИЙ ПРИМЕР
# OLD: трасса ТРАССА НА КАРТЕ
# NEW: трасса ТРАССА ПУЛИ, СНАРЯДА
# OLD: карта КАРТА (БЛАНК)
# NEW: карта КАРТОЧНАЯ ИГРА
# OLD: карта ИГРАЛЬНАЯ КАРТА
# NEW: карта КАРТОЧНАЯ ИГРА
# OLD: карта КАРТА (ЧЕРТЕЖ)
# NEW: карта КАРТОЧНАЯ ИГРА
# OLD: белок БЕЛОК (ОРГАНИЧЕСКОЕ СОЕДИНЕНИЕ)
# NEW: белок БЕЛОК ЯЙЦА
# OLD: цель ЦЕЛЬ ДЛЯ ПОПАДАНИЯ
# NEW: цель ЦЕЛЬ, ПРЕДМЕТ СТРЕМЛЕНИЯ
# OLD: попадать ПОПАДАТЬ (УПАСТЬ ОДИН ЗА ДРУГИМ)
# NEW: попадать ПОПАДАТЬ (УПАСТЬ В БОЛЬШОМ КОЛИЧЕСТВЕ)
# OLD: задний ЗАДНЕЕ НАПРАВЛЕНИЕ
# NEW: задний РАСПОЛОЖЕНИЕ СЗАДИ
# OLD: основа ОСНОВНАЯ НИТЬ
# NEW: основа ГРАММАТИЧЕСКАЯ ОСНОВА
# OLD: фон ЦВЕТ ФОНА
# NEW: фон ЗАДНИЙ ПЛАН ИЗОБРАЖЕНИЯ
# OLD: портрет ПОРТРЕТ (ПРОИЗВЕДЕНИЕ ИСКУССТВА)
# NEW: портрет ПОРТРЕТ (ХАРАКТЕРИСТИКА)
# OLD: колокольчик КОЛОКОЛЬЧИК (ТРАВЯНИСТОЕ РАСТЕНИЕ)
# NEW: колокольчик КОЛОКОЛЬЧИК (ЗВОНОК)
# OLD: группа ГРУППА, ОБЪЕДИНЕННАЯ ПО ОБЩЕМУ ПРИЗНАКУ
# NEW: группа ГРУППА ЛЮДЕЙ
# OLD: воля ВОЛЯ (СТРЕМЛЕНИЕ К ОСУЩЕСТВЛЕНИЮ)
# NEW: воля СИЛА ВОЛИ
# OLD: аппарат СИСТЕМА ОРГАНОВ ОРГАНИЗМА
# NEW: аппарат АППАРАТ ОРГАНИЗАЦИИ
# OLD: пустота БЕССОДЕРЖАТЕЛЬНЫЙ
# NEW: пустота ОПУСТОШЕННОСТЬ
# OLD: стрелка СТРЕЛКА РЕК
# NEW: стрелка СТРЕЛКА СПУЩЕННЫХ ПЕТЕЛЬ
# OLD: роман РОМАН (ЛЮБОВНЫЕ ОТНОШЕНИЯ)
# NEW: роман РОМАН (ПОВЕСТВОВАТЕЛЬНОЕ ПРОИЗВЕДЕНИЕ)
# OLD: стрелка СТРЕЛКА НА БРЮКАХ
# NEW: стрелка СТРЕЛКА СПУЩЕННЫХ ПЕТЕЛЬ
# OLD: стрелка ЖЕЛЕЗНОДОРОЖНАЯ СТРЕЛКА
# NEW: стрелка СТРЕЛКА СПУЩЕННЫХ ПЕТЕЛЬ
# OLD: ухо УХО ШАПКИ
# NEW: ухо УШНАЯ РАКОВИНА
# OLD: огненный ОГНЕННЫЙ ЦВЕТ
# NEW: огненный ОБЖИГАЮЩЕ ГОРЯЧИЙ
# OLD: цветочный ЦВЕТКОВОЕ РАСТЕНИЕ
# NEW: цветочный ЦВЕТОК (ЧАСТЬ РАСТЕНИЯ)
# OLD: провал ПРОВАЛ, МЕСТО ПРОВАЛА
# NEW: провал ПРОВАЛИТЬСЯ ОТ ТЯЖЕСТИ, ВЕТХОСТИ
# OLD: марш УЛИЧНОЕ ШЕСТВИЕ
# NEW: марш МАРШ (КОМАНДА)
# OLD: книга КНИГА (ЧАСТЬ РОМАНА)
# NEW: книга КНИГА ДЛЯ ЗАПИСИ
# OLD: очередь ОЧЕРЕДЬ СТРОИТЕЛЬСТВА
# NEW: очередь ОЧЕРЕДЬ, ОЧЕРЕДНОСТЬ
# OLD: взвод ВЗВОД (ПОДРАЗДЕЛЕНИЕ)
# NEW: взвод ВЗВОД КУРКА
# OLD: тяжесть ТЯЖЕСТЬ (БОЛЕЗНЕННОЕ ЧУВСТВО)
# NEW: тяжесть ТЯЖЕЛЫЙ (ОПАСНЫЙ)
# OLD: очередь ЖИВАЯ ОЧЕРЕДЬ
# NEW: очередь ОЧЕРЕДЬ, ОЧЕРЕДНОСТЬ
# OLD: мишень МИШЕНЬ ДЕЙСТВИЯ
# NEW: мишень МИШЕНЬ ДЛЯ СТРЕЛЬБЫ
# OLD: канал КАНАЛ (ПОЛОСТЬ)
# NEW: канал ЛИНИЯ СВЯЗИ
# OLD: дно ДНО УГЛУБЛЕНИЯ
# NEW: дно ДНО ВМЕСТИЛИЩА
# 1250/5877 synsets parsed.
# OLD: история ИСТОРИЯ (ХОД РАЗВИТИЯ, ДВИЖЕНИЯ)
# NEW: история ИСТОРИЧЕСКИЕ НАУКИ
# OLD: соль СОЛЬ (ХИМИЧЕСКОЕ СОЕДИНЕНИЕ)
# NEW: соль ПИЩЕВАЯ СОЛЬ
# OLD: ДАТЬ, ВРУЧИТЬ ДАТЬ, ВРУЧИТЬ
# NEW: ДАТЬ, ВРУЧИТЬ ДАТЬ, ВРУЧИТЬ
# OLD: низкий НИЗКИЙ, МЕНЬШЕ НОРМЫ
# NEW: низкий НИЗКИЙ ПО ЗВУКУ
# OLD: моль МОЛЕВОЙ СПЛАВ
# NEW: моль МОЛЬ (НАСЕКОМОЕ)
# OLD: телесный ТЕЛО ЧЕЛОВЕКА, ЖИВОТНОГО
# NEW: телесный ТЕЛЕСНЫЙ ЦВЕТ
# OLD: диск ЛАЗЕРНЫЙ ДИСК
# NEW: диск ДИСК (ПРЕДМЕТ)
# OLD: плащ ПЛАЩ-НАКИДКА
# NEW: плащ ПЛАЩ-ПАЛЬТО
# OLD: корона МОНАРХИЯ (ГОСУДАРСТВО)
# NEW: корона КОРОНА (УКРАШЕНИЕ)
# OLD: камера ВНУТРЕННЯЯ КАМЕРА УСТРОЙСТВА
# NEW: камера ТЮРЕМНАЯ КАМЕРА
# OLD: огненный СТРАСТЬ (СИЛЬНОЕ ЧУВСТВО)
# NEW: огненный ОБЖИГАЮЩЕ ГОРЯЧИЙ
# OLD: цветочный ЦВЕТОЧНЫЙ УЗОР
# NEW: цветочный ЦВЕТОК (ЧАСТЬ РАСТЕНИЯ)
# OLD: провал ПРОВАЛИТЬСЯ В ОТВЕРСТИЕ, УГЛУБЛЕНИЕ
# NEW: провал ПРОВАЛИТЬСЯ ОТ ТЯЖЕСТИ, ВЕТХОСТИ
# OLD: ПЕРЕЙТИ В ДРУГОЕ СОСТОЯНИЕ, ПОЛОЖЕНИЕ ПЕРЕЙТИ В ДРУГОЕ СОСТОЯНИЕ, ПОЛОЖЕНИЕ
# NEW: ПЕРЕЙТИ В ДРУГОЕ СОСТОЯНИЕ, ПОЛОЖЕНИЕ ПЕРЕЙТИ В ДРУГОЕ СОСТОЯНИЕ, ПОЛОЖЕНИЕ
# OLD: палата БОЛЬНИЧНАЯ ПАЛАТА
# NEW: палата ПАЛАТА ПАРЛАМЕНТА
# OLD: диск ДИСК ДЛЯ МЕТАНИЯ
# NEW: диск ДИСК (ПРЕДМЕТ)
# OLD: звезда ЗВЕЗДА (ЗНАМЕНИТОСТЬ)
# NEW: звезда ЗВЕЗДА (НЕБЕСНОЕ ТЕЛО)
# OLD: сигнал ЭЛЕКТРОМАГНИТНЫЙ СИГНАЛ
# NEW: сигнал СИГНАЛ (УСЛОВНЫЙ ЗНАК)
# OLD: звезда ЗВЕЗДНОСТЬ ГОСТИНИЦЫ
# NEW: звезда ЗВЕЗДА (НЕБЕСНОЕ ТЕЛО)
# OLD: жирный ЖИРНЫЙ, БОГАТЫЙ ЖИРАМИ
# NEW: жирный ЖИРНЫЙ, ГРЯЗНЫЙ ОТ ЖИРА
# OLD: жирный ЖИРНЫЙ (ОЧЕНЬ ТОЛСТЫЙ)
# NEW: жирный ЖИРНЫЙ, ГРЯЗНЫЙ ОТ ЖИРА
# OLD: здоровый ЗДОРОВЫЙ, НЕБОЛЬНОЙ
# NEW: здоровый ЗДОРОВЫЙ, ПОЛЕЗНЫЙ ДЛЯ ЗДОРОВЬЯ
# OLD: юг ЮЖНАЯ МЕСТНОСТЬ
# NEW: юг ЮГ
# OLD: рост РОСТ ЧЕЛОВЕКА, ЖИВОТНОГО
# NEW: рост РАСТИ (СОВЕРШЕНСТВОВАТЬСЯ)
# OLD: кожа КОЖА (НАРУЖНЫЙ ПОКРОВ)
# NEW: кожа КОЖА (МАТЕРИАЛ)
# OLD: очередь АВТОМАТНЫЙ ОГОНЬ
# NEW: очередь ОЧЕРЕДЬ, ОЧЕРЕДНОСТЬ
# OLD: очередь ОЧЕРЕДЬ, МЕСТО В ОЧЕРЕДИ
# NEW: очередь ОЧЕРЕДЬ, ОЧЕРЕДНОСТЬ
# OLD: школа ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА
# NEW: школа ШКОЛА
# 1500/5877 synsets parsed.
# OLD: колодец КОЛОДЕЦ (СКВАЖИНА)
# NEW: колодец КОЛОДЕЦ (ВОДА)
# OLD: канал ВОДНЫЙ КАНАЛ
# NEW: канал ЛИНИЯ СВЯЗИ
# OLD: канал КАНАЛ ВЕЩАНИЯ
# NEW: канал ЛИНИЯ СВЯЗИ
# OLD: райский РАЙСКИЙ (ПРЕКРАСНЫЙ)
# NEW: райский РАЙ НЕБЕСНЫЙ
# OLD: след СЛЕД (ОСТАТОК)
# NEW: след СЛЕД НОГИ
# OLD: лес ЛЕС (МНОЖЕСТВО ЧЕГО-Н. ПОДНЯТОГО)
# NEW: лес ДЕЛОВАЯ ДРЕВЕСИНА
# OLD: холодный ХОЛОДНЫЙ ПО ТЕМПЕРАТУРЕ
# NEW: холодный ХОЛОДНЫЙ ПО ЦВЕТУ
# OLD: снаряд СНАРЯД
# NEW: снаряд СПОРТИВНЫЙ ИНВЕНТАРЬ
# OLD: моль МОЛЬ ВЕЩЕСТВА
# NEW: моль МОЛЬ (НАСЕКОМОЕ)
# OLD: корона КОРОНА НЕБЕСНОГО СВЕТИЛА
# NEW: корона КОРОНА (УКРАШЕНИЕ)
# OLD: пустота ПУСТОЙ, НЕЗАПОЛНЕННЫЙ
# NEW: пустота ОПУСТОШЕННОСТЬ
# OLD: осколок ОСКОЛОК ПРОШЛОГО
# NEW: осколок ОСКОЛОК (ОТКОЛОВШИЙСЯ КУСОК)
# OLD: ЕСТЬ, ПРИНИМАТЬ ПИЩУ ЕСТЬ, ПРИНИМАТЬ ПИЩУ
# NEW: ЕСТЬ, ПРИНИМАТЬ ПИЩУ ЕСТЬ, ПРИНИМАТЬ ПИЩУ
# OLD: газовый ГАЗОВОЕ ТОПЛИВО
# NEW: газовый ГАЗООБРАЗНОЕ ВЕЩЕСТВО
# OLD: ОТВЕТИТЬ, ПОСТУПИТЬ В ОТВЕТ ОТВЕТИТЬ, ПОСТУПИТЬ В ОТВЕТ
# NEW: ОТВЕТИТЬ, ПОСТУПИТЬ В ОТВЕТ ОТВЕТИТЬ, ПОСТУПИТЬ В ОТВЕТ
# OLD: ручка РУЧКА ДЛЯ ПИСЬМА
# NEW: ручка РУКОЯТКА УПРАВЛЕНИЯ
# OLD: след СЛЕД НА ПОВЕРХНОСТИ
# NEW: след СЛЕД НОГИ
# OLD: ДОРОГА (ПУТЬ СООБЩЕНИЯ) ДОРОГА (ПУТЬ СООБЩЕНИЯ)
# NEW: ДОРОГА (ПУТЬ СООБЩЕНИЯ) ДОРОГА (ПУТЬ СООБЩЕНИЯ)
# OLD: круг ТУР СОРЕВНОВАНИЙ
# NEW: круг КРУГ, КРУГЛАЯ ПЛОЩАДКА
# OLD: ручка РУЧКА ДЛЯ ДЕРЖАНИЯ
# NEW: ручка РУКОЯТКА УПРАВЛЕНИЯ
# OLD: культура КУЛЬТУРА (СФЕРА ДЕЯТЕЛЬНОСТИ)
# NEW: культура КУЛЬТУРНОЕ РАСТЕНИЕ
# OLD: вредный ВРЕДНЫЙ
# NEW: вредный ВРЕДНЫЙ ПО ХАРАКТЕРУ
# OLD: случайный СЛУЧАЙНЫЙ (НЕОЖИДАННЫЙ И НЕПРОИЗВОЛЬНЫЙ)
# NEW: случайный СЛУЧАЙНЫЙ, ОТ СЛУЧАЯ К СЛУЧАЮ
# OLD: танк ТАНК
# NEW: танк ТАНК (РЕЗЕРВУАР)
# OLD: сторона СТОРОНА МНОГОУГОЛЬНИКА
# NEW: сторона СТОРОНА (БОКОВАЯ ЧАСТЬ)
# OLD: хлопок ХЛОПЧАТОБУМАЖНАЯ ТКАНЬ
# NEW: хлопок ХЛОПКОВОЕ ВОЛОКНО
# OLD: кукла КУКЛА (ИГРУШКА)
# NEW: кукла ТЕАТРАЛЬНАЯ КУКЛА
# OLD: кора КОРА ГОЛОВНОГО МОЗГА
# NEW: кора ДРЕВЕСНАЯ КОРА
# OLD: ДВИЖЕНИЕ, ПЕРЕМЕЩЕНИЕ ДВИЖЕНИЕ, ПЕРЕМЕЩЕНИЕ
# NEW: ДВИЖЕНИЕ, ПЕРЕМЕЩЕНИЕ ДВИЖЕНИЕ, ПЕРЕМЕЩЕНИЕ
# OLD: пытка ТЕРЗАНИЕ, НРАВСТВЕННОЕ СТРАДАНИЕ
# NEW: пытка ПЫТКА
# OLD: тройка ТРОЙКА ЛОШАДЕЙ
# NEW: тройка ТРОЙКА (ГРУППА)
# OLD: среда ОКРУЖАЮЩАЯ СРЕДА
# NEW: среда СРЕДА (ВЕЩЕСТВО)
# OLD: братский ТОВАРИЩЕСКИЕ ОТНОШЕНИЯ
# NEW: братский БРАТ
# OLD: колонна ДВИЖУЩАЯСЯ КОЛОННА
# NEW: колонна КОЛОННА (СООРУЖЕНИЕ)
# OLD: братский ДРУЖЕСТВЕННЫЕ СВЯЗИ
# NEW: братский БРАТ
# OLD: парк ПАРК (ТРАНСПОРТНОЕ ПРЕДПРИЯТИЕ)
# NEW: парк ПАРК, ПАРКОВАЯ ЗОНА
# OLD: рассеянный РАССЕЯННЫЙ (СЛАБЫЙ, РАЗРЕЖЕННЫЙ)
# NEW: рассеянный РАССЕЯННЫЙ
# OLD: парк ПАРК ТЕХНИЧЕСКИХ СРЕДСТВ
# NEW: парк ПАРК, ПАРКОВАЯ ЗОНА
# 1750/5877 synsets parsed.
# OLD: станция СТАНЦИЯ ТЕХНИЧЕСКОГО ОБСЛУЖИВАНИЯ
# NEW: станция КОСМИЧЕСКАЯ СТАНЦИЯ
# OLD: братский БРАТСК
# NEW: братский БРАТ
# OLD: сила СИЛА (ФИЗИЧЕСКАЯ ВЕЛИЧИНА)
# NEW: сила СИЛА, ЖИЗНЕННАЯ СИЛА
# OLD: печень ПЕЧЕНКА (МЯСО)
# NEW: печень ПЕЧЕНЬ (ОРГАН)
# OLD: фигура ШАХМАТНАЯ ФИГУРА
# NEW: фигура ГЕОМЕТРИЧЕСКАЯ ФИГУРА
# OLD: фигура ФИГУРА (ПОЛОЖЕНИЕ ТЕЛА)
# NEW: фигура ГЕОМЕТРИЧЕСКАЯ ФИГУРА
# OLD: порог ДВЕРНОЙ ПОРОГ
# NEW: порог ПОРОГ, ПОРОГОВОЕ ЗНАЧЕНИЕ
# OLD: отдельный ОТДЕЛЬНЫЙ, ОБОСОБЛЕННЫЙ
# NEW: отдельный ЕДИНИЧНЫЙ, ОТДЕЛЬНЫЙ
# OLD: порог ПОРОГ РЕКИ
# NEW: порог ПОРОГ, ПОРОГОВОЕ ЗНАЧЕНИЕ
# OLD: ЭТНИЧЕСКИЕ НАРОДЫ ЭТНИЧЕСКИЕ НАРОДЫ
# NEW: ЭТНИЧЕСКИЕ НАРОДЫ ЭТНИЧЕСКИЕ НАРОДЫ
# OLD: ПРИЦЕЛИВАНИЕ (НАВЕДЕНИЕ НА ЦЕЛЬ) ПРИЦЕЛИВАНИЕ (НАВЕДЕНИЕ НА ЦЕЛЬ)
# NEW: ПРИЦЕЛИВАНИЕ (НАВЕДЕНИЕ НА ЦЕЛЬ) ПРИЦЕЛИВАНИЕ (НАВЕДЕНИЕ НА ЦЕЛЬ)
# OLD: народный НАЦИОНАЛЬНЫЙ ХАРАКТЕР
# NEW: народный НАСЕЛЕНИЕ ГОСУДАРСТВА
# OLD: приговор ПРИГОВОР (ОСУДИТЕЛЬНАЯ ОЦЕНКА)
# NEW: приговор ПРИГОВОР СУДА
# OLD: кадр КАДР ПЛЕНКИ
# NEW: кадр КАДР ФИЛЬМА
# OLD: газ ГАЗОВОЕ ТОПЛИВО
# NEW: газ ГОРЬКОВСКИЙ АВТОМОБИЛЬНЫЙ ЗАВОД
# OLD: потный ПОТ (ВЫДЕЛЕНИЕ)
# NEW: потный ПОТНЫЙ, МОКРЫЙ ОТ ПОТА
# OLD: зуб ЗУБЕЦ (ОСТРЫЙ ВЫСТУП)
# NEW: зуб ЗУБ (ОРГАН ДЛЯ ЖЕВАНИЯ)
# OLD: оборона ОБОРОНА ГОСУДАРСТВА
# NEW: оборона ОБОРОНЯТЬ ОТ НАПАДЕНИЯ
# OLD: кора ЗЕМНАЯ КОРА
# NEW: кора ДРЕВЕСНАЯ КОРА
# OLD: король КОРОЛЬ (ИГРАЛЬНАЯ КАРТА)
# NEW: король КОРОЛЬ (МОНОПОЛИСТ)
# OLD: воевать ВОЕННЫЕ ДЕЙСТВИЯ
# NEW: воевать ВОЕВАТЬ (БОРОТЬСЯ)
# OLD: торжество ТОРЖЕСТВО (ПОБЕДА)
# NEW: торжество ТОРЖЕСТВО, ЧУВСТВО ТОРЖЕСТВА
# OLD: грубый ГРУБЫЙ НА ОЩУПЬ
# NEW: грубый ГРУБО ОБРАБОТАННЫЙ
# 2000/5877 synsets parsed.
# OLD: мирный МИРНЫЙ (СПОКОЙНЫЙ, ЧУЖДЫЙ ВОЛНЕНИЙ)
# NEW: мирный МИРОЛЮБИЕ
# OLD: тройка КОСТЮМ-ТРОЙКА
# NEW: тройка ТРОЙКА (ГРУППА)
# OLD: среда СРЕДА (ДЕНЬ НЕДЕЛИ)
# NEW: среда СРЕДА (ВЕЩЕСТВО)
# OLD: мирный МИРНОЕ НАСЕЛЕНИЕ
# NEW: мирный МИРОЛЮБИЕ
# OLD: держаться ПРИДЕРЖИВАТЬСЯ ПРИНЦИПА, ПРАВИЛА
# NEW: держаться ДЕРЖАТЬСЯ (ВЕСТИ СЕБЯ)
# OLD: молочный МОЛОЧНЫЙ ЦВЕТ
# NEW: молочный МОЛОКО МЛЕКОПИТАЮЩИХ
# OLD: смена СМЕНА (РАБОЧЕЕ ВРЕМЯ)
# NEW: смена СМЕНИТЬ (ЗАМЕНИТЬ СОБОЙ)
# OLD: почта ПОЧТОВОЕ ОТПРАВЛЕНИЕ
# NEW: почта ПОЧТОВАЯ СВЯЗЬ
# OLD: центр ЦЕНТР, ЦЕНТРАЛЬНАЯ ТОЧКА
# NEW: центр ЦЕНТР (ОРГАНИЗАЦИЯ)
# OLD: торжество ТОРЖЕСТВО (ПРАЗДНЕСТВО)
# NEW: торжество ТОРЖЕСТВО, ЧУВСТВО ТОРЖЕСТВА
# OLD: висок ВИСОК
# NEW: висок ВОЛОСЫ НА ВИСКАХ
# OLD: род РОД ЖИВОТНЫХ, РАСТЕНИЙ
# NEW: род ГРАММАТИЧЕСКИЙ РОД
# OLD: правый ПРАВАЯ ПОЛИТИЧЕСКАЯ ОРИЕНТАЦИЯ
# NEW: правый РАСПОЛОЖЕНИЕ СПРАВА
# OLD: ВОДА (ЖИДКОСТЬ) ВОДА (ЖИДКОСТЬ)
# NEW: ВОДА (ЖИДКОСТЬ) ВОДА (ЖИДКОСТЬ)
# OLD: номер НОМЕР (ОТДЕЛЬНОЕ ПОМЕЩЕНИЕ)
# NEW: номер НОМЕР ПО ПОРЯДКУ
# OLD: дышать ДЫШАТЬ (ПРОПУСКАТЬ ВОЗДУХ)
# NEW: дышать ДЫШАТЬ (ИСПУСКАТЬ)
# OLD: воздух АТМОСФЕРНЫЙ ВОЗДУХ
# NEW: воздух ВОЗДУШНОЕ ПРОСТРАНСТВО
# OLD: БОГ БОГ
# NEW: БОГ БОГ
# OLD: цифра ЦИФРА (ЗНАК)
# NEW: цифра КОЛИЧЕСТВЕННЫЕ ДАННЫЕ
# OLD: смола СМОЛА ДЕРЕВА
# NEW: смола СИНТЕТИЧЕСКИЕ СМОЛЫ
# OLD: груз ГРУЗ ДЛЯ ПЕРЕВОЗКИ
# NEW: груз ГРУЗ (ТЯЖЕЛЫЙ ПРЕДМЕТ)
# OLD: парить ПАРИТЬ, ДЫШАТЬ ЖАРОМ
# NEW: парить ПАРИТЬ, ПРОПАРИТЬ
# OLD: плавник ПЛАВНИК (ОРГАН)
# NEW: плавник ПЛАВНИК (ОБЛОМКИ)
# OLD: король ШАХМАТНЫЙ КОРОЛЬ
# NEW: король КОРОЛЬ (МОНОПОЛИСТ)
# OLD: карандаш КОСМЕТИЧЕСКИЙ КАРАНДАШ
# NEW: карандаш КАРАНДАШ
# OLD: центр ЦЕНТР, ЦЕНТРАЛЬНАЯ ЧАСТЬ
# NEW: центр ЦЕНТР (ОРГАНИЗАЦИЯ)
# OLD: изгнание ГНАТЬ, ВЫГОНЯТЬ
# NEW: изгнание ИЗГНАНИЕ, ЖИЗНЬ В ИЗГНАНИИ
# OLD: дно СОЦИАЛЬНЫЕ НИЗЫ
# NEW: дно ДНО ВМЕСТИЛИЩА
# OLD: доска ДОСКА ДЛЯ КАТАНИЯ
# NEW: доска ДЕРЕВЯННАЯ ДОСКА
# OLD: минута УГЛОВАЯ МИНУТА
# NEW: минута МИНУТА (ЕДИНИЦА ВРЕМЕНИ)
# OLD: нож НОЖ (ХОЛОДНОЕ ОРУЖИЕ)
# NEW: нож НОЖ (КУХОННАЯ УТВАРЬ)
# OLD: игра ИГРАЛЬНЫЙ КОМПЛЕКТ
# NEW: игра ИГРАТЬ, ОБРАЩАТЬСЯ ЛЕГКОМЫСЛЕННО
# OLD: КАСАТЬСЯ, ДОТРАГИВАТЬСЯ КАСАТЬСЯ, ДОТРАГИВАТЬСЯ
# NEW: КАСАТЬСЯ, ДОТРАГИВАТЬСЯ КАСАТЬСЯ, ДОТРАГИВАТЬСЯ
# OLD: опыт ОПЫТ (СОВОКУПНОСТЬ ЗНАНИЙ И УМЕНИЙ)
# NEW: опыт ОПЫТ (ПОПЫТКА)
# OLD: игра ИГРА (РАЗВЛЕЧЕНИЕ)
# NEW: игра ИГРАТЬ, ОБРАЩАТЬСЯ ЛЕГКОМЫСЛЕННО
# OLD: игра ИГРАТЬ (ПРОЯВЛЯТЬСЯ С ЖИВОСТЬЮ, БЛЕСКОМ)
# NEW: игра ИГРАТЬ, ОБРАЩАТЬСЯ ЛЕГКОМЫСЛЕННО
# 2250/5877 synsets parsed.
# OLD: режим ПОЛИТИЧЕСКИЙ РЕЖИМ
# NEW: режим РЕЖИМ (УСЛОВИЯ ДЕЯТЕЛЬНОСТИ)
# OLD: знак ЗНАК РУКОЙ
# NEW: знак ЗНАК (ПРЕДМЕТ)
# OLD: кошка КОШКИ ДЛЯ ЛАЗАНИЯ
# NEW: кошка КОШАЧЬИ
# OLD: доска КЛАССНАЯ ДОСКА
# NEW: доска ДЕРЕВЯННАЯ ДОСКА
# OLD: ВОЙТИ В СОСТАВ ВОЙТИ В СОСТАВ
# NEW: ВОЙТИ В СОСТАВ ВОЙТИ В СОСТАВ
# OLD: грудь ГРУДНАЯ КЛЕТКА
# NEW: грудь ГРУДЬ (ТУЛОВИЩЕ)
# OLD: подошва ОБУВНАЯ ПОДОШВА
# NEW: подошва РАБОЧАЯ ПОВЕРХНОСТЬ УТЮГА
# OLD: смешной СМЕШНОЙ, СМЕХОТВОРНЫЙ
# NEW: смешной СМЕШНОЙ (ВЫЗЫВАЮЩИЙ СМЕХ)
# OLD: язык ЯЗЫК
# NEW: язык ЯЗЫК (МЯСО)
# OLD: язык ЯЗЫК (ОРГАН ВКУСА)
# NEW: язык ЯЗЫК (МЯСО)
# OLD: номер НОМЕР (ЧАСТЬ ПРЕДСТАВЛЕНИЯ)
# NEW: номер НОМЕР ПО ПОРЯДКУ
# OLD: поворот ПОВОРОТ, МЕСТО ПОВОРОТА
# NEW: поворот ПОВЕРНУТЬ ПРИ ДВИЖЕНИИ
# OLD: поворот ПОВОРОТ В РАЗВИТИИ
# NEW: поворот ПОВЕРНУТЬ ПРИ ДВИЖЕНИИ
# OLD: поворот ПОВЕРНУТЬСЯ (ИЗМЕНИТЬ ПОЛОЖЕНИЕ)
# NEW: поворот ПОВЕРНУТЬ ПРИ ДВИЖЕНИИ
# OLD: поворот ПОВЕРНУТЬ, ИЗМЕНИТЬ ПОЛОЖЕНИЕ
# NEW: поворот ПОВЕРНУТЬ ПРИ ДВИЖЕНИИ
# OLD: ОБНЯТЬ, ЗАКЛЮЧИТЬ В ОБЪЯТИЯ ОБНЯТЬ, ЗАКЛЮЧИТЬ В ОБЪЯТИЯ
# NEW: ОБНЯТЬ, ЗАКЛЮЧИТЬ В ОБЪЯТИЯ ОБНЯТЬ, ЗАКЛЮЧИТЬ В ОБЪЯТИЯ
# OLD: ВЕРНУТЬ (ЗАСТАВИТЬ ИЛИ ДАТЬ ВОЗМОЖНОСТЬ ВЕРНУТЬСЯ) ВЕРНУТЬ (ЗАСТАВИТЬ ИЛИ ДАТЬ ВОЗМОЖНОСТЬ ВЕРНУТЬСЯ)
# NEW: ВЕРНУТЬ (ЗАСТАВИТЬ ИЛИ ДАТЬ ВОЗМОЖНОСТЬ ВЕРНУТЬСЯ) ВЕРНУТЬ (ЗАСТАВИТЬ ИЛИ ДАТЬ ВОЗМОЖНОСТЬ ВЕРНУТЬСЯ)
# OLD: ответственность ОТВЕТСТВЕННОСТЬ ЗА ДЕЙСТВИЯ
# NEW: ответственность ОТВЕТСТВЕННЫЙ (ВАЖНЫЙ, СЕРЬЕЗНЫЙ)
# OLD: ответственность ОТВЕТСТВЕННЫЙ ПО ХАРАКТЕРУ
# NEW: ответственность ОТВЕТСТВЕННЫЙ (ВАЖНЫЙ, СЕРЬЕЗНЫЙ)
# OLD: поле ПОЛЕ СИЛ
# NEW: поле ПОЛЕ (ПЛОЩАДКА)
# OLD: крестный КРЕСТНЫЙ РОДИТЕЛЬ
# NEW: крестный КРЕСТИТЬ, ОСЕНИТЬ КРЕСТОМ
# OLD: картина КАРТИНА СПЕКТАКЛЯ
# NEW: картина СЛОВЕСНАЯ КАРТИНА
# OLD: банк БАНК (СОБРАНИЕ ПРЕДМЕТОВ, ОБЪЕКТОВ СВЕДЕНИЙ)
# NEW: банк БАНК (ФИНАНСОВОЕ УЧРЕЖДЕНИЕ)
# OLD: игра ИГРАТЬ (ИСПОЛНЯТЬ)
# NEW: игра ИГРАТЬ, ОБРАЩАТЬСЯ ЛЕГКОМЫСЛЕННО
# OLD: ПЕНИЕ ПТИЦЫ ПЕНИЕ ПТИЦЫ
# NEW: ПЕНИЕ ПТИЦЫ ПЕНИЕ ПТИЦЫ
# OLD: ПРИТВОРИТЬСЯ, ПРИКИНУТЬСЯ ПРИТВОРИТЬСЯ, ПРИКИНУТЬСЯ
# NEW: ПРИТВОРИТЬСЯ, ПРИКИНУТЬСЯ ПРИТВОРИТЬСЯ, ПРИКИНУТЬСЯ
# OLD: сцена СЦЕНА В ПРОИЗВЕДЕНИИ
# NEW: сцена СЦЕНА (ПЛОЩАДКА)
# OLD: душа ДУША (БЕССМЕРТНАЯ СУЩНОСТЬ)
# NEW: душа ДУША (ВНУТРЕННИЙ МИР)
# OLD: электричество ЭЛЕКТРИЧЕСТВО (ФИЗИЧЕСКОЕ ЯВЛЕНИЕ)
# NEW: электричество ЭЛЕКТРИЧЕСКАЯ ЭНЕРГИЯ
# OLD: сцена СЦЕНА (ПРОИСШЕСТВИЕ)
# NEW: сцена СЦЕНА (ПЛОЩАДКА)
# OLD: отряд ОТРЯД ЖИВОТНЫХ
# NEW: отряд ВООРУЖЕННЫЙ ОТРЯД
# OLD: крона КРОНА, ШВЕДСКАЯ
# NEW: крона КРОНА ДЕРЕВА
# OLD: крона КРОНА, НОРВЕЖСКАЯ
# NEW: крона КРОНА ДЕРЕВА
# OLD: крона КРОНА, ДАТСКАЯ
# NEW: крона КРОНА ДЕРЕВА
# OLD: поток ПОТОК (ДВИЖУЩАЯСЯ МАССА)
# NEW: поток ПОТОЧНОЕ ПРОИЗВОДСТВО
# OLD: платформа ПЛАТФОРМА (ПОДОШВА)
# NEW: платформа ПЛАТФОРМА (ВОЗВЫШЕННАЯ ПЛОЩАДКА)
# OLD: адский АД, ПРЕИСПОДНЯЯ
# NEW: адский АДСКИЙ (НЕВЫНОСИМЫЙ)
# OLD: гроза ГРОЗА (О ТОМ, ЧТО ВНУШАЕТ СТРАХ, УЖАС)
# NEW: гроза ГРОЗА
# OLD: касса КАССОВАЯ НАЛИЧНОСТЬ
# NEW: касса КАССА (УЧРЕЖДЕНИЕ)
# OLD: маска МАСКА (НАКЛАДКА)
# NEW: маска МАСКА, СКРЫВАЮЩАЯ ЛИЦО
# OLD: род РОД (ГРУППА ЛЮДЕЙ)
# NEW: род ГРАММАТИЧЕСКИЙ РОД
# OLD: маска КОСМЕТИЧЕСКАЯ МАСКА
# NEW: маска МАСКА, СКРЫВАЮЩАЯ ЛИЦО
# 2500/5877 synsets parsed.
# OLD: свалка МАССОВАЯ ДРАКА
# NEW: свалка СВАЛКА ОТХОДОВ, ОТБРОСОВ
# OLD: плюс ПЛЮС (МАТЕМАТИЧЕСКИЙ ЗНАК)
# NEW: плюс ДОБАВИТЬ
# OLD: ПОДОБРАТЬ (ВЫБРАТЬ) ПОДОБРАТЬ (ВЫБРАТЬ)
# NEW: ПОДОБРАТЬ (ВЫБРАТЬ) ПОДОБРАТЬ (ВЫБРАТЬ)
# OLD: ПОМОЩЬ, ПОДДЕРЖКА ПОМОЩЬ, ПОДДЕРЖКА
# NEW: ПОМОЩЬ, ПОДДЕРЖКА ПОМОЩЬ, ПОДДЕРЖКА
# OLD: свидетель СВИДЕТЕЛЬ (ЛИЦО, ПРИСУТСТВУЮЩЕЕ ДЛЯ УДОСТОВЕРЕНИЯ)
# NEW: свидетель СВИДЕТЕЛЬ ПО ДЕЛУ
# OLD: защита ОБЕРЕГАТЬ, ЗАЩИЩАТЬ
# NEW: защита ЗАЩИТА ОТ ВОЗДЕЙСТВИЯ
# OLD: защита ЗАЩИТИТЬ ТОЧКУ ЗРЕНИЯ
# NEW: защита ЗАЩИТА ОТ ВОЗДЕЙСТВИЯ
# OLD: курс КУРС ОБУЧЕНИЯ
# NEW: курс КУРС (ГРУППА УЧАЩИХСЯ)
# OLD: курс КУРСОВАЯ СТОИМОСТЬ
# NEW: курс КУРС (ГРУППА УЧАЩИХСЯ)
# OLD: курс КУРС ЛЕЧЕНИЯ
# NEW: курс КУРС (ГРУППА УЧАЩИХСЯ)
# OLD: рак ОНКОЛОГИЧЕСКОЕ ЗАБОЛЕВАНИЕ
# NEW: рак РАК ПО ЗНАКУ ЗОДИАКА
# OLD: выражение ВЫРАЗИТЬ В ДРУГИХ ЕДИНИЦАХ
# NEW: выражение ВЫРАЗИТЬ (ПОКАЗАТЬ)
# OLD: пузырь ПУЗЫРЬ (НАПОЛНЕННЫЙ ВОЗДУХОМ ПРОЗР.ШАРИК)
# NEW: пузырь ЭКОНОМИЧЕСКИЙ ПУЗЫРЬ
# OLD: ИДТИ НОГАМИ ИДТИ НОГАМИ
# NEW: ИДТИ НОГАМИ ИДТИ НОГАМИ
# OLD: жертва ЖЕРТВА БОГАМ
# NEW: жертва ЖЕРТВА, ПОСТРАДАВШЕЕ ЛИЦО
# OLD: жертва ПРИНЕСТИ В ЖЕРТВУ (ДОБРОВОЛЬНО ОТКАЗАТЬСЯ В ПОЛЬЗУ)
# NEW: жертва ЖЕРТВА, ПОСТРАДАВШЕЕ ЛИЦО
# OLD: камера СЪЕМОЧНАЯ КАМЕРА
# NEW: камера ТЮРЕМНАЯ КАМЕРА
# OLD: горка СОРТИРОВОЧНАЯ ГОРКА
# NEW: горка ГОРКА (МЕБЕЛЬ)
# OLD: действие ДЕЙСТВОВАТЬ (ВЛИЯТЬ, ВОЗДЕЙСТВОВАТЬ)
# NEW: действие ДЕЙСТВИЕ ПРОИЗВЕДЕНИЯ
# OLD: узел ТРАНСПОРТНЫЙ УЗЕЛ
# NEW: узел УЗЕЛ (УТОЛЩЕНИЕ)
# OLD: спор СПОР (ОБСУЖДЕНИЕ)
# NEW: спор СУДЕБНЫЙ СПОР
# OLD: власть ОРГАН ВЛАСТИ
# NEW: власть ВЛАСТЬ, БРАЗДЫ ПРАВЛЕНИЯ
# OLD: исторический ИСТОРИЧЕСКОЕ РАЗВИТИЕ
# NEW: исторический ИСТОРИЧЕСКИЕ НАУКИ
# OLD: команда КОМАНДОВАТЬ (РУКОВОДИТЬ)
# NEW: команда КОМАНДА (ПРИКАЗ)
# OLD: команда КОМАНДА УСТРОЙСТВУ
# NEW: команда КОМАНДА (ПРИКАЗ)
# OLD: власть ПУБЛИЧНАЯ ВЛАСТЬ
# NEW: власть ВЛАСТЬ, БРАЗДЫ ПРАВЛЕНИЯ
# OLD: команда КОМАНДА (ОКРУЖЕНИЕ)
# NEW: команда КОМАНДА (ПРИКАЗ)
# OLD: ПРОЧНЫЙ (НЕИЗМЕННЫЙ) ПРОЧНЫЙ (НЕИЗМЕННЫЙ)
# NEW: ПРОЧНЫЙ (НЕИЗМЕННЫЙ) ПРОЧНЫЙ (НЕИЗМЕННЫЙ)
# OLD: воскресение ВОСКРЕСНУТЬ, ВОСПРЯНУТЬ ДУХОМ
# NEW: воскресение ВОСКРЕСЕНИЕ УМЕРШЕГО
# OLD: РАСКРОЙ ТКАНИ РАСКРОЙ ТКАНИ
# NEW: РАСКРОЙ ТКАНИ РАСКРОЙ ТКАНИ
# OLD: виться ВИТЬСЯ (ЛЕТАТЬ, КРУЖАСЬ)
# NEW: виться ВИТЬСЯ (РАСТИ ЗАВИТКАМИ)
# 2750/5877 synsets parsed.
# OLD: неверный ИЗМЕНИТЬ (НАРУШИТЬ ВЕРНОСТЬ)
# NEW: неверный ГЯУР (ИНОВЕРЕЦ)
# OLD: жирный ЖИРНОСТЬ ЛИНИИ
# NEW: жирный ЖИРНЫЙ, ГРЯЗНЫЙ ОТ ЖИРА
# OLD: палец ПАЛЕЦ ПЕРЧАТКИ
# NEW: палец ПАЛЕЦ МЕХАНИЗМА
# OLD: круглый КРУГЛЫЙ (ПОЛНЫЙ, СОВЕРШЕННЫЙ)
# NEW: круглый КРУГЛАЯ ФОРМА
# OLD: круглый КРУГЛЫЙ (ЦЕЛЫЙ О ВРЕМЕНИ)
# NEW: круглый КРУГЛАЯ ФОРМА
# OLD: ОТЛИТЬ, ВЫЛИТЬ ЧАСТЬ ОТЛИТЬ, ВЫЛИТЬ ЧАСТЬ
# NEW: ОТЛИТЬ, ВЫЛИТЬ ЧАСТЬ ОТЛИТЬ, ВЫЛИТЬ ЧАСТЬ
# OLD: нежность НЕЖНИЧАТЬ, ГОВОРИТЬ НЕЖНОСТИ
# NEW: нежность ЛАСКОВЫЙ
# OLD: плотный ПЛОТНЫЙ ПО СОСТАВУ
# NEW: плотный ПЛОТНЫЙ (ТОЛСТЫЙ И ПРОЧНЫЙ)
# OLD: сок СОК (НАПИТОК)
# NEW: сок СОК В ОРГАНИЗМЕ
# OLD: ВОЙТИ ВНУТРЬ ВОЙТИ ВНУТРЬ
# NEW: ВОЙТИ ВНУТРЬ ВОЙТИ ВНУТРЬ
# OLD: восточный ВОСТОЧНАЯ МЕСТНОСТЬ
# NEW: восточный ВОСТОК (МАКРОРЕГИОН)
# OLD: цикл ЦИКЛ ПРОИЗВЕДЕНИЙ
# NEW: цикл ЦИКЛИЧЕСКИЙ ПРОЦЕСС
# OLD: ДАВИТЬ, ОКАЗЫВАТЬ ДАВЛЕНИЕ ДАВИТЬ, ОКАЗЫВАТЬ ДАВЛЕНИЕ
# NEW: ДАВИТЬ, ОКАЗЫВАТЬ ДАВЛЕНИЕ ДАВИТЬ, ОКАЗЫВАТЬ ДАВЛЕНИЕ
# OLD: вкус ВКУС, ОЩУЩЕНИЕ НА ЯЗЫКЕ
# NEW: вкус ВКУС, ЧУВСТВО ПРЕКРАСНОГО
# OLD: вина ВИНА
# NEW: вина ВИНА (ПРИЧИНА НЕБЛАГОПРИЯТНОГО)
# OLD: война ВОЙНА
# NEW: война ВОЕВАТЬ (БОРОТЬСЯ)
# OLD: красивый КРАСИВЫЙ НА ВИД
# NEW: красивый БЛАГОЗВУЧНЫЙ
# OLD: кровавый КРОВАВЫЙ ЦВЕТ
# NEW: кровавый КРОВОПРОЛИТИЕ (МАССОВОЕ УБИЙСТВО)
# OLD: грудной ГРУДНОЙ МЛАДЕНЕЦ
# NEW: грудной ГРУДЬ (ТУЛОВИЩЕ)
# OLD: РАЗГОВОР, БЕСЕДА РАЗГОВОР, БЕСЕДА
# NEW: РАЗГОВОР, БЕСЕДА РАЗГОВОР, БЕСЕДА
# OLD: ЕВРЕИ ЕВРЕИ
# NEW: ЕВРЕИ ЕВРЕИ
# OLD: живой ЖИВОЙ (АКТИВНЫЙ, ДЕЯТЕЛЬНЫЙ)
# NEW: живой ЖИВОЙ (ВЫРАЗИТЕЛЬНЫЙ)
# OLD: урок ДОМАШНЕЕ ЗАДАНИЕ
# NEW: урок ШКОЛЬНЫЙ УРОК
# OLD: продукт ПРОДУКТЫ ПИТАНИЯ
# NEW: продукт ПРОДУКТ ПРОИЗВОДСТВА
# OLD: живой ЖИВОЙ, ЖИВУЩИЙ
# NEW: живой ЖИВОЙ (ВЫРАЗИТЕЛЬНЫЙ)
# OLD: конец КОНЕЦ В ПРОСТРАНСТВЕ
# NEW: конец КОНЕЦ ВО ВРЕМЕНИ
# OLD: ценность ЦЕННОСТЬ (ЦЕННЫЙ ПРЕДМЕТ, ЯВЛЕНИЕ)
# NEW: ценность ЦЕННОСТНЫЕ УСТАНОВКИ
# OLD: эфир ЭФИРНОЕ ВЕЩАНИЕ
# NEW: эфир ЭФИР (ОРГАНИЧЕСКОЕ СОЕДИНЕНИЕ)
# OLD: хрен ХРЕН (ПРИПРАВА)
# NEW: хрен ХРЕН (РАСТЕНИЕ)
# OLD: зерно ЗЕРНО (ЧАСТИЦА)
# NEW: зерно ЗЕРНО РАСТЕНИЯ
# OLD: имя ИМЯ ЧЕЛОВЕКА
# NEW: имя ИЗВЕСТНЫЙ ЧЕЛОВЕК
# OLD: ВСТАТЬ, ПРИНЯТЬ СТОЯЧЕЕ ПОЛОЖЕНИЕ ВСТАТЬ, ПРИНЯТЬ СТОЯЧЕЕ ПОЛОЖЕНИЕ
# NEW: ВСТАТЬ, ПРИНЯТЬ СТОЯЧЕЕ ПОЛОЖЕНИЕ ВСТАТЬ, ПРИНЯТЬ СТОЯЧЕЕ ПОЛОЖЕНИЕ
# OLD: сила СИЛА ВЛИЯНИЯ
# NEW: сила СИЛА, ЖИЗНЕННАЯ СИЛА
# OLD: трубка ТРУБКА (ПРЕДМЕТ ТРУБООБРАЗНОЙ ФОРМЫ)
# NEW: трубка КУРИТЕЛЬНАЯ ТРУБКА
# OLD: имя ЛИЧНОЕ ИМЯ
# NEW: имя ИЗВЕСТНЫЙ ЧЕЛОВЕК
# OLD: газовый ГАЗОВАЯ ТКАНЬ
# NEW: газовый ГАЗООБРАЗНОЕ ВЕЩЕСТВО
# OLD: дальний ДАЛЕКИЙ ПО РАССТОЯНИЮ
# NEW: дальний ДАЛЕКИЙ ПО ВРЕМЕНИ
# OLD: бояться БЕРЕЧЬСЯ, ДЕЙСТВОВАТЬ ОСМОТРИТЕЛЬНО
# NEW: бояться БОЯТЬСЯ (НЕ ПЕРЕНОСИТЬ, ПОРТИТЬСЯ)
# OLD: СЕЛЬСКАЯ МЕСТНОСТЬ СЕЛЬСКАЯ МЕСТНОСТЬ
# NEW: СЕЛЬСКАЯ МЕСТНОСТЬ СЕЛЬСКАЯ МЕСТНОСТЬ
# OLD: ПЫТАТЬСЯ, СТАРАТЬСЯ ПЫТАТЬСЯ, СТАРАТЬСЯ
# NEW: ПЫТАТЬСЯ, СТАРАТЬСЯ ПЫТАТЬСЯ, СТАРАТЬСЯ
# OLD: звезда ЗВЕЗДА (ФИГУРА)
# NEW: звезда ЗВЕЗДА (НЕБЕСНОЕ ТЕЛО)
# 3000/5877 synsets parsed.
# OLD: СЛАБОВОЛЬНЫЙ СЛАБОВОЛЬНЫЙ
# NEW: СЛАБОВОЛЬНЫЙ СЛАБОВОЛЬНЫЙ
# OLD: мастер МАСТЕР СПОРТА
# NEW: мастер МАСТЕР, ИСКУСНИК
# OLD: мастер МАСТЕР (КВАЛИФИЦИРОВАННЫЙ РАБОТНИК)
# NEW: мастер МАСТЕР, ИСКУСНИК
# OLD: мастер МАСТЕР ПРОИЗВОДСТВА
# NEW: мастер МАСТЕР, ИСКУСНИК
# OLD: ЗАБОТИТЬСЯ, ОКРУЖИТЬ ЗАБОТОЙ ЗАБОТИТЬСЯ, ОКРУЖИТЬ ЗАБОТОЙ
# NEW: ЗАБОТИТЬСЯ, ОКРУЖИТЬ ЗАБОТОЙ ЗАБОТИТЬСЯ, ОКРУЖИТЬ ЗАБОТОЙ
# OLD: выражение МАТЕМАТИЧЕСКОЕ ВЫРАЖЕНИЕ
# NEW: выражение ВЫРАЗИТЬ (ПОКАЗАТЬ)
# OLD: мак МАК
# NEW: мак ЗЕРНА МАКА
# OLD: шерсть ШЕРСТЬ ЖИВОТНОГО
# NEW: шерсть ШЕРСТЯНОЕ СЫРЬЕ
# OLD: шерсть ШЕРСТЯНАЯ ТКАНЬ
# NEW: шерсть ШЕРСТЯНОЕ СЫРЬЕ
# OLD: шерсть ШЕРСТЯНАЯ ПРЯЖА
# NEW: шерсть ШЕРСТЯНОЕ СЫРЬЕ
# OLD: стенка СТЕНКА ПОЛОГО ОРГАНА
# NEW: стенка БОКОВАЯ СТЕНКА
# OLD: душа ДУША КОМПАНИИ
# NEW: душа ДУША (ВНУТРЕННИЙ МИР)
# OLD: рабочий РАБОЧИЙ (ПРЕДВАРИТЕЛЬНЫЙ)
# NEW: рабочий РАБОЧИЙ, РАБОТНИК ФИЗИЧЕСКОГО ТРУДА
# OLD: стенка СТЕНКА (ШКАФ)
# NEW: стенка БОКОВАЯ СТЕНКА
# OLD: ножка НОЖКА ГРИБА
# NEW: ножка НОЖКА (СТЕБЕЛЬ)
# OLD: ножка НОЖКА (ОПОРА)
# NEW: ножка НОЖКА (СТЕБЕЛЬ)
# OLD: борьба БОРОТЬСЯ (НАПАДАЯ СТАРАТЬСЯ ОСИЛИТЬ)
# NEW: борьба БОРОТЬСЯ, СТРЕМИТЬСЯ УНИЧТОЖИТЬ
# OLD: борьба БОРОТЬСЯ, ДОБИВАТЬСЯ
# NEW: борьба БОРОТЬСЯ, СТРЕМИТЬСЯ УНИЧТОЖИТЬ
# OLD: потолок ПОТОЛОК ПОМЕЩЕНИЯ
# NEW: потолок ПОТОЛОК, ВЕРХНИЙ ПРЕДЕЛ
# OLD: борьба БОРОТЬСЯ С СОПЕРНИКОМ
# NEW: борьба БОРОТЬСЯ, СТРЕМИТЬСЯ УНИЧТОЖИТЬ
# OLD: борьба СПОРТИВНАЯ БОРЬБА
# NEW: борьба БОРОТЬСЯ, СТРЕМИТЬСЯ УНИЧТОЖИТЬ
# OLD: СООБЩИТЬ, УВЕДОМИТЬ СООБЩИТЬ, УВЕДОМИТЬ
# NEW: СООБЩИТЬ, УВЕДОМИТЬ СООБЩИТЬ, УВЕДОМИТЬ
# OLD: концерт КОНЦЕРТ
# NEW: концерт КОНЦЕРТ (МУЗЫКАЛЬНОЕ ПРОИЗВЕДЕНИЕ)
# OLD: операция ОПЕРАЦИЯ (ОТДЕЛЬНОЕ ДЕЙСТВИЕ)
# NEW: операция ХИРУРГИЧЕСКАЯ ОПЕРАЦИЯ
# OLD: фронт ЛИНИЯ ФРОНТА
# NEW: фронт ФРОНТ (ОБЩЕСТВЕННОЕ ДВИЖЕНИЕ)
# OLD: фронт АТМОСФЕРНЫЙ ФРОНТ
# NEW: фронт ФРОНТ (ОБЩЕСТВЕННОЕ ДВИЖЕНИЕ)
# OLD: статус СТАТУС
# NEW: статус ПРАВОВОЙ СТАТУС
# OLD: ток ТОКОВИЩЕ
# NEW: ток ЗЕРНОВОЙ ТОК
# OLD: ток ТОКОВАНИЕ ПТИЦ
# NEW: ток ЗЕРНОВОЙ ТОК
# OLD: печь ПАЛИТЬ, ОБДАВАТЬ ЗНОЕМ
# NEW: печь ПЕЧЬ ДЛЯ НАГРЕВАНИЯ
# OLD: молния ЗАСТЕЖКА МОЛНИЯ
# NEW: молния МОЛНИЯ (ИСКРОВОЙ РАЗРЯД)
# OLD: запад ЗАПАД (МАКРОРЕГИОН)
# NEW: запад ЗАПАДНАЯ МЕСТНОСТЬ
# OLD: ПРОВАЛИТЬСЯ, ПОТЕРПЕТЬ ПРОВАЛ ПРОВАЛИТЬСЯ, ПОТЕРПЕТЬ ПРОВАЛ
# NEW: ПРОВАЛИТЬСЯ, ПОТЕРПЕТЬ ПРОВАЛ ПРОВАЛИТЬСЯ, ПОТЕРПЕТЬ ПРОВАЛ
# OLD: закатный ВЕЧЕРНЯЯ ЗАРЯ
# NEW: закатный ЗАКАТ СОЛНЦА
# OLD: восток ВОСТОЧНАЯ МЕСТНОСТЬ
# NEW: восток ВОСТОК (МАКРОРЕГИОН)
# OLD: ствол СТВОЛ ОРУЖИЯ
# NEW: ствол СТВОЛ ДЕРЕВА
# OLD: ВОЖДЕЛЕТЬ, ИСПЫТЫВАТЬ ЧУВСТВЕННОЕ ВЛЕЧЕНИЕ ВОЖДЕЛЕТЬ, ИСПЫТЫВАТЬ ЧУВСТВЕННОЕ ВЛЕЧЕНИЕ
# NEW: ВОЖДЕЛЕТЬ, ИСПЫТЫВАТЬ ЧУВСТВЕННОЕ ВЛЕЧЕНИЕ ВОЖДЕЛЕТЬ, ИСПЫТЫВАТЬ ЧУВСТВЕННОЕ ВЛЕЧЕНИЕ
# OLD: ствол СТВОЛ (СТЕРЖЕНЬ ИЛИ ТРУБА)
# NEW: ствол СТВОЛ ДЕРЕВА
# OLD: хлопок ХЛОПАТЬ В ЛАДОШИ
# NEW: хлопок ХЛОПКОВОЕ ВОЛОКНО
# OLD: корень КОРЕНЬ СЛОВА
# NEW: корень КОРЕНЬ ЧИСЛА
# OLD: гладкий ГЛАДКИЙ НА ОЩУПЬ
# NEW: гладкий ГЛАДКИЙ (ПЛАВНЫЙ, БЕЗ ЗАТРУДНЕНИЙ)
# OLD: восток ВОСТОК
# NEW: восток ВОСТОК (МАКРОРЕГИОН)
# OLD: горизонт ГОРИЗОНТ (ВИДИМОЕ ПРОСТРАНСТВО)
# NEW: горизонт ГОРИЗОНТ, ЛИНИЯ ГОРИЗОНТА
# OLD: ИЗГОТОВИТЬ, ВЫРАБОТАТЬ ИЗГОТОВИТЬ, ВЫРАБОТАТЬ
# NEW: ИЗГОТОВИТЬ, ВЫРАБОТАТЬ ИЗГОТОВИТЬ, ВЫРАБОТАТЬ
# OLD: ЧЕЛОВЕК ЧЕЛОВЕК
# NEW: ЧЕЛОВЕК ЧЕЛОВЕК
# OLD: профиль ПРОФИЛЬ (СЕЧЕНИЕ)
# NEW: профиль МЕТАЛЛИЧЕСКИЙ ПРОФИЛЬ
# OLD: профиль ПРОФИЛЬ ДЕЯТЕЛЬНОСТИ
# NEW: профиль МЕТАЛЛИЧЕСКИЙ ПРОФИЛЬ
# OLD: ВЫСКАЗАТЬ ВЫСКАЗАТЬ
# NEW: ВЫСКАЗАТЬ ВЫСКАЗАТЬ
# OLD: ПРОХЛАДНЫЙ (НЕ ЖАРКИЙ) ПРОХЛАДНЫЙ (НЕ ЖАРКИЙ)
# NEW: ПРОХЛАДНЫЙ (НЕ ЖАРКИЙ) ПРОХЛАДНЫЙ (НЕ ЖАРКИЙ)
# OLD: поток ПОТОК ВОДЫ
# NEW: поток ПОТОЧНОЕ ПРОИЗВОДСТВО
# OLD: почка ПОЧКА РАСТЕНИЯ
# NEW: почка ПОЧКИ
# OLD: грош НИЗКАЯ ОПЛАТА ТРУДА
# NEW: грош ГРОШ, ПОЛЬСКИЙ
# OLD: любовь ЛЮБОВЬ (ПРИВЯЗАННОСТЬ)
# NEW: любовь ЛЮБОВЬ, СЕРДЕЧНОЕ ВЛЕЧЕНИЕ
# 3250/5877 synsets parsed.
# OLD: зависеть ЗАВИСИМОСТЬ (ОТНОШЕНИЕ)
# NEW: зависеть ЗАВИСЕТЬ, НАХОДИТЬСЯ В ЗАВИСИМОСТИ
# OLD: вспышка ВСПЫЛИТЬ
# NEW: вспышка ВСПЫХНУТЬ (ВНЕЗАПНО ВОЗНИКНУТЬ)
# OLD: зерно ЗЕРНО ХЛЕБНЫХ ЗЛАКОВ
# NEW: зерно ЗЕРНО РАСТЕНИЯ
# OLD: трубка ТЕЛЕФОННАЯ ТРУБКА
# NEW: трубка КУРИТЕЛЬНАЯ ТРУБКА
# OLD: ПРОПАСТЬ КУДА-ТО ПРОПАСТЬ КУДА-ТО
# NEW: ПРОПАСТЬ КУДА-ТО ПРОПАСТЬ КУДА-ТО
# OLD: тополь ТОПОЛЬ (ДРЕВЕСИНА)
# NEW: тополь ТОПОЛЬ
# OLD: грунт ГРУНТОВОЧНЫЙ СОСТАВ
# NEW: грунт ГРУНТОВОЧНЫЙ СЛОЙ
# OLD: душ ДУШЕВАЯ УСТАНОВКА
# NEW: душ ДУШЕВАЯ КОМНАТА
# OLD: УБИЙСТВО ЧЕЛОВЕКА УБИЙСТВО ЧЕЛОВЕКА
# NEW: УБИЙСТВО ЧЕЛОВЕКА УБИЙСТВО ЧЕЛОВЕКА
# OLD: липа ЛИПА (ДЕРЕВО)
# NEW: липа ЛИПА (ДРЕВЕСИНА)
# OLD: стальной СТАЛЬНОЙ ЦВЕТ
# NEW: стальной СТАЛЬ
# OLD: хлопок ХЛОПОК (ЗВУК)
# NEW: хлопок ХЛОПКОВОЕ ВОЛОКНО
# OLD: хлопок ХЛОПЧАТНИК
# NEW: хлопок ХЛОПКОВОЕ ВОЛОКНО
# OLD: ОСТАНОВИТЬ ДВИЖЕНИЕ ОСТАНОВИТЬ ДВИЖЕНИЕ
# NEW: ОСТАНОВИТЬ ДВИЖЕНИЕ ОСТАНОВИТЬ ДВИЖЕНИЕ
# OLD: пустота ПУСТОГОЛОВЫЙ
# NEW: пустота ОПУСТОШЕННОСТЬ
# OLD: пачка ПАЧКА, КИПА
# NEW: пачка БАЛЕТНАЯ ПАЧКА
# OLD: ЗАМЕНИТЬ, НАЙТИ ЗАМЕНУ ЗАМЕНИТЬ, НАЙТИ ЗАМЕНУ
# NEW: ЗАМЕНИТЬ, НАЙТИ ЗАМЕНУ ЗАМЕНИТЬ, НАЙТИ ЗАМЕНУ
# OLD: смена СМЕНА (ГРУППА РАБОТАЮЩИХ)
# NEW: смена СМЕНИТЬ (ЗАМЕНИТЬ СОБОЙ)
# OLD: смена СМЕНИТЬСЯ (ОСВОБОДИТЬСЯ ОТ ОБЯЗАННОСТИ)
# NEW: смена СМЕНИТЬ (ЗАМЕНИТЬ СОБОЙ)
# OLD: фронт ФРОНТ (ВОИНСКИЙ СТРОЙ)
# NEW: фронт ФРОНТ (ОБЩЕСТВЕННОЕ ДВИЖЕНИЕ)
# OLD: журавль ЖУРАВЛЬ (ПТИЦА)
# NEW: журавль КОЛОДЕЗНЫЙ ЖУРАВЛЬ
# OLD: культурный КУЛЬТУРНЫЙ (НЕ ДИКИЙ)
# NEW: культурный КУЛЬТУРА (СФЕРА ДЕЯТЕЛЬНОСТИ)
# OLD: музыка МУЗЫКАЛЬНОЕ ИСКУССТВО
# NEW: музыка МУЗЫКАЛЬНЫЙ ЗВУК
# OLD: БЕЗУМНЫЙ ПОСТУПОК БЕЗУМНЫЙ ПОСТУПОК
# NEW: БЕЗУМНЫЙ ПОСТУПОК БЕЗУМНЫЙ ПОСТУПОК
# OLD: дочка ДОЧЕРНЯЯ КОМПАНИЯ
# NEW: дочка ДОЧКА (ОБРАЩЕНИЕ К МОЛОДОЙ ЖЕНЩИНЕ, ДЕВОЧКЕ)
# OLD: материнский МАТЕРИНСКИЙ (ИСХОДНЫЙ)
# NEW: материнский ХОЛДИНГОВАЯ КОМПАНИЯ
# OLD: материнский МАТЬ
# NEW: материнский ХОЛДИНГОВАЯ КОМПАНИЯ
# OLD: ПРОСТИТЬ, ИЗВИНИТЬ ПРОСТИТЬ, ИЗВИНИТЬ
# NEW: ПРОСТИТЬ, ИЗВИНИТЬ ПРОСТИТЬ, ИЗВИНИТЬ
# OLD: вена ВЕНА (СОСУД)
# NEW: вена ВЕНА, СТОЛИЦА АВСТРИИ
# OLD: вечность БЕССРОЧНЫЙ, ВЕЧНЫЙ
# NEW: вечность ВЕЧНЫЙ, ВЕЧНО СУЩЕСТВУЮЩИЙ
# OLD: рукав РУКАВ (ШЛАНГ)
# NEW: рукав РУКАВ РЕКИ
# OLD: утка УТЯТИНА
# NEW: утка УТКА
# OLD: адрес ПОЧТОВЫЙ АДРЕС
# NEW: адрес ПОЗДРАВИТЕЛЬНЫЙ АДРЕС
# OLD: завязать ЗАВЯЗАТЬ С ВРЕДНОЙ ПРИВЫЧКОЙ
# NEW: завязать ЗАВЯЗАТЬ (ЗАКРЕПИТЬ)

# %%
filename = 'synsetMeanDiff1-9_Fixed'
with open(f'{filename}.json', 'w', encoding='utf-8') as f:
    json.dump(freqdatalist, f, ensure_ascii=False, indent=4)

# %%
# shake up the data
for f in freqdatalist:
    f['s_x'] = f['s_x'] + [-1,1][random.randrange(2)]*random.random()/2
    f['s_y'] = f['s_y'] + [-1,1][random.randrange(2)]*random.random()/2

# %%
filename = 'shakenSynsetMeanDiff1-9'
with open(f'{filename}.json', 'w', encoding='utf-8') as f:
    json.dump(freqdatalist, f, ensure_ascii=False, indent=4)

# %%
\
