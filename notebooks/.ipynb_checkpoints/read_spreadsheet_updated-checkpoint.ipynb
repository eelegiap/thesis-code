# %%
import tqdm
from tqdm import tqdm
import pandas as pd 
import random
import json
import spacy
import translators as ts
import scipy

df = pd.read_excel('../Excel_files/Full_Poem_Dataset_12-17.xlsx')
df = df.drop(columns=['Unnamed: 0'])
records = df.to_dict('records')
random.choice(records)
# Out:
# Using United States server backend.
# {'Text': 'Туда, где роща корабельная \nлежит и смотрит, как живая, \nвыходит девочка дебильная, \nпо желтой насыпи гуляет.\n \nЕе, для глаза незаметная, \nнепреднамеренно хипповая, \nсвисает сумка с инструментами, \nв которой дрель, уже не новая.\n \nИ вот, как будто полоумная \n(хотя вообще она дебильная), \nона по болтикам поломанным \nпроводит стершимся напильником.\n \nЧего ты ищешь в окружающем \nметаллоломе, как приматая, \nключи вытаскиваешь ржавые, \nлопатой бьешь по трансформатору?\n \nЕй очень трудно нагибаться. \nОна к болту на 28 \nподносит ключ на 18, \nхотя ее никто не просит.\n \nЕе такое время косит, \nв нее вошли такие бесы... \nОна обед с собой приносит, \nа то и вовсе без обеда.\n \nВокруг нее свистит природа \nи электрические приводы. \nОна имеет два привода \nза кражу дросселя и провода.\n \nЕе один грызет вопрос, \nона не хочет раздвоиться:\nто в стрелку может превратиться, \nто в маневровый паровоз.\n \nЕе мы видим здесь и там. \nИ, никакая не лазутчица, \nона шагает по путям, \nона всю жизнь готова мучиться,\n \nно не допустит, чтоб навек \nв осадок выпали, как сода, \nнепросвещенная природа \nи возмущенный человек!',
#  'Author': 'Александр Ерёменко',
#  'Before or after': 'Before',
#  'Source': 'essentialpoetry',
#  'Date posted': datetime.datetime(2020, 10, 25, 0, 0),
#  'UniqueIndex': 2546}

# %%
# df.to_json('Full_Poem_Dataset_2-3.json', orient='records', force_ascii=False)

# %% [markdown]
# ### Statistics for Methods section

# %%
nlp = spacy.load("ru_core_news_lg")

# %%
for rec in tqdm(records):
    doc = nlp(rec['Text'])
    rec['doc'] = doc
# Out:
# 100%|██████████████████████████████████████| 3222/3222 [03:06<00:00, 17.28it/s]

# %%
# look at lemma counts
tokenCt = dict()
poemCt = dict()
for p in ['Before','After']:
    tokenCt.setdefault(p, 0)
    poemCt.setdefault(p, 0)
for rec in tqdm(records):
    poemCt[rec['Before or after']] += 1
    for t in rec['doc']:
        tokenCt[rec['Before or after']] += 1 
print(tokenCt)
print(poemCt)
# Out:
# 100%|███████████████████████████████████| 3222/3222 [00:00<00:00, 11634.37it/s]
# {'Before': 291769, 'After': 266511}
# {'Before': 1661, 'After': 1561}

# %% [markdown]
# #### Calculating two sample one sided t-test

# %%
textDict = dict()
lemmaCts = dict()
totalPoemCts = dict()
scipyArray = dict()

for r in tqdm(records[:10]):
    p = r['Before or after']
    totalPoemCts.setdefault(p, 0)
    lemmasFound = set()
    totalPoemCts[p] += 1
    for t in r['doc']:
        if t.lemma_ not in lemmasFound:
            # lemmaCts.setdefault(t.lemma_, {'Before' : 0, 'After' : 0})
            lemmaCts.setdefault(t.lemma_, {'Before' : 0, 'After' : 0, 'nlpToken' : t})
            lemmaCts[t.lemma_][p] += 1
            textDict.setdefault(t.lemma_, {'Before' : [], 'After' : []})
            textDict[t.lemma_][p].append({'ID' : r['UniqueIndex'], 'tokenText' : t.text})
            lemmasFound.add(t.lemma_)
        else:
            continue
# lemmaFreqs = dict()
# for word in lemmaCts:
#     lemmaFreqs.setdefault(word, {'Before' : 0, 'After' : 0})
#     for p in ['Before','After']:
#         lemmaFreqs[word][p] = lemmaCts[word][p]/totalPoemCts[p]
#         lemmaFreqs[word][p+'Ct'] = lemmaCts[word][p]
#         lemmaFreqs[word]['nlp'] = lemmaCts[word]['nlpToken']
        
# # create arrays for scipy
# scipyArray = dict()
# for lem in lemmaCts:
#     scipyArray.setdefault(lem, {'Before' : [], 'After' : []})

# for r in tqdm(records):
#     p = r['Before or after']
#     recLemmas = set([t.lemma_ for t in r['doc']])
#     for rl in recLemmas:
#         scipyArray[rl][p].append(1)
#     for lem in lemmaCts:
#         if lem not in recLemmas:
#             scipyArray[lem][p].append(0)
# Out:
# 100%|██████████████████████████████████████████| 10/10 [00:00<00:00, 48.62it/s]

# %%
textDict
# Out:
# {'зима': {'Before': [{'ID': 624, 'tokenText': 'Зима'},
#    {'ID': 1105, 'tokenText': 'зимы'}],
#   'After': []},
#  'в': {'Before': [{'ID': 624, 'tokenText': 'в'},
#    {'ID': 971, 'tokenText': 'в'},
#    {'ID': 933, 'tokenText': 'в'},
#    {'ID': 1064, 'tokenText': 'в'},
#    {'ID': 1072, 'tokenText': 'в'},
#    {'ID': 1082, 'tokenText': 'в'},
#    {'ID': 1105, 'tokenText': 'в'},
#    {'ID': 1169, 'tokenText': 'в'},
#    {'ID': 1256, 'tokenText': 'в'}],
#   'After': []},
#  'бавария': {'Before': [{'ID': 624, 'tokenText': 'Баварии'}], 'After': []},
#  'похожий': {'Before': [{'ID': 624, 'tokenText': 'похожа'}], 'After': []},
#  '\n': {'Before': [{'ID': 624, 'tokenText': '\n'},
#    {'ID': 971, 'tokenText': '\n'},
#    {'ID': 933, 'tokenText': '\n'},
#    {'ID': 1064, 'tokenText': '\n'},
#    {'ID': 1072, 'tokenText': '\n'},
#    {'ID': 1082, 'tokenText': '\n'},
#    {'ID': 1105, 'tokenText': '\n'},
#    {'ID': 1160, 'tokenText': '\n'},
#    {'ID': 1256, 'tokenText': '\n'}],
#   'After': []},
#  'на': {'Before': [{'ID': 624, 'tokenText': 'на'},
#    {'ID': 971, 'tokenText': 'на'},
#    {'ID': 933, 'tokenText': 'на'},
#    {'ID': 1064, 'tokenText': 'на'},
#    {'ID': 1072, 'tokenText': 'на'},
#    {'ID': 1082, 'tokenText': 'на'},
#    {'ID': 1105, 'tokenText': 'на'},
#    {'ID': 1169, 'tokenText': 'на'},
#    {'ID': 1256, 'tokenText': 'на'}],
#   'After': []},
#  'всякий': {'Before': [{'ID': 624, 'tokenText': 'всякую'}], 'After': []},
#  'другую': {'Before': [{'ID': 624, 'tokenText': 'другую'}], 'After': []},
#  ',': {'Before': [{'ID': 624, 'tokenText': ','},
#    {'ID': 933, 'tokenText': ','},
#    {'ID': 1072, 'tokenText': ','},
#    {'ID': 1105, 'tokenText': ','},
#    {'ID': 1256, 'tokenText': ','}],
#   'After': []},
#  'когда': {'Before': [{'ID': 624, 'tokenText': 'когда'},
#    {'ID': 1169, 'tokenText': 'когда'}],
#   'After': []},
#  'блуждать': {'Before': [{'ID': 624, 'tokenText': 'блуждая'}], 'After': []},
#  'одиночка': {'Before': [{'ID': 624, 'tokenText': 'одиночку'}], 'After': []},
#  'ты': {'Before': [{'ID': 624, 'tokenText': 'ты'},
#    {'ID': 971, 'tokenText': 'ты'},
#    {'ID': 933, 'tokenText': 'Ты'},
#    {'ID': 1064, 'tokenText': 'ты'},
#    {'ID': 1169, 'tokenText': 'ты'}],
#   'After': []},
#  'искать': {'Before': [{'ID': 624, 'tokenText': 'ищешь'}], 'After': []},
#  'панна': {'Before': [{'ID': 624, 'tokenText': 'панну'}], 'After': []},
#  'будто': {'Before': [{'ID': 624, 'tokenText': 'будто'}], 'After': []},
#  'рифма': {'Before': [{'ID': 624, 'tokenText': 'рифму'}], 'After': []},
#  'или': {'Before': [{'ID': 624, 'tokenText': 'или'},
#    {'ID': 1072, 'tokenText': 'или'},
#    {'ID': 1256, 'tokenText': 'или'}],
#   'After': []},
#  'напротив': {'Before': [{'ID': 624, 'tokenText': 'напротив'}], 'After': []},
#  'как': {'Before': [{'ID': 624, 'tokenText': 'как'},
#    {'ID': 933, 'tokenText': 'Как'},
#    {'ID': 1072, 'tokenText': 'как'},
#    {'ID': 1105, 'tokenText': 'как'},
#    {'ID': 1160, 'tokenText': 'как'},
#    {'ID': 1256, 'tokenText': 'как'}],
#   'After': []},
#  'отголосок': {'Before': [{'ID': 624, 'tokenText': 'отголосок'}], 'After': []},
#  'слабый': {'Before': [{'ID': 624, 'tokenText': 'слабой'},
#    {'ID': 1105, 'tokenText': 'слабые'}],
#   'After': []},
#  'весть': {'Before': [{'ID': 624, 'tokenText': 'вести'}], 'After': []},
#  'и': {'Before': [{'ID': 624, 'tokenText': 'и'},
#    {'ID': 933, 'tokenText': 'И'},
#    {'ID': 1064, 'tokenText': 'и'},
#    {'ID': 1072, 'tokenText': 'и'},
#    {'ID': 1082, 'tokenText': 'и'},
#    {'ID': 1105, 'tokenText': 'и'},
#    {'ID': 1169, 'tokenText': 'и'},
#    {'ID': 1256, 'tokenText': 'и'}],
#   'After': []},
#  'вот': {'Before': [{'ID': 624, 'tokenText': 'вот'},
#    {'ID': 1072, 'tokenText': 'вот'},
#    {'ID': 1169, 'tokenText': 'вот'},
#    {'ID': 1256, 'tokenText': 'вот'}],
#   'After': []},
#  'девица': {'Before': [{'ID': 624, 'tokenText': 'девицы'}], 'After': []},
#  'без': {'Before': [{'ID': 624, 'tokenText': 'без'},
#    {'ID': 1256, 'tokenText': 'без'}],
#   'After': []},
#  'предел': {'Before': [{'ID': 624, 'tokenText': 'предела'}], 'After': []},
#  'все': {'Before': [{'ID': 624, 'tokenText': 'все'},
#    {'ID': 1064, 'tokenText': 'все'},
#    {'ID': 1105, 'tokenText': 'все'},
#    {'ID': 1169, 'tokenText': 'все'}],
#   'After': []},
#  'пойти': {'Before': [{'ID': 624, 'tokenText': 'пошли'}], 'After': []},
#  'антифашистки': {'Before': [{'ID': 624, 'tokenText': 'антифашистки'}],
#   'After': []},
#  '.': {'Before': [{'ID': 624, 'tokenText': '.'},
#    {'ID': 933, 'tokenText': '.'},
#    {'ID': 1072, 'tokenText': '.'},
#    {'ID': 1105, 'tokenText': '.'}],
#   'After': []},
#  'известный': {'Before': [{'ID': 624, 'tokenText': 'известно'}], 'After': []},
#  'затягивать': {'Before': [{'ID': 624, 'tokenText': 'Затягивает'}],
#   'After': []},
#  'вечереть': {'Before': [{'ID': 624, 'tokenText': 'Вечерело'}], 'After': []},
#  'мелодия': {'Before': [{'ID': 624, 'tokenText': 'мелодия'}], 'After': []},
#  'дебил': {'Before': [{'ID': 624, 'tokenText': 'дебила'}], 'After': []},
#  'терзать': {'Before': [{'ID': 624, 'tokenText': 'терзает'}], 'After': []},
#  'душа': {'Before': [{'ID': 624, 'tokenText': 'душу'}], 'After': []},
#  'мне': {'Before': [{'ID': 624, 'tokenText': 'мне'},
#    {'ID': 1064, 'tokenText': 'мне'},
#    {'ID': 1169, 'tokenText': 'мне'}],
#   'After': []},
#  'покуда': {'Before': [{'ID': 624, 'tokenText': 'покуда'},
#    {'ID': 933, 'tokenText': 'покуда'}],
#   'After': []},
#  'ходить': {'Before': [{'ID': 624, 'tokenText': 'хожу'},
#    {'ID': 971, 'tokenText': 'ходил'}],
#   'After': []},
#  'я': {'Before': [{'ID': 624, 'tokenText': 'я'},
#    {'ID': 933, 'tokenText': 'я'},
#    {'ID': 1064, 'tokenText': 'я'},
#    {'ID': 1169, 'tokenText': 'я'},
#    {'ID': 1256, 'tokenText': 'я'}],
#   'After': []},
#  'парк': {'Before': [{'ID': 624, 'tokenText': 'парком'}], 'After': []},
#  'сохнут': {'Before': [{'ID': 624, 'tokenText': 'Сохнут'}], 'After': []},
#  'сок': {'Before': [{'ID': 624, 'tokenText': 'соки'}], 'After': []},
#  'во': {'Before': [{'ID': 624, 'tokenText': 'во'},
#    {'ID': 971, 'tokenText': 'во'},
#    {'ID': 1256, 'tokenText': 'во'}],
#   'After': []},
#  'дерево': {'Before': [{'ID': 624, 'tokenText': 'деревьев'}], 'After': []},
#  'напряга': {'Before': [{'ID': 624, 'tokenText': 'напряга'}], 'After': []},
#  'мир': {'Before': [{'ID': 624, 'tokenText': 'мир'},
#    {'ID': 933, 'tokenText': 'мира'},
#    {'ID': 1064, 'tokenText': 'мира'},
#    {'ID': 1082, 'tokenText': 'мира'},
#    {'ID': 1256, 'tokenText': 'мира'}],
#   'After': []},
#  'их': {'Before': [{'ID': 624, 'tokenText': 'их'},
#    {'ID': 1105, 'tokenText': 'их'}],
#   'After': []},
#  'обездвижить': {'Before': [{'ID': 624, 'tokenText': 'обездвижен'}],
#   'After': []},
#  'тишина': {'Before': [{'ID': 624, 'tokenText': 'тишине'}], 'After': []},
#  'дно': {'Before': [{'ID': 624, 'tokenText': 'дне'}], 'After': []},
#  'залив': {'Before': [{'ID': 624, 'tokenText': 'залива'},
#    {'ID': 1072, 'tokenText': 'заливами'}],
#   'After': []},
#  'мечтаю': {'Before': [{'ID': 624, 'tokenText': 'Мечтаю'}], 'After': []},
#  'о': {'Before': [{'ID': 624, 'tokenText': 'о'},
#    {'ID': 1105, 'tokenText': 'О'}],
#   'After': []},
#  'гертруде': {'Before': [{'ID': 624, 'tokenText': 'Гертруде'}], 'After': []},
#  'рыжий': {'Before': [{'ID': 624, 'tokenText': 'рыжей'}], 'After': []},
#  'стабильный': {'Before': [{'ID': 624, 'tokenText': 'стабильна'}],
#   'After': []},
#  'не': {'Before': [{'ID': 624, 'tokenText': 'не'},
#    {'ID': 971, 'tokenText': 'не'},
#    {'ID': 933, 'tokenText': 'Не'},
#    {'ID': 1064, 'tokenText': 'не'},
#    {'ID': 1072, 'tokenText': 'не'},
#    {'ID': 1105, 'tokenText': 'не'},
#    {'ID': 1160, 'tokenText': 'не'},
#    {'ID': 1169, 'tokenText': 'не'},
#    {'ID': 1256, 'tokenText': 'Не'}],
#   'After': []},
#  'что': {'Before': [{'ID': 624, 'tokenText': 'что'},
#    {'ID': 933, 'tokenText': 'что'},
#    {'ID': 1072, 'tokenText': 'чего'},
#    {'ID': 1105, 'tokenText': 'что'},
#    {'ID': 1169, 'tokenText': 'что'},
#    {'ID': 1256, 'tokenText': 'что'}],
#   'After': []},
#  'со': {'Before': [{'ID': 624, 'tokenText': 'со'},
#    {'ID': 933, 'tokenText': 'со'}],
#   'After': []},
#  'мною': {'Before': [{'ID': 624, 'tokenText': 'мною'}], 'After': []},
#  ':': {'Before': [{'ID': 624, 'tokenText': ':'},
#    {'ID': 1072, 'tokenText': ':'},
#    {'ID': 1105, 'tokenText': ':'},
#    {'ID': 1169, 'tokenText': ':'},
#    {'ID': 1256, 'tokenText': ':'}],
#   'After': []},
#  'мой': {'Before': [{'ID': 624, 'tokenText': 'моя'},
#    {'ID': 1064, 'tokenText': 'мой'},
#    {'ID': 1105, 'tokenText': 'мой'},
#    {'ID': 1169, 'tokenText': 'моя'},
#    {'ID': 1256, 'tokenText': 'мой'}],
#   'After': []},
#  'почти': {'Before': [{'ID': 624, 'tokenText': 'почти'},
#    {'ID': 1169, 'tokenText': 'почти'}],
#   'After': []},
#  'бессильный': {'Before': [{'ID': 624, 'tokenText': 'бессильна'}],
#   'After': []},
#  'тут': {'Before': [{'ID': 624, 'tokenText': 'тут'},
#    {'ID': 1169, 'tokenText': 'тут'}],
#   'After': []},
#  'стать': {'Before': [{'ID': 624, 'tokenText': 'станет'},
#    {'ID': 1256, 'tokenText': 'стала'}],
#   'After': []},
#  'зимнею': {'Before': [{'ID': 624, 'tokenText': 'зимнею'}], 'After': []},
#  'сосна': {'Before': [{'ID': 624, 'tokenText': 'сосною'}], 'After': []},
#  'жить': {'Before': [{'ID': 624, 'tokenText': 'Живу'},
#    {'ID': 933, 'tokenText': 'живёт'},
#    {'ID': 1072, 'tokenText': 'жила'},
#    {'ID': 1256, 'tokenText': 'живем'}],
#   'After': []},
#  'воспоминание': {'Before': [{'ID': 624, 'tokenText': 'воспоминанием'}],
#   'After': []},
#  'весною': {'Before': [{'ID': 624, 'tokenText': 'Весною'}], 'After': []},
#  'живу': {'Before': [{'ID': 624, 'tokenText': 'Живу'}], 'After': []},
#  'думать': {'Before': [{'ID': 624, 'tokenText': 'думаю'},
#    {'ID': 1256, 'tokenText': 'думая'}],
#   'After': []},
#  'грудь': {'Before': [{'ID': 624, 'tokenText': 'груди'},
#    {'ID': 1082, 'tokenText': 'грудь'},
#    {'ID': 1105, 'tokenText': 'груди'}],
#   'After': []},
#  'гертруда': {'Before': [{'ID': 624, 'tokenText': 'Гертруды'}], 'After': []},
#  'рухну': {'Before': [{'ID': 624, 'tokenText': 'рухну'}], 'After': []},
#  'эхом': {'Before': [{'ID': 624, 'tokenText': 'эхом'}], 'After': []},
#  'снег': {'Before': [{'ID': 624, 'tokenText': 'снег'},
#    {'ID': 971, 'tokenText': 'снега'},
#    {'ID': 1256, 'tokenText': 'снег'}],
#   'After': []},
#  'полечь': {'Before': [{'ID': 624, 'tokenText': 'полегший'}], 'After': []},
#  'гора': {'Before': [{'ID': 624, 'tokenText': 'горы'}], 'After': []},
#  'тьма': {'Before': [{'ID': 624, 'tokenText': 'тьмой'},
#    {'ID': 1105, 'tokenText': 'тьме'}],
#   'After': []},
#  'луна': {'Before': [{'ID': 624, 'tokenText': 'луною'}], 'After': []},
#  'весь': {'Before': [{'ID': 624, 'tokenText': 'все'},
#    {'ID': 933, 'tokenText': 'Вся'},
#    {'ID': 1082, 'tokenText': 'все'},
#    {'ID': 1256, 'tokenText': 'всю'}],
#   'After': []},
#  'окрестный': {'Before': [{'ID': 624, 'tokenText': 'окрестные'}], 'After': []},
#  'сооружение': {'Before': [{'ID': 624, 'tokenText': 'сооруженья'}],
#   'After': []},
#  'так': {'Before': [{'ID': 624, 'tokenText': 'так'},
#    {'ID': 933, 'tokenText': 'так'},
#    {'ID': 1082, 'tokenText': 'так'},
#    {'ID': 1105, 'tokenText': 'так'},
#    {'ID': 1160, 'tokenText': 'так'},
#    {'ID': 1169, 'tokenText': 'так'},
#    {'ID': 1256, 'tokenText': 'так'}],
#   'After': []},
#  'нежный': {'Before': [{'ID': 624, 'tokenText': 'нежна'},
#    {'ID': 1064, 'tokenText': 'нежный'},
#    {'ID': 1169, 'tokenText': 'нежного'}],
#   'After': []},
#  'непрочный': {'Before': [{'ID': 624, 'tokenText': 'непрочна'}], 'After': []},
#  'же': {'Before': [{'ID': 624, 'tokenText': 'же'},
#    {'ID': 971, 'tokenText': 'же'},
#    {'ID': 1072, 'tokenText': 'же'},
#    {'ID': 1105, 'tokenText': 'же'},
#    {'ID': 1169, 'tokenText': 'же'},
#    {'ID': 1256, 'tokenText': 'же'}],
#   'After': []},
#  'невечна': {'Before': [{'ID': 624, 'tokenText': 'невечна'}], 'After': []},
#  'ментальный': {'Before': [{'ID': 624, 'tokenText': 'ментальных'}],
#   'After': []},
#  ' \n': {'Before': [{'ID': 624, 'tokenText': ' \n'}], 'After': []},
#  'ее': {'Before': [{'ID': 624, 'tokenText': 'ее'},
#    {'ID': 1169, 'tokenText': 'ее'}],
#   'After': []},
#  'тронуть': {'Before': [{'ID': 624, 'tokenText': 'тронет'}], 'After': []},
#  'призрак': {'Before': [{'ID': 624, 'tokenText': 'призрак'}], 'After': []},
#  'дальний': {'Before': [{'ID': 624, 'tokenText': 'дальних'}], 'After': []},
#  'дыра': {'Before': [{'ID': 624, 'tokenText': 'Дыра'}], 'After': []},
#  'смысловой': {'Before': [{'ID': 624, 'tokenText': 'смысловое'}], 'After': []},
#  'пробел': {'Before': [{'ID': 624, 'tokenText': 'пробел'}], 'After': []},
#  'меж': {'Before': [{'ID': 624, 'tokenText': 'меж'},
#    {'ID': 1105, 'tokenText': 'меж'}],
#   'After': []},
#  'это': {'Before': [{'ID': 624, 'tokenText': 'этом'},
#    {'ID': 933, 'tokenText': 'это'},
#    {'ID': 1064, 'tokenText': 'это'},
#    {'ID': 1072, 'tokenText': 'это'},
#    {'ID': 1256, 'tokenText': 'это'}],
#   'After': []},
#  'любимый': {'Before': [{'ID': 624, 'tokenText': 'любимая'}], 'After': []},
#  'потусторонний': {'Before': [{'ID': 624, 'tokenText': 'потусторонняя'}],
#   'After': []},
#  'говорить': {'Before': [{'ID': 624, 'tokenText': 'говорила'},
#    {'ID': 1105, 'tokenText': 'говорят'},
#    {'ID': 1256, 'tokenText': 'говорил'}],
#   'After': []},
#  '-': {'Before': [{'ID': 624, 'tokenText': '-'},
#    {'ID': 971, 'tokenText': '-'},
#    {'ID': 933, 'tokenText': '-'},
#    {'ID': 1072, 'tokenText': '-'},
#    {'ID': 1105, 'tokenText': '-'},
#    {'ID': 1169, 'tokenText': '-'},
#    {'ID': 1256, 'tokenText': '-'}],
#   'After': []},
#  ' ': {'Before': [{'ID': 624, 'tokenText': ' '}], 'After': []},
#  'тлен': {'Before': [{'ID': 624, 'tokenText': 'тленом'}], 'After': []},
#  'тело': {'Before': [{'ID': 624, 'tokenText': 'телом'},
#    {'ID': 1064, 'tokenText': 'тел'}],
#   'After': []},
#  'лето': {'Before': [{'ID': 624, 'tokenText': 'летом'}], 'After': []},
#  'необходимый': {'Before': [{'ID': 624, 'tokenText': 'необходимая'},
#    {'ID': 1064, 'tokenText': 'необходимый'}],
#   'After': []},
#  'только': {'Before': [{'ID': 624, 'tokenText': 'только'},
#    {'ID': 971, 'tokenText': 'только'},
#    {'ID': 933, 'tokenText': 'только'},
#    {'ID': 1169, 'tokenText': 'только'}],
#   'After': []},
#  'мной': {'Before': [{'ID': 624, 'tokenText': 'мной'},
#    {'ID': 933, 'tokenText': 'мной'}],
#   'After': []},
#  'искомый': {'Before': [{'ID': 624, 'tokenText': 'искомая'}], 'After': []},
#  'юг': {'Before': [{'ID': 624, 'tokenText': 'юге'}], 'After': []},
#  'полоса': {'Before': [{'ID': 624, 'tokenText': 'полоса'}], 'After': []},
#  'серебряный': {'Before': [{'ID': 624, 'tokenText': 'серебряная'}],
#   'After': []},
#  'высокий': {'Before': [{'ID': 624, 'tokenText': 'высоких'},
#    {'ID': 1072, 'tokenText': 'высокого'},
#    {'ID': 1169, 'tokenText': 'высшей'}],
#   'After': []},
#  'альп': {'Before': [{'ID': 624, 'tokenText': 'Альп'}], 'After': []},
#  'ставить': {'Before': [{'ID': 624, 'tokenText': 'ставлю'}], 'After': []},
#  'запятую': {'Before': [{'ID': 624, 'tokenText': 'запятую'}], 'After': []},
#  'её': {'Before': [{'ID': 624, 'tokenText': 'ее'},
#    {'ID': 1082, 'tokenText': 'её'},
#    {'ID': 1256, 'tokenText': 'её'}],
#   'After': []},
#  'предчувствие': {'Before': [{'ID': 624, 'tokenText': 'предчувствии'}],
#   'After': []},
#  'песок': {'Before': [{'ID': 624, 'tokenText': 'песком'}], 'After': []},
#  'час': {'Before': [{'ID': 624, 'tokenText': 'часах'},
#    {'ID': 1072, 'tokenText': 'час'}],
#   'After': []},
#  'песочный': {'Before': [{'ID': 624, 'tokenText': 'песочных'}], 'After': []},
#  'еще': {'Before': [{'ID': 624, 'tokenText': 'еще'},
#    {'ID': 1169, 'tokenText': 'еще'}],
#   'After': []},
#  'немного': {'Before': [{'ID': 624, 'tokenText': 'немного'},
#    {'ID': 1064, 'tokenText': 'немного'},
#    {'ID': 1169, 'tokenText': 'немного'}],
#   'After': []},
#  'получить': {'Before': [{'ID': 624, 'tokenText': 'получу'}], 'After': []},
#  'отныне': {'Before': [{'ID': 624, 'tokenText': 'отныне'}], 'After': []},
#  'невесомый': {'Before': [{'ID': 624, 'tokenText': 'невесомое'}], 'After': []},
#  'присутствие': {'Before': [{'ID': 624, 'tokenText': 'присутствие'}],
#   'After': []},
#  'провал': {'Before': [{'ID': 624, 'tokenText': 'провале'}], 'After': []},
#  'эпоха': {'Before': [{'ID': 624, 'tokenText': 'эпохи'}], 'After': []},
#  '*': {'Before': [{'ID': 971, 'tokenText': '*'}], 'After': []},
#  '\n \n': {'Before': [{'ID': 971, 'tokenText': '\n \n'},
#    {'ID': 933, 'tokenText': '\n \n'},
#    {'ID': 1064, 'tokenText': '\n \n'},
#    {'ID': 1072, 'tokenText': '\n \n'},
#    {'ID': 1082, 'tokenText': '\n \n'},
#    {'ID': 1105, 'tokenText': '\n \n'},
#    {'ID': 1160, 'tokenText': '\n \n'},
#    {'ID': 1169, 'tokenText': '\n \n'},
#    {'ID': 1256, 'tokenText': '\n \n'}],
#   'After': []},
#  'год': {'Before': [{'ID': 971, 'tokenText': 'годы'},
#    {'ID': 1169, 'tokenText': 'лет'},
#    {'ID': 1256, 'tokenText': 'лет'}],
#   'After': []},
#  'налево': {'Before': [{'ID': 971, 'tokenText': 'налево'}], 'After': []},
#  'за': {'Before': [{'ID': 971, 'tokenText': 'за'},
#    {'ID': 933, 'tokenText': 'за'},
#    {'ID': 1082, 'tokenText': 'за'},
#    {'ID': 1105, 'tokenText': 'за'},
#    {'ID': 1256, 'tokenText': 'за'}],
#   'After': []},
#  'красный': {'Before': [{'ID': 971, 'tokenText': 'красным'}], 'After': []},
#  'вино': {'Before': [{'ID': 971, 'tokenText': 'вином'}], 'After': []},
#  'вдовый': {'Before': [{'ID': 971, 'tokenText': 'вдовых'}], 'After': []},
#  'направо': {'Before': [{'ID': 971, 'tokenText': 'направо'}], 'After': []},
#  'водить': {'Before': [{'ID': 971, 'tokenText': 'водил'}], 'After': []},
#  'белый': {'Before': [{'ID': 971, 'tokenText': 'белым'},
#    {'ID': 933, 'tokenText': 'белый'},
#    {'ID': 1064, 'tokenText': 'белой'},
#    {'ID': 1105, 'tokenText': 'белых'}],
#   'After': []},
#  'хлеб': {'Before': [{'ID': 971, 'tokenText': 'хлебом'}], 'After': []},
#  'бегать': {'Before': [{'ID': 971, 'tokenText': 'бегал'}], 'After': []},
#  'сон': {'Before': [{'ID': 971, 'tokenText': 'сне'}], 'After': []},
#  'тяжесть': {'Before': [{'ID': 971, 'tokenText': 'тяжести'}], 'After': []},
#  'влажный': {'Before': [{'ID': 971, 'tokenText': 'влажным'},
#    {'ID': 1169, 'tokenText': 'влажных'}],
#   'After': []},
#  'бревном': {'Before': [{'ID': 971, 'tokenText': 'бревном'}], 'After': []},
#  'бить': {'Before': [{'ID': 971, 'tokenText': 'бил'}], 'After': []},
#  'тебя': {'Before': [{'ID': 971, 'tokenText': 'тебя'},
#    {'ID': 933, 'tokenText': 'тебя'},
#    {'ID': 1169, 'tokenText': 'тебя'},
#    {'ID': 1256, 'tokenText': 'тебя'}],
#   'After': []},
#  'свет': {'Before': [{'ID': 971, 'tokenText': 'свет'},
#    {'ID': 933, 'tokenText': 'свет'}],
#   'After': []},
#  'был': {'Before': [{'ID': 971, 'tokenText': 'был'},
#    {'ID': 933, 'tokenText': 'был'}],
#   'After': []},
#  'крепкий': {'Before': [{'ID': 971, 'tokenText': 'крепок'}], 'After': []},
#  'спи': {'Before': [{'ID': 971, 'tokenText': 'спи'}], 'After': []},
#  'предстоять': {'Before': [{'ID': 971, 'tokenText': 'предстоит'},
#    {'ID': 1105, 'tokenText': 'предстоять'}],
#   'After': []},
#  'остановка': {'Before': [{'ID': 971, 'tokenText': 'остановка'}], 'After': []},
#  'солёный': {'Before': [{'ID': 971, 'tokenText': 'солёном'}], 'After': []},
#  'путь': {'Before': [{'ID': 971, 'tokenText': 'пути'}], 'After': []},
#  'время': {'Before': [{'ID': 971, 'tokenText': 'время'},
#    {'ID': 1105, 'tokenText': 'временах'},
#    {'ID': 1256, 'tokenText': 'время'}],
#   'After': []},
#  'разделить': {'Before': [{'ID': 971, 'tokenText': 'разделит'}], 'After': []},
#  'глаз': {'Before': [{'ID': 971, 'tokenText': 'глаз'}], 'After': []},
#  'острый': {'Before': [{'ID': 971, 'tokenText': 'острая'}], 'After': []},
#  'стрелка': {'Before': [{'ID': 971, 'tokenText': 'стрелка'}], 'After': []},
#  'сердце': {'Before': [{'ID': 971, 'tokenText': 'сердце'},
#    {'ID': 1256, 'tokenText': 'сердца'}],
#   'After': []},
#  'камень': {'Before': [{'ID': 971, 'tokenText': 'камень'},
#    {'ID': 1072, 'tokenText': 'камнем'}],
#   'After': []},
#  'которое': {'Before': [{'ID': 971, 'tokenText': 'которое'}], 'After': []},
#  'упустить': {'Before': [{'ID': 971, 'tokenText': 'упустил'}], 'After': []},
#  'встать': {'Before': [{'ID': 971, 'tokenText': 'встанет'}], 'After': []},
#  'сейчас': {'Before': [{'ID': 971, 'tokenText': 'сейчас'},
#    {'ID': 1169, 'tokenText': 'сейчас'},
#    {'ID': 1256, 'tokenText': 'сейчас'}],
#   'After': []},
#  'сторона': {'Before': [{'ID': 971, 'tokenText': 'сторону'}], 'After': []},
#  '---': {'Before': [{'ID': 971, 'tokenText': '---'}], 'After': []},
#  'личный': {'Before': [{'ID': 971, 'tokenText': 'Личный'},
#    {'ID': 1072, 'tokenText': 'личного'},
#    {'ID': 1160, 'tokenText': 'личного'}],
#   'After': []},
#  'блог': {'Before': [{'ID': 971, 'tokenText': 'блог'},
#    {'ID': 1072, 'tokenText': 'блога'},
#    {'ID': 1082, 'tokenText': 'блог'},
#    {'ID': 1160, 'tokenText': 'блога'}],
#   'After': []},
#  'автор': {'Before': [{'ID': 971, 'tokenText': 'автора'},
#    {'ID': 933, 'tokenText': 'автором'},
#    {'ID': 1072, 'tokenText': 'автора'}],
#   'After': []},
#  '#': {'Before': [{'ID': 971, 'tokenText': '#'},
#    {'ID': 1064, 'tokenText': '#'},
#    {'ID': 1072, 'tokenText': '#'},
#    {'ID': 1082, 'tokenText': '#'},
#    {'ID': 1160, 'tokenText': '#'},
#    {'ID': 1169, 'tokenText': '#'},
#    {'ID': 1256, 'tokenText': '#'}],
#   'After': []},
#  'выбор_родионова_алексея': {'Before': [{'ID': 971,
#     'tokenText': 'выбор_Родионова_Алексея'}],
#   'After': []},
#  'сорная': {'Before': [{'ID': 933, 'tokenText': 'СОРНАЯ'}], 'After': []},
#  'сказка': {'Before': [{'ID': 933, 'tokenText': 'СКАЗКА'}], 'After': []},
#  'надышаться': {'Before': [{'ID': 933, 'tokenText': 'Надышалась'}],
#   'After': []},
#  'крапива': {'Before': [{'ID': 933, 'tokenText': 'крапива'}], 'After': []},
#  'озон': {'Before': [{'ID': 933, 'tokenText': 'озоном'}], 'After': []},
#  'к': {'Before': [{'ID': 933, 'tokenText': 'к'},
#    {'ID': 1105, 'tokenText': 'к'},
#    {'ID': 1169, 'tokenText': 'к'},
#    {'ID': 1256, 'tokenText': 'к'}],
#   'After': []},
#  'человечий': {'Before': [{'ID': 933, 'tokenText': 'человечьим'}],
#   'After': []},
#  'перст': {'Before': [{'ID': 933, 'tokenText': 'перстам'}], 'After': []},
#  'податься': {'Before': [{'ID': 933, 'tokenText': 'подалась'}], 'After': []},
#  'зажить': {'Before': [{'ID': 933, 'tokenText': 'зажила'}], 'After': []},
#  'по': {'Before': [{'ID': 933, 'tokenText': 'по'},
#    {'ID': 1064, 'tokenText': 'по'},
#    {'ID': 1105, 'tokenText': 'по'},
#    {'ID': 1169, 'tokenText': 'по'},
#    {'ID': 1256, 'tokenText': 'по'}],
#   'After': []},
#  'неверный': {'Before': [{'ID': 933, 'tokenText': 'неверным'}], 'After': []},
#  'закон': {'Before': [{'ID': 933, 'tokenText': 'законам'}], 'After': []},
#  'то': {'Before': [{'ID': 933, 'tokenText': 'то'},
#    {'ID': 1064, 'tokenText': 'то'},
#    {'ID': 1105, 'tokenText': 'то'},
#    {'ID': 1256, 'tokenText': 'то'}],
#   'After': []},
#  'роса': {'Before': [{'ID': 933, 'tokenText': 'росу'}], 'After': []},
#  'утирать': {'Before': [{'ID': 933, 'tokenText': 'утирая'}], 'After': []},
#  'грязь': {'Before': [{'ID': 933, 'tokenText': 'грязь'}], 'After': []},
#  'там': {'Before': [{'ID': 933, 'tokenText': 'там'},
#    {'ID': 1072, 'tokenText': 'там'},
#    {'ID': 1256, 'tokenText': 'там'}],
#   'After': []},
#  'где': {'Before': [{'ID': 933, 'tokenText': 'где'},
#    {'ID': 1064, 'tokenText': 'где'},
#    {'ID': 1072, 'tokenText': 'где'},
#    {'ID': 1105, 'tokenText': 'где'},
#    {'ID': 1256, 'tokenText': 'Где'}],
#   'After': []},
#  'крепнуть': {'Before': [{'ID': 933, 'tokenText': 'крепнут'}], 'After': []},
#  'людской': {'Before': [{'ID': 933, 'tokenText': 'людские'}], 'After': []},
#  'побег': {'Before': [{'ID': 933, 'tokenText': 'побеги'}], 'After': []},
#  'род': {'Before': [{'ID': 933, 'tokenText': 'род'}], 'After': []},
#  'стена': {'Before': [{'ID': 933, 'tokenText': 'стена'},
#    {'ID': 1105, 'tokenText': 'стене'}],
#   'After': []},
#  '...': {'Before': [{'ID': 933, 'tokenText': '...'},
#    {'ID': 1256, 'tokenText': '...'}],
#   'After': []},
#  '"': {'Before': [{'ID': 933, 'tokenText': '«'},
#    {'ID': 1169, 'tokenText': '«'},
#    {'ID': 1256, 'tokenText': '"'}],
#   'After': []},
#  'этот': {'Before': [{'ID': 933, 'tokenText': 'Этой'},
#    {'ID': 1072, 'tokenText': 'эта'},
#    {'ID': 1105, 'tokenText': 'этой'},
#    {'ID': 1256, 'tokenText': 'этими'}],
#   'After': []},
#  'ночь': {'Before': [{'ID': 933, 'tokenText': 'ночью'},
#    {'ID': 1256, 'tokenText': 'ночь'}],
#   'After': []},
#  'ваш': {'Before': [{'ID': 933, 'tokenText': 'вашем'}], 'After': []},
#  'ночлег': {'Before': [{'ID': 933, 'tokenText': 'ночлеге'}], 'After': []},
#  'с': {'Before': [{'ID': 933, 'tokenText': 'с'},
#    {'ID': 1072, 'tokenText': 'с'},
#    {'ID': 1105, 'tokenText': 'с'},
#    {'ID': 1169, 'tokenText': 'с'},
#    {'ID': 1256, 'tokenText': 'с'}],
#   'After': []},
#  'тем': {'Before': [{'ID': 933, 'tokenText': 'тем'},
#    {'ID': 1256, 'tokenText': 'тем'}],
#   'After': []},
#  'лечь': {'Before': [{'ID': 933, 'tokenText': 'лягу'}], 'After': []},
#  'кто': {'Before': [{'ID': 933, 'tokenText': 'кто'},
#    {'ID': 1169, 'tokenText': 'кому'},
#    {'ID': 1256, 'tokenText': 'кто'}],
#   'After': []},
#  '—': {'Before': [{'ID': 933, 'tokenText': '—'}], 'After': []},
#  'бывать': {'Before': [{'ID': 933, 'tokenText': 'бывать'},
#    {'ID': 1256, 'tokenText': 'бывает'}],
#   'After': []},
#  'тебе': {'Before': [{'ID': 933, 'tokenText': 'тебе'}], 'After': []},
#  'наш': {'Before': [{'ID': 933, 'tokenText': 'наших'},
#    {'ID': 1072, 'tokenText': 'наши'},
#    {'ID': 1082, 'tokenText': 'нашем'},
#    {'ID': 1105, 'tokenText': 'нашей'},
#    {'ID': 1160, 'tokenText': 'нашей'}],
#   'After': []},
#  'кровь': {'Before': [{'ID': 933, 'tokenText': 'кровей'},
#    {'ID': 1105, 'tokenText': 'кровью'}],
#   'After': []},
#  'любить': {'Before': [{'ID': 933, 'tokenText': 'любить'},
#    {'ID': 1072, 'tokenText': 'любим'}],
#   'After': []},
#  'у': {'Before': [{'ID': 933, 'tokenText': 'у'},
#    {'ID': 1072, 'tokenText': 'у'},
#    {'ID': 1169, 'tokenText': 'у'},
#    {'ID': 1256, 'tokenText': 'у'}],
#   'After': []},
#  'крутой': {'Before': [{'ID': 933, 'tokenText': 'крутого'}], 'After': []},
#  'обрыв': {'Before': [{'ID': 933, 'tokenText': 'обрыва'}], 'After': []},
#  'благородный': {'Before': [{'ID': 933, 'tokenText': 'благородных'}],
#   'After': []},
#  'сын': {'Before': [{'ID': 933, 'tokenText': 'сыновей'},
#    {'ID': 1169, 'tokenText': 'сын'}],
#   'After': []},
#  'трать': {'Before': [{'ID': 933, 'tokenText': 'трать'}], 'After': []},
#  'свой': {'Before': [{'ID': 933, 'tokenText': 'своё'},
#    {'ID': 1082, 'tokenText': 'своим'},
#    {'ID': 1105, 'tokenText': 'своей'},
#    {'ID': 1256, 'tokenText': 'своим'}],
#   'After': []},
#  'сорный': {'Before': [{'ID': 933, 'tokenText': 'сорное'}], 'After': []},
#  'лоно': {'Before': [{'ID': 933, 'tokenText': 'лоно'}], 'After': []},
#  'проказа': {'Before': [{'ID': 933, 'tokenText': 'проказы'}], 'After': []},
#  'хоть': {'Before': [{'ID': 933, 'tokenText': 'хоть'}], 'After': []},
#  'об': {'Before': [{'ID': 933, 'tokenText': 'об'}], 'After': []},
#  'лоб': {'Before': [{'ID': 933, 'tokenText': 'лбом'}], 'After': []},
#  'сколь': {'Before': [{'ID': 933, 'tokenText': 'Сколь'}], 'After': []},
#  'ни': {'Before': [{'ID': 933, 'tokenText': 'ни'},
#    {'ID': 1072, 'tokenText': 'ни'},
#    {'ID': 1169, 'tokenText': 'ни'},
#    {'ID': 1256, 'tokenText': 'ни'}],
#   'After': []},
#  'жгуча': {'Before': [{'ID': 933, 'tokenText': 'жгуча'}], 'After': []},
#  'твой': {'Before': [{'ID': 933, 'tokenText': 'твоя'},
#    {'ID': 1160, 'tokenText': 'твоего'}],
#   'After': []},
#  'оборона': {'Before': [{'ID': 933, 'tokenText': 'оборона'}], 'After': []},
#  'мы': {'Before': [{'ID': 933, 'tokenText': 'мы'},
#    {'ID': 1072, 'tokenText': 'мы'},
#    {'ID': 1105, 'tokenText': 'мы'},
#    {'ID': 1169, 'tokenText': 'мы'},
#    {'ID': 1256, 'tokenText': 'мы'}],
#   'After': []},
#  'приласкаем': {'Before': [{'ID': 933, 'tokenText': 'приласкаем'}],
#   'After': []},
#  'серп': {'Before': [{'ID': 933, 'tokenText': 'серпом'}], 'After': []},
#  '!': {'Before': [{'ID': 933, 'tokenText': '!'},
#    {'ID': 1064, 'tokenText': '!'},
#    {'ID': 1072, 'tokenText': '!'},
#    {'ID': 1256, 'tokenText': '!'}],
#   'After': []},
#  'приходить': {'Before': [{'ID': 933, 'tokenText': 'приходит'}], 'After': []},
#  'изгнанник': {'Before': [{'ID': 933, 'tokenText': 'изгнанник'}], 'After': []},
#  'оттуда': {'Before': [{'ID': 933, 'tokenText': 'оттуда'}], 'After': []},
#  'лишь': {'Before': [{'ID': 933, 'tokenText': 'лишь'},
#    {'ID': 1256, 'tokenText': 'лишь'}],
#   'After': []},
#  'солнце': {'Before': [{'ID': 933, 'tokenText': 'солнце'},
#    {'ID': 1256, 'tokenText': 'солнцу'}],
#   'After': []},
#  'полдень': {'Before': [{'ID': 933, 'tokenText': 'полудню'},
#    {'ID': 1072, 'tokenText': 'полдень'}],
#   'After': []},
#  'расти': {'Before': [{'ID': 933, 'tokenText': 'растёт'}], 'After': []},
#  'зелень': {'Before': [{'ID': 933, 'tokenText': 'зелень'}], 'After': []},
#  'надежда': {'Before': [{'ID': 933, 'tokenText': 'надеждой'}], 'After': []},
#  'чудо': {'Before': [{'ID': 933, 'tokenText': 'чудо'}], 'After': []},
#  'под': {'Before': [{'ID': 933, 'tokenText': 'под'},
#    {'ID': 1072, 'tokenText': 'под'}],
#   'After': []},
#  'шуметь': {'Before': [{'ID': 933, 'tokenText': 'шумящий'}], 'After': []},
#  'дождь': {'Before': [{'ID': 933, 'tokenText': 'дождём'}], 'After': []},
#  'небосвод': {'Before': [{'ID': 933, 'tokenText': 'небосвод'}], 'After': []},
#  'теплокровье': {'Before': [{'ID': 933, 'tokenText': 'теплокровье'}],
#   'After': []},
#  'ночной': {'Before': [{'ID': 933, 'tokenText': 'ночное'},
#    {'ID': 1105, 'tokenText': 'ночном'}],
#   'After': []},
#  'дыхание': {'Before': [{'ID': 933, 'tokenText': 'дыханье'}], 'After': []},
#  'родство': {'Before': [{'ID': 933, 'tokenText': 'родства'}], 'After': []},
#  'плодоносный': {'Before': [{'ID': 933, 'tokenText': 'плодоносное'}],
#   'After': []},
#  'семя': {'Before': [{'ID': 933, 'tokenText': 'семя'}], 'After': []},
#  'мужской': {'Before': [{'ID': 933, 'tokenText': 'мужское'}], 'After': []},
#  'выбирать': {'Before': [{'ID': 933, 'tokenText': 'выбираю'}], 'After': []},
#  'живой': {'Before': [{'ID': 933, 'tokenText': 'жива'},
#    {'ID': 1105, 'tokenText': 'живые'}],
#   'After': []},
#  'любовь': {'Before': [{'ID': 933, 'tokenText': 'любовь'}], 'After': []},
#  'жёлтый': {'Before': [{'ID': 933, 'tokenText': 'жёлтая'}], 'After': []},
#  'глина': {'Before': [{'ID': 933, 'tokenText': 'глина'}], 'After': []},
#  'злой': {'Before': [{'ID': 933, 'tokenText': 'злые'}], 'After': []},
#  'брызги': {'Before': [{'ID': 933, 'tokenText': 'брызги'}], 'After': []},
#  'болотный': {'Before': [{'ID': 933, 'tokenText': 'болотного'},
#    {'ID': 1105, 'tokenText': 'болотной'}],
#   'After': []},
#  'мох': {'Before': [{'ID': 933, 'tokenText': 'мха'}], 'After': []},
#  'твердь': {'Before': [{'ID': 933, 'tokenText': 'тверди'},
#    {'ID': 1105, 'tokenText': 'тверди'}],
#   'After': []},
#  'от': {'Before': [{'ID': 933, 'tokenText': 'от'},
#    {'ID': 1105, 'tokenText': 'от'},
#    {'ID': 1169, 'tokenText': 'от'},
#    {'ID': 1256, 'tokenText': 'от'}],
#   'After': []},
#  'век': {'Before': [{'ID': 933, 'tokenText': 'века'}], 'After': []},
#  'невинный': {'Before': [{'ID': 933, 'tokenText': 'невинна'}], 'After': []},
#  'средь': {'Before': [{'ID': 933, 'tokenText': 'средь'}], 'After': []},
#  'осот': {'Before': [{'ID': 933, 'tokenText': 'осота'}], 'After': []},
#  'вьюнок': {'Before': [{'ID': 933, 'tokenText': 'вьюнка'}], 'After': []},
#  'лопух': {'Before': [{'ID': 933, 'tokenText': 'лопуха'}], 'After': []},
#  'верить': {'Before': [{'ID': 933, 'tokenText': 'верим'},
#    {'ID': 1105, 'tokenText': 'Верю'}],
#   'After': []},
#  'стёртый': {'Before': [{'ID': 933, 'tokenText': 'стёртый'}], 'After': []},
#  'ржавый': {'Before': [{'ID': 933, 'tokenText': 'ржавый'},
#    {'ID': 1105, 'tokenText': 'ржавых'}],
#   'After': []},
#  'ломаный': {'Before': [{'ID': 933, 'tokenText': 'ломаный'}], 'After': []},
#  'грош': {'Before': [{'ID': 933, 'tokenText': 'грош'}], 'After': []},
#  'ткнись': {'Before': [{'ID': 933, 'tokenText': 'Ткнись'}], 'After': []},
#  'трава': {'Before': [{'ID': 933, 'tokenText': 'траву'}], 'After': []},
#  'беспородною': {'Before': [{'ID': 933, 'tokenText': 'беспородною'}],
#   'After': []},
#  'морда': {'Before': [{'ID': 933, 'tokenText': 'мордой'}], 'After': []},
#  'сказать': {'Before': [{'ID': 933, 'tokenText': 'скажи'},
#    {'ID': 1256, 'tokenText': 'сказал'}],
#   'After': []},
#  'сколько': {'Before': [{'ID': 933, 'tokenText': 'сколько'},
#    {'ID': 1169, 'tokenText': 'сколько'}],
#   'After': []},
#  'берёшь': {'Before': [{'ID': 933, 'tokenText': 'берёшь'}], 'After': []},
#  'брать': {'Before': [{'ID': 933, 'tokenText': 'беру'},
#    {'ID': 1082, 'tokenText': 'брать'}],
#   'After': []},
#  'земля': {'Before': [{'ID': 933, 'tokenText': 'землю'},
#    {'ID': 1064, 'tokenText': 'земли'},
#    {'ID': 1105, 'tokenText': 'землей'}],
#   'After': []},
#  'которой': {'Before': [{'ID': 933, 'tokenText': 'которой'}], 'After': []},
#  'вязкий': {'Before': [{'ID': 933, 'tokenText': 'вязкий'}], 'After': []},
#  'сонм': {'Before': [{'ID': 933, 'tokenText': 'сонм'}], 'After': []},
#  'рыболовный': {'Before': [{'ID': 933, 'tokenText': 'рыболовных'}],
#   'After': []},
#  'червь': {'Before': [{'ID': 933, 'tokenText': 'червей'}], 'After': []},
#  'окно': {'Before': [{'ID': 933, 'tokenText': 'окна'}], 'After': []},
#  'виноградный': {'Before': [{'ID': 933, 'tokenText': 'виноградною'}],
#   'After': []},
#  'штора': {'Before': [{'ID': 933, 'tokenText': 'шторой'}], 'After': []},
#  'домовой': {'Before': [{'ID': 933, 'tokenText': 'домовой'}], 'After': []},
#  'котофей': {'Before': [{'ID': 933, 'tokenText': 'котофей'}], 'After': []},
#  'родник': {'Before': [{'ID': 933, 'tokenText': 'родник'}], 'After': []},
#  'песня': {'Before': [{'ID': 933, 'tokenText': 'песню'}], 'After': []},
#  'стрекотать': {'Before': [{'ID': 933, 'tokenText': 'стрекочет'}],
#   'After': []},
#  'сверчок': {'Before': [{'ID': 933, 'tokenText': 'сверчок'}], 'After': []},
#  'повторять': {'Before': [{'ID': 933, 'tokenText': 'повторяет'},
#    {'ID': 1256, 'tokenText': 'повторяли'}],
#   'After': []},
#  'мотив': {'Before': [{'ID': 933, 'tokenText': 'мотив'}], 'After': []},
#  'выводить': {'Before': [{'ID': 933, 'tokenText': 'выводит'}], 'After': []},
#  'нитяный': {'Before': [{'ID': 933, 'tokenText': 'нитяный'}], 'After': []},
#  'почерк': {'Before': [{'ID': 933, 'tokenText': 'почерк'}], 'After': []},
#  'шелкопряд': {'Before': [{'ID': 933, 'tokenText': 'шелкопряд'}], 'After': []},
#  'кружева': {'Before': [{'ID': 933, 'tokenText': 'кружева'}], 'After': []},
#  'распустить': {'Before': [{'ID': 933, 'tokenText': 'распустив'}],
#   'After': []},
#  'травяной': {'Before': [{'ID': 933, 'tokenText': 'травяных'}], 'After': []},
#  'древесный': {'Before': [{'ID': 933, 'tokenText': 'древесных'}], 'After': []},
#  'обитель': {'Before': [{'ID': 933, 'tokenText': 'обители'}], 'After': []},
#  'из': {'Before': [{'ID': 933, 'tokenText': 'из'},
#    {'ID': 1072, 'tokenText': 'Из'},
#    {'ID': 1105, 'tokenText': 'из'},
#    {'ID': 1160, 'tokenText': 'Из'},
#    {'ID': 1256, 'tokenText': 'из'}],
#   'After': []},
#  'кирпич': {'Before': [{'ID': 933, 'tokenText': 'кирпича'}], 'After': []},
#  'ищи': {'Before': [{'ID': 933, 'tokenText': 'ищи'}], 'After': []},
#  'утешение': {'Before': [{'ID': 933, 'tokenText': 'утешений'}], 'After': []},
#  'телесный': {'Before': [{'ID': 933, 'tokenText': 'телесных'}], 'After': []},
#  'рука': {'Before': [{'ID': 933, 'tokenText': 'руки'},
#    {'ID': 1105, 'tokenText': 'руки'},
#    {'ID': 1169, 'tokenText': 'руки'}],
#   'After': []},
#  'палач': {'Before': [{'ID': 933, 'tokenText': 'палача'}], 'After': []},
#  'потому': {'Before': [{'ID': 933, 'tokenText': 'Потому'}], 'After': []},
#  'пусть': {'Before': [{'ID': 933, 'tokenText': 'пусть'}], 'After': []},
#  'хороший': {'Before': [{'ID': 933, 'tokenText': 'лучше'},
#    {'ID': 1169, 'tokenText': 'лучшей'},
#    {'ID': 1256, 'tokenText': 'хорошие'}],
#   'After': []},
#  'плохой': {'Before': [{'ID': 933, 'tokenText': 'хуже'}], 'After': []},
#  'грех': {'Before': [{'ID': 933, 'tokenText': 'грех'}], 'After': []},
#  'чужой': {'Before': [{'ID': 933, 'tokenText': 'чужой'}], 'After': []},
#  'себя': {'Before': [{'ID': 933, 'tokenText': 'себя'},
#    {'ID': 1072, 'tokenText': 'себя'},
#    {'ID': 1105, 'tokenText': 'себя'}],
#   'After': []},
#  'бежать': {'Before': [{'ID': 933, 'tokenText': 'бежала'}], 'After': []},
#  'снаружи': {'Before': [{'ID': 933, 'tokenText': 'снаружи'}], 'After': []},
#  'нас': {'Before': [{'ID': 933, 'tokenText': 'нас'},
#    {'ID': 1105, 'tokenText': 'нас'},
#    {'ID': 1256, 'tokenText': 'нас'}],
#   'After': []},
#  'убивать': {'Before': [{'ID': 933, 'tokenText': 'убивает'}], 'After': []},
#  'внутри': {'Before': [{'ID': 933, 'tokenText': 'внутри'},
#    {'ID': 1256, 'tokenText': 'внутри'}],
#   'After': []},
#  'неужели': {'Before': [{'ID': 933, 'tokenText': 'Неужели'}], 'After': []},
#  'темень': {'Before': [{'ID': 933, 'tokenText': 'темени'}], 'After': []},
#  'выход': {'Before': [{'ID': 933, 'tokenText': 'выхода'}], 'After': []},
#  'нет': {'Before': [{'ID': 933, 'tokenText': 'нет'},
#    {'ID': 1105, 'tokenText': 'Нет'},
#    {'ID': 1169, 'tokenText': 'нет'},
#    {'ID': 1256, 'tokenText': 'нет'}],
#   'After': []},
#  '?': {'Before': [{'ID': 933, 'tokenText': '?'},
#    {'ID': 1105, 'tokenText': '?'},
#    {'ID': 1256, 'tokenText': '?'}],
#   'After': []},
#  'для': {'Before': [{'ID': 933, 'tokenText': 'Для'}], 'After': []},
#  'ж': {'Before': [{'ID': 933, 'tokenText': 'ж'}], 'After': []},
#  'затеять': {'Before': [{'ID': 933, 'tokenText': 'затеян'}], 'After': []},
#  '..': {'Before': [{'ID': 933, 'tokenText': '..'}], 'After': []},
#  'единый': {'Before': [{'ID': 933, 'tokenText': 'единого'}], 'After': []},
#  'слово': {'Before': [{'ID': 933, 'tokenText': 'слова'},
#    {'ID': 1105, 'tokenText': 'слов'}],
#   'After': []},
#  'ответ': {'Before': [{'ID': 933, 'tokenText': 'ответ'}], 'After': []},
#  '(': {'Before': [{'ID': 933, 'tokenText': '('},
#    {'ID': 1072, 'tokenText': '('},
#    {'ID': 1082, 'tokenText': '('},
#    {'ID': 1160, 'tokenText': '('},
#    {'ID': 1256, 'tokenText': '('}],
#   'After': []},
#  'предоставить': {'Before': [{'ID': 933, 'tokenText': 'Предоставлено'}],
#   'After': []},
#  ')': {'Before': [{'ID': 933, 'tokenText': ')'},
#    {'ID': 1072, 'tokenText': ')'},
#    {'ID': 1082, 'tokenText': ')'},
#    {'ID': 1160, 'tokenText': ')'},
#    {'ID': 1256, 'tokenText': ')'}],
#   'After': []},
#  'рот': {'Before': [{'ID': 1064, 'tokenText': 'рот'},
#    {'ID': 1105, 'tokenText': 'рты'},
#    {'ID': 1169, 'tokenText': 'рта'}],
#   'After': []},
#  'он': {'Before': [{'ID': 1064, 'tokenText': 'он'},
#    {'ID': 1082, 'tokenText': 'он'},
#    {'ID': 1169, 'tokenText': 'он'},
#    {'ID': 1256, 'tokenText': 'он'}],
#   'After': []},
#  'изранить': {'Before': [{'ID': 1064, 'tokenText': 'изранен'}], 'After': []},
#  'эй': {'Before': [{'ID': 1064, 'tokenText': 'эй'}], 'After': []},
#  'чёрный': {'Before': [{'ID': 1064, 'tokenText': 'черным'},
#    {'ID': 1105, 'tokenText': 'черного'},
#    {'ID': 1256, 'tokenText': 'чёрная'}],
#   'After': []},
#  'черно': {'Before': [{'ID': 1064, 'tokenText': 'черно'}], 'After': []},
#  'распускаться': {'Before': [{'ID': 1064, 'tokenText': 'распускается'}],
#   'After': []},
#  'дымок': {'Before': [{'ID': 1064, 'tokenText': 'дымок'}], 'After': []},
#  'хранилище': {'Before': [{'ID': 1064, 'tokenText': 'хранилища'}],
#   'After': []},
#  'слепота': {'Before': [{'ID': 1064, 'tokenText': 'слепоты'}], 'After': []},
#  'а': {'Before': [{'ID': 1064, 'tokenText': 'а'},
#    {'ID': 1072, 'tokenText': 'а'},
#    {'ID': 1082, 'tokenText': 'а'},
#    {'ID': 1105, 'tokenText': 'а'},
#    {'ID': 1169, 'tokenText': 'а'},
#    {'ID': 1256, 'tokenText': 'а'}],
#   'After': []},
#  'над': {'Before': [{'ID': 1064, 'tokenText': 'над'},
#    {'ID': 1072, 'tokenText': 'над'},
#    {'ID': 1105, 'tokenText': 'над'}],
#   'After': []},
#  'ласковый': {'Before': [{'ID': 1064, 'tokenText': 'ласковые'}], 'After': []},
#  'небо': {'Before': [{'ID': 1064, 'tokenText': 'небеса'},
#    {'ID': 1072, 'tokenText': 'неба'},
#    {'ID': 1256, 'tokenText': 'небе'}],
#   'After': []},
#  'размежаются': {'Before': [{'ID': 1064, 'tokenText': 'размежаются'}],
#   'After': []},
#  'кусочек': {'Before': [{'ID': 1064, 'tokenText': 'кусочкам'}], 'After': []},
#  'полосочкам': {'Before': [{'ID': 1064, 'tokenText': 'полосочкам'}],
#   'After': []},
#  'раздвигаться': {'Before': [{'ID': 1064, 'tokenText': 'раздвигаются'}],
#   'After': []},
#  'ними': {'Before': [{'ID': 1064, 'tokenText': 'ними'},
#    {'ID': 1072, 'tokenText': 'ними'}],
#   'After': []},
#  'пасть': {'Before': [{'ID': 1064, 'tokenText': 'пасть'}], 'After': []},
#  'история': {'Before': [{'ID': 1064, 'tokenText': 'истории'}], 'After': []},
#  'клацать': {'Before': [{'ID': 1064, 'tokenText': 'клацает'}], 'After': []},
#  'страшный': {'Before': [{'ID': 1064, 'tokenText': 'страшно'},
#    {'ID': 1105, 'tokenText': 'страшные'}],
#   'After': []},
#  'веко': {'Before': [{'ID': 1064, 'tokenText': 'веки'}], 'After': []},
#  'тяжёлый': {'Before': [{'ID': 1064, 'tokenText': 'тяжелы'}], 'After': []},
#  'взрыв': {'Before': [{'ID': 1064, 'tokenText': 'взрыв'}], 'After': []},
#  'разрыв': {'Before': [{'ID': 1064, 'tokenText': 'разрыв'}], 'After': []},
#  'если': {'Before': [{'ID': 1064, 'tokenText': 'если'},
#    {'ID': 1169, 'tokenText': 'если'},
#    {'ID': 1256, 'tokenText': 'если'}],
#   'After': []},
#  'здесь': {'Before': [{'ID': 1064, 'tokenText': 'здесь'}], 'After': []},
#  '–': {'Before': [{'ID': 1064, 'tokenText': '–'},
#    {'ID': 1256, 'tokenText': '–'}],
#   'After': []},
#  'отзовись': {'Before': [{'ID': 1064, 'tokenText': 'отзовись'}], 'After': []},
#  'между': {'Before': [{'ID': 1064, 'tokenText': 'между'},
#    {'ID': 1256, 'tokenText': 'между'}],
#   'After': []},
#  'нами': {'Before': [{'ID': 1064, 'tokenText': 'нами'}], 'After': []},
#  'дрожать': {'Before': [{'ID': 1064, 'tokenText': 'дрожит'}], 'After': []},
#  'ветер': {'Before': [{'ID': 1064, 'tokenText': 'ветер'}], 'After': []},
#  'тянуться': {'Before': [{'ID': 1064, 'tokenText': 'тянется'}], 'After': []},
#  'сомнение': {'Before': [{'ID': 1064, 'tokenText': 'сомнением'}], 'After': []},
#  'опасение': {'Before': [{'ID': 1064, 'tokenText': 'опасением'}], 'After': []},
#  'знать': {'Before': [{'ID': 1064, 'tokenText': 'знаю'},
#    {'ID': 1169, 'tokenText': 'знаешь'},
#    {'ID': 1256, 'tokenText': 'знаю'}],
#   'After': []},
#  'композиция': {'Before': [{'ID': 1064, 'tokenText': 'композиции'}],
#   'After': []},
#  'но': {'Before': [{'ID': 1064, 'tokenText': 'но'},
#    {'ID': 1169, 'tokenText': 'но'},
#    {'ID': 1256, 'tokenText': 'но'}],
#   'After': []},
#  'помнить': {'Before': [{'ID': 1064, 'tokenText': 'помню'}], 'After': []},
#  'напор': {'Before': [{'ID': 1064, 'tokenText': 'напор'}], 'After': []},
#  'устать': {'Before': [{'ID': 1064, 'tokenText': 'устали'}], 'After': []},
#  'дымиться': {'Before': [{'ID': 1064, 'tokenText': 'дымится'}], 'After': []},
#  'рассвет': {'Before': [{'ID': 1064, 'tokenText': 'рассвет'}], 'After': []},
#  'бесконечный': {'Before': [{'ID': 1064, 'tokenText': 'бесконечный'}],
#   'After': []},
#  'лучезарный': {'Before': [{'ID': 1064, 'tokenText': 'лучезарный'}],
#   'After': []},
#  'слепые': {'Before': [{'ID': 1064, 'tokenText': 'слепые'}], 'After': []},
#  'петь': {'Before': [{'ID': 1064, 'tokenText': 'поют'},
#    {'ID': 1072, 'tokenText': 'поют'}],
#   'After': []},
#  'темнота': {'Before': [{'ID': 1064, 'tokenText': 'темноте'},
#    {'ID': 1105, 'tokenText': 'темноты'}],
#   'After': []},
#  'ком': {'Before': [{'ID': 1064, 'tokenText': 'комья'}], 'After': []},
#  'катить': {'Before': [{'ID': 1064, 'tokenText': 'катят'}], 'After': []},
#  'каменный': {'Before': [{'ID': 1064, 'tokenText': 'каменных'}], 'After': []},
#  'обломать': {'Before': [{'ID': 1064, 'tokenText': 'обломанных'}],
#   'After': []},
#  'снежок': {'Before': [{'ID': 1064, 'tokenText': 'снежок'}], 'After': []},
#  'такой': {'Before': [{'ID': 1064, 'tokenText': 'такой'},
#    {'ID': 1169, 'tokenText': 'такого'}],
#   'After': []},
#  'тихий': {'Before': [{'ID': 1064, 'tokenText': 'тихий'}], 'After': []},
#  'виться': {'Before': [{'ID': 1064, 'tokenText': 'вьется'}], 'After': []},
#  'попадаться': {'Before': [{'ID': 1064, 'tokenText': 'попадается'}],
#   'After': []},
#  'язык': {'Before': [{'ID': 1064, 'tokenText': 'язык'}], 'After': []},
#  'чувствовать': {'Before': [{'ID': 1064, 'tokenText': 'чувствую'}],
#   'After': []},
#  'холод': {'Before': [{'ID': 1064, 'tokenText': 'холод'},
#    {'ID': 1256, 'tokenText': 'холода'}],
#   'After': []},
#  'тёплый': {'Before': [{'ID': 1064, 'tokenText': 'теплую'}], 'After': []},
#  'близость': {'Before': [{'ID': 1064, 'tokenText': 'близость'}], 'After': []},
#  'пахнуть': {'Before': [{'ID': 1064, 'tokenText': 'пахнет'},
#    {'ID': 1072, 'tokenText': 'пахнут'}],
#   'After': []},
#  'вьюга': {'Before': [{'ID': 1064, 'tokenText': 'вьюгой'}], 'After': []},
#  'выбор_зои_фальковой': {'Before': [{'ID': 1064,
#     'tokenText': 'Выбор_Зои_Фальковой'},
#    {'ID': 1082, 'tokenText': 'выбор_Зои_Фальковой'}],
#   'After': []},
#  'выбор_динары_расулевой': {'Before': [{'ID': 1064,
#     'tokenText': 'Выбор_Динары_Расулевой'},
#    {'ID': 1072, 'tokenText': 'выбор_динары_расулевой'},
#    {'ID': 1160, 'tokenText': 'выбор_динары_расулевой'}],
#   'After': []},
#  'выбор_евгения_никитина': {'Before': [{'ID': 1064,
#     'tokenText': 'Выбор_Евгения_Никитина'}],
#   'After': []},
#  'ерке': {'Before': [{'ID': 1072, 'tokenText': 'ерке'}], 'After': []},
#  'помидор': {'Before': [{'ID': 1072, 'tokenText': 'помидоры'}], 'After': []},
#  'луковица': {'Before': [{'ID': 1072, 'tokenText': 'луковицу'}], 'After': []},
#  'выдавить': {'Before': [{'ID': 1072, 'tokenText': 'выдавить'}], 'After': []},
#  'чеснок': {'Before': [{'ID': 1072, 'tokenText': 'чеснок'}], 'After': []},
#  'добавить': {'Before': [{'ID': 1072, 'tokenText': 'Добавить'}], 'After': []},
#  'сахар': {'Before': [{'ID': 1072, 'tokenText': 'сахар'}], 'After': []},
#  'кой': {'Before': [{'ID': 1072, 'tokenText': 'коем'}], 'After': []},
#  'случай': {'Before': [{'ID': 1072, 'tokenText': 'случае'}], 'After': []},
#  'соль': {'Before': [{'ID': 1072, 'tokenText': 'соль'}], 'After': []},
#  'уксус': {'Before': [{'ID': 1072, 'tokenText': 'уксус'}], 'After': []},
#  'подсолнечный': {'Before': [{'ID': 1072, 'tokenText': 'подсолнечное'}],
#   'After': []},
#  'масло': {'Before': [{'ID': 1072, 'tokenText': 'масло'}], 'After': []},
#  'перемешать': {'Before': [{'ID': 1072, 'tokenText': 'Перемешать'}],
#   'After': []},
#  'поставить': {'Before': [{'ID': 1072, 'tokenText': 'Поставить'}],
#   'After': []},
#  'холодильник': {'Before': [{'ID': 1072, 'tokenText': 'холодильник'}],
#   'After': []},
#  'подавать': {'Before': [{'ID': 1072, 'tokenText': 'Подавать'}], 'After': []},
#  'жареный': {'Before': [{'ID': 1072, 'tokenText': 'жареной'}], 'After': []},
#  'рыба': {'Before': [{'ID': 1072, 'tokenText': 'рыбой'}], 'After': []},
#  'стейк': {'Before': [{'ID': 1072, 'tokenText': 'стейком'}], 'After': []},
#  'до': {'Before': [{'ID': 1072, 'tokenText': 'до'},
#    {'ID': 1105, 'tokenText': 'до'},
#    {'ID': 1169, 'tokenText': 'до'}],
#   'After': []},
#  'вкусный': {'Before': [{'ID': 1072, 'tokenText': 'вкусная'}], 'After': []},
#  'летний': {'Before': [{'ID': 1072, 'tokenText': 'летняя'}], 'After': []},
#  'еда': {'Before': [{'ID': 1072, 'tokenText': 'еда'}], 'After': []},
#  'грустный': {'Before': [{'ID': 1072, 'tokenText': 'грустная'}], 'After': []},
#  'облако': {'Before': [{'ID': 1072, 'tokenText': 'облаков'}], 'After': []},
#  'течь': {'Before': [{'ID': 1072, 'tokenText': 'течет'}], 'After': []},
#  'вода': {'Before': [{'ID': 1072, 'tokenText': 'вода'},
#    {'ID': 1105, 'tokenText': 'воде'},
#    {'ID': 1256, 'tokenText': 'вода'}],
#   'After': []},
#  'зелёный': {'Before': [{'ID': 1072, 'tokenText': 'зелеными'}], 'After': []},
#  'курчавый': {'Before': [{'ID': 1072, 'tokenText': 'курчавыми'}], 'After': []},
#  'стадами': {'Before': [{'ID': 1072, 'tokenText': 'стадами'}], 'After': []},
#  'граната': {'Before': [{'ID': 1072, 'tokenText': 'гранатами'}], 'After': []},
#  'лимон': {'Before': [{'ID': 1072, 'tokenText': 'лимонами'}], 'After': []},
#  'военный': {'Before': [{'ID': 1072, 'tokenText': 'военными'}], 'After': []},
#  'плод': {'Before': [{'ID': 1072, 'tokenText': 'плодами'}], 'After': []},
#  'синий': {'Before': [{'ID': 1072, 'tokenText': 'синего'}], 'After': []},
#  'кружиться': {'Before': [{'ID': 1072, 'tokenText': 'кружатся'}], 'After': []},
#  'сокол': {'Before': [{'ID': 1072, 'tokenText': 'соколы'}], 'After': []},
#  'облачный': {'Before': [{'ID': 1072, 'tokenText': 'облачными'}], 'After': []},
#  'батальон': {'Before': [{'ID': 1072, 'tokenText': 'батальонами'}],
#   'After': []},
#  'волокнистый': {'Before': [{'ID': 1072, 'tokenText': 'волокнистыми'}],
#   'After': []},
#  'гряда': {'Before': [{'ID': 1072, 'tokenText': 'грядами'}], 'After': []},
#  'ах': {'Before': [{'ID': 1072, 'tokenText': 'ах'}], 'After': []},
#  'грядка': {'Before': [{'ID': 1072, 'tokenText': 'грядке'}], 'After': []},
#  'полезный': {'Before': [{'ID': 1072, 'tokenText': 'полезные'}], 'After': []},
#  'травка': {'Before': [{'ID': 1072, 'tokenText': 'травки'}], 'After': []},
#  'летать': {'Before': [{'ID': 1072, 'tokenText': 'летают'}], 'After': []},
#  'пчела': {'Before': [{'ID': 1072, 'tokenText': 'пчелы'}], 'After': []},
#  'муха': {'Before': [{'ID': 1072, 'tokenText': 'мухи'}], 'After': []},
# ...
#   'After': []},
#  'https://doxajournal.ru/uni/harassment/poem?fbclid=iwar3x_d8zltk_zgwem-rd2z2vbaikjbakn6mrgaskvfi_9zt0jafbeiwt01q': {'Before': [{'ID': 1169,
#     'tokenText': 'https://doxajournal.ru/uni/harassment/poem?fbclid=IwAR3X_d8ZlTk_zgwem-rD2Z2vBAiKjbaKN6mrGaskvFi_9zT0JaFBeiWt01Q'}],
#   'After': []},
#  'выбор_романа_осьминкина': {'Before': [{'ID': 1169,
#     'tokenText': 'выбор_Романа_Осьминкина'}],
#   'After': []},
#  'возможность': {'Before': [{'ID': 1256, 'tokenText': 'возможность'}],
#   'After': []},
#  'существование': {'Before': [{'ID': 1256, 'tokenText': 'существования'}],
#   'After': []},
#  'кроме': {'Before': [{'ID': 1256, 'tokenText': 'кроме'}], 'After': []},
#  'точка': {'Before': [{'ID': 1256, 'tokenText': 'точками'}], 'After': []},
#  'совсем': {'Before': [{'ID': 1256, 'tokenText': 'Совсем'}], 'After': []},
#  'рисунок': {'Before': [{'ID': 1256, 'tokenText': 'рисунок'}], 'After': []},
#  'вырезать': {'Before': [{'ID': 1256, 'tokenText': 'вырезанный'}],
#   'After': []},
#  'иллюзия': {'Before': [{'ID': 1256, 'tokenText': 'иллюзий'}], 'After': []},
#  'ницше': {'Before': [{'ID': 1256, 'tokenText': 'Ницше'}], 'After': []},
#  'несчастный': {'Before': [{'ID': 1256, 'tokenText': 'несчастный'}],
#   'After': []},
#  'волочить': {'Before': [{'ID': 1256, 'tokenText': 'волочащий'}], 'After': []},
#  'телега': {'Before': [{'ID': 1256, 'tokenText': 'телегу'}], 'After': []},
#  'улица': {'Before': [{'ID': 1256, 'tokenText': 'улице'}], 'After': []},
#  'родственник': {'Before': [{'ID': 1256, 'tokenText': 'родственник'}],
#   'After': []},
#  'хлебнуть': {'Before': [{'ID': 1256, 'tokenText': 'хлебнувший'}],
#   'After': []},
#  'горе': {'Before': [{'ID': 1256, 'tokenText': 'горя'}], 'After': []},
#  'старушка': {'Before': [{'ID': 1256, 'tokenText': 'Старушка'}], 'After': []},
#  'пенсионерка': {'Before': [{'ID': 1256, 'tokenText': 'пенсионерка'}],
#   'After': []},
#  'соседний': {'Before': [{'ID': 1256, 'tokenText': 'соседней'}], 'After': []},
#  'комната': {'Before': [{'ID': 1256, 'tokenText': 'комнаты'}], 'After': []},
#  'ахать': {'Before': [{'ID': 1256, 'tokenText': 'ахала'}], 'After': []},
#  'охать': {'Before': [{'ID': 1256, 'tokenText': 'охала'}], 'After': []},
#  'оказываться': {'Before': [{'ID': 1256, 'tokenText': 'оказывается'}],
#   'After': []},
#  'правительство': {'Before': [{'ID': 1256, 'tokenText': 'правительство'}],
#   'After': []},
#  'удалить': {'Before': [{'ID': 1256, 'tokenText': 'удалило'}], 'After': []},
#  'пенсионер': {'Before': [{'ID': 1256, 'tokenText': 'пенсионеров'}],
#   'After': []},
#  'оралманов': {'Before': [{'ID': 1256, 'tokenText': 'оралманов'}],
#   'After': []},
#  'список': {'Before': [{'ID': 1256, 'tokenText': 'списков'}], 'After': []},
#  'распределение': {'Before': [{'ID': 1256, 'tokenText': 'распределение'}],
#   'After': []},
#  'давно': {'Before': [{'ID': 1256, 'tokenText': 'давно'}], 'After': []},
#  'видеть': {'Before': [{'ID': 1256, 'tokenText': 'видели'}], 'After': []},
#  'перелётный': {'Before': [{'ID': 1256, 'tokenText': 'перелётных'}],
#   'After': []},
#  'птица': {'Before': [{'ID': 1256, 'tokenText': 'птиц'}], 'After': []},
#  'большой': {'Before': [{'ID': 1256, 'tokenText': 'большому'}], 'After': []},
#  'счёт': {'Before': [{'ID': 1256, 'tokenText': 'счёту'}], 'After': []},
#  'событие': {'Before': [{'ID': 1256, 'tokenText': 'событие'}], 'After': []},
#  'сравнение': {'Before': [{'ID': 1256, 'tokenText': 'сравнение'}],
#   'After': []},
#  'снова': {'Before': [{'ID': 1256, 'tokenText': 'Снова'}], 'After': []},
#  'всё': {'Before': [{'ID': 1256, 'tokenText': 'всё'}], 'After': []},
#  'нечаянно': {'Before': [{'ID': 1256, 'tokenText': 'нечаянно'}], 'After': []},
#  'разрушить': {'Before': [{'ID': 1256, 'tokenText': 'разрушенный'}],
#   'After': []},
#  'рухнуть': {'Before': [{'ID': 1256, 'tokenText': 'рухнувшим'}], 'After': []},
#  'советский': {'Before': [{'ID': 1256, 'tokenText': 'Советским'}],
#   'After': []},
#  'союз': {'Before': [{'ID': 1256, 'tokenText': 'Союзом'}], 'After': []},
#  'было': {'Before': [{'ID': 1256, 'tokenText': 'было'}], 'After': []},
#  'да': {'Before': [{'ID': 1256, 'tokenText': 'Да'}], 'After': []},
#  'здравствовать': {'Before': [{'ID': 1256, 'tokenText': 'здравствует'}],
#   'After': []},
#  'партия': {'Before': [{'ID': 1256, 'tokenText': 'Партия'}], 'After': []},
#  'словно': {'Before': [{'ID': 1256, 'tokenText': 'словно'}], 'After': []},
#  'хайль': {'Before': [{'ID': 1256, 'tokenText': 'Хайль'}], 'After': []},
#  'гитлер': {'Before': [{'ID': 1256, 'tokenText': 'Гитлер'}], 'After': []},
#  'неплохой': {'Before': [{'ID': 1256, 'tokenText': 'неплохо'}], 'After': []},
#  'делать': {'Before': [{'ID': 1256, 'tokenText': 'делай'}], 'After': []},
#  'хотеть': {'Before': [{'ID': 1256, 'tokenText': 'хочешь'}], 'After': []},
#  'деньга': {'Before': [{'ID': 1256, 'tokenText': 'деньги'}], 'After': []},
#  'вчера': {'Before': [{'ID': 1256, 'tokenText': 'Вчера'}], 'After': []},
#  'идём': {'Before': [{'ID': 1256, 'tokenText': 'идём'}], 'After': []},
#  'мечеть': {'Before': [{'ID': 1256, 'tokenText': 'мечеть'}], 'After': []},
#  'потом': {'Before': [{'ID': 1256, 'tokenText': 'потом'}], 'After': []},
#  'сирия': {'Before': [{'ID': 1256, 'tokenText': 'Сирию'}], 'After': []},
#  'платить': {'Before': [{'ID': 1256, 'tokenText': 'платят'}], 'After': []},
#  'восемьсот': {'Before': [{'ID': 1256, 'tokenText': 'восемьсот'}],
#   'After': []},
#  'доллар': {'Before': [{'ID': 1256, 'tokenText': 'долларов'}], 'After': []},
#  'месяц': {'Before': [{'ID': 1256, 'tokenText': 'месяц'}], 'After': []},
#  'задумываться': {'Before': [{'ID': 1256, 'tokenText': 'задумываясь'}],
#   'After': []},
#  'отказаться': {'Before': [{'ID': 1256, 'tokenText': 'отказался'}],
#   'After': []},
#  'чуть': {'Before': [{'ID': 1256, 'tokenText': 'чуть'}], 'After': []},
#  'украина': {'Before': [{'ID': 1256, 'tokenText': 'Украине'}], 'After': []},
#  'воевать': {'Before': [{'ID': 1256, 'tokenText': 'воевать'}], 'After': []},
#  'готовый': {'Before': [{'ID': 1256, 'tokenText': 'готов'}], 'After': []},
#  'защищать': {'Before': [{'ID': 1256, 'tokenText': 'защищать'}], 'After': []},
#  'русский': {'Before': [{'ID': 1256, 'tokenText': 'русский'}], 'After': []},
#  'велика': {'Before': [{'ID': 1256, 'tokenText': 'Велика'}], 'After': []},
#  'россия': {'Before': [{'ID': 1256, 'tokenText': 'Россия'}], 'After': []},
#  'отступать': {'Before': [{'ID': 1256, 'tokenText': 'отступать'}],
#   'After': []},
#  'некуда': {'Before': [{'ID': 1256, 'tokenText': 'некуда'}], 'After': []},
#  'позади': {'Before': [{'ID': 1256, 'tokenText': 'позади'}], 'After': []},
#  'москва': {'Before': [{'ID': 1256, 'tokenText': 'Москва'}], 'After': []},
#  'какой': {'Before': [{'ID': 1256, 'tokenText': 'какое'}], 'After': []},
#  'выражение': {'Before': [{'ID': 1256, 'tokenText': 'выражение'}],
#   'After': []},
#  'его': {'Before': [{'ID': 1256, 'tokenText': 'его'}], 'After': []},
#  'распад': {'Before': [{'ID': 1256, 'tokenText': 'распада'}], 'After': []},
#  'ссср': {'Before': [{'ID': 1256, 'tokenText': 'СССР'}], 'After': []},
#  'смогут': {'Before': [{'ID': 1256, 'tokenText': 'Смогут'}], 'After': []},
#  'русские': {'Before': [{'ID': 1256, 'tokenText': 'русские'}], 'After': []},
#  'услышать': {'Before': [{'ID': 1256, 'tokenText': 'услышать'}], 'After': []},
#  'скрип': {'Before': [{'ID': 1256, 'tokenText': 'скрип'}], 'After': []},
#  'льдина': {'Before': [{'ID': 1256, 'tokenText': 'льдины'}], 'After': []},
#  'дрейфовать': {'Before': [{'ID': 1256, 'tokenText': 'дрейфующей'}],
#   'After': []},
#  'гладь': {'Before': [{'ID': 1256, 'tokenText': 'глади'}], 'After': []},
#  'смочь': {'Before': [{'ID': 1256, 'tokenText': 'смогут'}], 'After': []},
#  'слышать': {'Before': [{'ID': 1256, 'tokenText': 'слышит'}], 'After': []},
#  'слева': {'Before': [{'ID': 1256, 'tokenText': 'слева'}], 'After': []},
#  'справа': {'Before': [{'ID': 1256, 'tokenText': 'справа'}], 'After': []},
#  'человек': {'Before': [{'ID': 1256, 'tokenText': 'человек'}], 'After': []},
#  'написать': {'Before': [{'ID': 1256, 'tokenText': 'написал'}], 'After': []},
#  'казах': {'Before': [{'ID': 1256, 'tokenText': 'казах'}], 'After': []},
#  'умирать': {'Before': [{'ID': 1256, 'tokenText': 'умирал'}], 'After': []},
#  'рождаться': {'Before': [{'ID': 1256, 'tokenText': 'рождался'}], 'After': []},
#  'тысяча': {'Before': [{'ID': 1256, 'tokenText': 'тысячу'}], 'After': []},
#  'возможно': {'Before': [{'ID': 1256, 'tokenText': 'Возможно'}], 'After': []},
#  'него': {'Before': [{'ID': 1256, 'tokenText': 'него'}], 'After': []},
#  'наверное': {'Before': [{'ID': 1256, 'tokenText': 'наверное'}], 'After': []},
#  'перепутаться': {'Before': [{'ID': 1256, 'tokenText': 'перепуталось'}],
#   'After': []},
#  'визжать': {'Before': [{'ID': 1256, 'tokenText': 'визжал'}], 'After': []},
#  'растягивать': {'Before': [{'ID': 1256, 'tokenText': 'растягивая'}],
#   'After': []},
#  'глотка': {'Before': [{'ID': 1256, 'tokenText': 'глотку'}], 'After': []},
#  'ведь': {'Before': [{'ID': 1256, 'tokenText': 'ведь'}], 'After': []},
#  'создаваться': {'Before': [{'ID': 1256, 'tokenText': 'создаётся'}],
#   'After': []},
#  'один': {'Before': [{'ID': 1256, 'tokenText': 'один'}], 'After': []},
#  'пиши': {'Before': [{'ID': 1256, 'tokenText': 'Пиши'}], 'After': []},
#  'ему': {'Before': [{'ID': 1256, 'tokenText': 'ему'}], 'After': []},
#  'понадобиться': {'Before': [{'ID': 1256, 'tokenText': 'понадобится'}],
#   'After': []},
#  'бы': {'Before': [{'ID': 1256, 'tokenText': 'бы'}], 'After': []},
#  'назвать': {'Before': [{'ID': 1256, 'tokenText': 'назвать'}], 'After': []},
#  'ворона': {'Before': [{'ID': 1256, 'tokenText': 'ворону'}], 'After': []},
#  'например': {'Before': [{'ID': 1256, 'tokenText': 'Например'}], 'After': []},
#  'насчёт': {'Before': [{'ID': 1256, 'tokenText': 'насчёт'}], 'After': []},
#  'сталин': {'Before': [{'ID': 1256, 'tokenText': 'Сталина'}], 'After': []},
#  'дольше': {'Before': [{'ID': 1256, 'tokenText': 'дольше'}], 'After': []},
#  'ленин': {'Before': [{'ID': 1256, 'tokenText': 'Ленина'}], 'After': []},
#  'накаркает': {'Before': [{'ID': 1256, 'tokenText': 'накаркает'}],
#   'After': []},
#  'беда': {'Before': [{'ID': 1256, 'tokenText': 'беду'}], 'After': []},
#  'всегда': {'Before': [{'ID': 1256, 'tokenText': 'всегда'}], 'After': []},
#  'рядом': {'Before': [{'ID': 1256, 'tokenText': 'рядом'}], 'After': []},
#  'вампир': {'Before': [{'ID': 1256, 'tokenText': 'вампиром'}], 'After': []},
#  'ведьма': {'Before': [{'ID': 1256, 'tokenText': 'ведьмой'}], 'After': []},
#  'чушь': {'Before': [{'ID': 1256, 'tokenText': 'чушь'}], 'After': []},
#  'правильно': {'Before': [{'ID': 1256, 'tokenText': 'правильно'}],
#   'After': []},
#  'стремиться': {'Before': [{'ID': 1256, 'tokenText': 'стремимся'}],
#   'After': []},
#  'приукрашивать': {'Before': [{'ID': 1256, 'tokenText': 'приукрашивать'}],
#   'After': []},
#  'мочь': {'Before': [{'ID': 1256, 'tokenText': 'можем'}], 'After': []},
#  'преувеличивать': {'Before': [{'ID': 1256, 'tokenText': 'преувеличивать'}],
#   'After': []},
#  'орёл': {'Before': [{'ID': 1256, 'tokenText': 'орёл'}], 'After': []},
#  'выходить': {'Before': [{'ID': 1256, 'tokenText': 'выходит'}], 'After': []},
#  'самрук': {'Before': [{'ID': 1256, 'tokenText': 'самрук'}], 'After': []},
#  'одно': {'Before': [{'ID': 1256, 'tokenText': 'одно'}], 'After': []},
#  'место': {'Before': [{'ID': 1256, 'tokenText': 'место'}], 'After': []},
#  'переставать': {'Before': [{'ID': 1256, 'tokenText': 'перестаёт'}],
#   'After': []},
#  'чесаться': {'Before': [{'ID': 1256, 'tokenText': 'чесаться'}], 'After': []},
#  'того': {'Before': [{'ID': 1256, 'tokenText': 'того'}], 'After': []},
#  'мазать': {'Before': [{'ID': 1256, 'tokenText': 'мажем'}], 'After': []},
#  'неё': {'Before': [{'ID': 1256, 'tokenText': 'неё'}], 'After': []},
#  'краска': {'Before': [{'ID': 1256, 'tokenText': 'краску'}], 'After': []},
#  'жалеть': {'Before': [{'ID': 1256, 'tokenText': 'жалея'}], 'After': []},
#  'пятно': {'Before': [{'ID': 1256, 'tokenText': 'пятно'}], 'After': []},
#  'значить': {'Before': [{'ID': 1256, 'tokenText': 'значит'}], 'After': []},
#  'виноватый': {'Before': [{'ID': 1256, 'tokenText': 'виновата'}], 'After': []},
#  'кстати': {'Before': [{'ID': 1256, 'tokenText': 'кстати'}], 'After': []},
#  'хваля': {'Before': [{'ID': 1256, 'tokenText': 'хваля'}], 'After': []},
#  'вождь': {'Before': [{'ID': 1256, 'tokenText': 'вождя'}], 'After': []},
#  'приравнивать': {'Before': [{'ID': 1256, 'tokenText': 'приравнивали'}],
#   'After': []},
#  'сегодня': {'Before': [{'ID': 1256, 'tokenText': 'сегодня'}], 'After': []},
#  'найти': {'Before': [{'ID': 1256, 'tokenText': 'найти'}], 'After': []},
#  'сравнить': {'Before': [{'ID': 1256, 'tokenText': 'сравнить'}], 'After': []},
#  'называть': {'Before': [{'ID': 1256, 'tokenText': 'называем'}], 'After': []},
#  'вещь': {'Before': [{'ID': 1256, 'tokenText': 'вещи'}], 'After': []},
#  'объяснить': {'Before': [{'ID': 1256, 'tokenText': 'объяснить'}],
#   'After': []},
#  'более': {'Before': [{'ID': 1256, 'tokenText': 'более'}], 'After': []},
#  'понять': {'Before': [{'ID': 1256, 'tokenText': 'понять'}], 'After': []},
#  'дед': {'Before': [{'ID': 1256, 'tokenText': 'дед'}], 'After': []},
#  'абай': {'Before': [{'ID': 1256, 'tokenText': 'Абай'}], 'After': []},
#  'наивно': {'Before': [{'ID': 1256, 'tokenText': 'наивно'}], 'After': []},
#  'хлопочем': {'Before': [{'ID': 1256, 'tokenText': 'хлопочем'}], 'After': []},
#  'стоять': {'Before': [{'ID': 1256, 'tokenText': 'стоял'}], 'After': []},
#  'двор': {'Before': [{'ID': 1256, 'tokenText': 'дворе'}], 'After': []},
#  'наблюдать': {'Before': [{'ID': 1256, 'tokenText': 'наблюдая'}], 'After': []},
#  'качаться': {'Before': [{'ID': 1256, 'tokenText': 'качаются'}], 'After': []},
#  'качелях': {'Before': [{'ID': 1256, 'tokenText': 'качелях'}], 'After': []},
#  'внезапно': {'Before': [{'ID': 1256, 'tokenText': 'внезапно'}], 'After': []},
#  'начать': {'Before': [{'ID': 1256, 'tokenText': 'начал'}], 'After': []},
#  'хлопьями': {'Before': [{'ID': 1256, 'tokenText': 'хлопьями'}], 'After': []},
#  'падать': {'Before': [{'ID': 1256, 'tokenText': 'падать'}], 'After': []},
#  'погляди': {'Before': [{'ID': 1256, 'tokenText': 'погляди'}], 'After': []},
#  'ка': {'Before': [{'ID': 1256, 'tokenText': 'ка'}], 'After': []},
#  'обыкновенный': {'Before': [{'ID': 1256, 'tokenText': 'обыкновенный'}],
#   'After': []},
#  'бескрайний': {'Before': [{'ID': 1256, 'tokenText': 'бескрайнем'}],
#   'After': []},
#  'пар': {'Before': [{'ID': 1256, 'tokenText': 'паром'}], 'After': []},
#  'капля': {'Before': [{'ID': 1256, 'tokenText': 'капля'}], 'After': []},
#  'превратиться': {'Before': [{'ID': 1256, 'tokenText': 'превратившись'}],
#   'After': []},
#  'теперь': {'Before': [{'ID': 1256, 'tokenText': 'теперь'}], 'After': []},
#  'рассыпаться': {'Before': [{'ID': 1256, 'tokenText': 'рассыпается'}],
#   'After': []},
#  'макушка': {'Before': [{'ID': 1256, 'tokenText': 'макушке'}], 'After': []},
#  'момент': {'Before': [{'ID': 1256, 'tokenText': 'момент'}], 'After': []},
#  'верхушка': {'Before': [{'ID': 1256, 'tokenText': 'верхушку'}], 'After': []},
#  'карагач': {'Before': [{'ID': 1256, 'tokenText': 'карагача'}], 'After': []},
#  'стоить': {'Before': [{'ID': 1256, 'tokenText': 'стоящего'}], 'After': []},
#  'неподалеку': {'Before': [{'ID': 1256, 'tokenText': 'неподалеку'}],
#   'After': []},
#  'пречёрным': {'Before': [{'ID': 1256, 'tokenText': 'пречёрным'}],
#   'After': []},
#  'садиться': {'Before': [{'ID': 1256, 'tokenText': 'садится'}], 'After': []},
#  'стая': {'Before': [{'ID': 1256, 'tokenText': 'стая'}], 'After': []},
#  'правильный': {'Before': [{'ID': 1256, 'tokenText': 'Правильная'}],
#   'After': []},
#  'вёрстка': {'Before': [{'ID': 1256, 'tokenText': 'верстка'}], 'After': []},
#  '[': {'Before': [{'ID': 1256, 'tokenText': '['}], 'After': []},
#  'здесь](https://www.angime.com': {'Before': [{'ID': 1256,
#     'tokenText': 'здесь](https://www.angime.com'}],
#   'After': []},
#  '/': {'Before': [{'ID': 1256, 'tokenText': '/'}], 'After': []},
#  'ardak': {'Before': [{'ID': 1256, 'tokenText': 'ardak'}], 'After': []},
#  'razboynik': {'Before': [{'ID': 1256, 'tokenText': 'razboynik'}],
#   'After': []},
#  'rus': {'Before': [{'ID': 1256, 'tokenText': 'rus'}], 'After': []},
#  '\n \n ': {'Before': [{'ID': 1256, 'tokenText': '\n \n '}], 'After': []},
#  'выбор_антона_платонова': {'Before': [{'ID': 1256,
#     'tokenText': 'выбор_Антона_Платонова'}],
#   'After': []}}

# %%
jsonData = []
for keyword in tqdm(lemmaCts):
    if lemmaCts[keyword]['Before'] + lemmaCts[keyword]['After'] >= 25:
        a1 = scipyArray[keyword]['Before']
        a2 = scipyArray[keyword]['After']
        test = scipy.stats.ttest_ind(a1, a2, axis=0, equal_var=True, nan_policy='propagate', 
                              permutations=None, random_state=None, alternative='two-sided', trim=0)
        lemmaFreqs[keyword]['stats'] = {'statistic' : test.statistic, 'pvalue' : test.pvalue}
        jsonData.append({
            'keyword' : keyword,
            'info' : lemmaFreqs[keyword]
        })
# Out:
# 100%|█████████████████████████████████| 43565/43565 [00:02<00:00, 20289.01it/s]

# %%
random.choice(jsonData)['info']['nlp'].pos_
# Out:
# 'ADV'

# %%
# with open(f'frequencyData2-3_1.json', 'w', encoding='utf-8') as f:
#     json.dump(jsonData, f, ensure_ascii=False, indent=4)

# %% [markdown]
# #### Significant word breakdown

# %%
# filter data
data = [d for d in jsonData if not d['info']['Before']*d['info']['After']==0 ]
data = [d for d in data if d['info']['stats']['pvalue'] < .05]
data = [d for d in data if d['keyword'].isalpha()]
irrelevantWords = ['авторский', 'блог', 'личный', 'источник','автор']
data = [d for d in data if d['keyword'] not in irrelevantWords]
print(len(jsonData), len(data))
# Out:
# 1626 421

# %%
posDict = {'increase' : dict(), 'decrease' : dict()}
for d in data:
    which = ''
    if d['info']['After'] - d['info']['Before'] > 0:
        which = 'increase'
    else:
        which = 'decrease'
    pos = d['info']['nlp'].pos_
    posDict[which].setdefault(pos, [])
    posDict[which][pos].append(d)

# %%
sorted([p for p in set(list(posDict['increase'].keys()) + list(posDict['decrease'].keys()))])
# Out:
# ['ADJ',
#  'ADP',
#  'ADV',
#  'AUX',
#  'CCONJ',
#  'DET',
#  'NOUN',
#  'NUM',
#  'PART',
#  'PRON',
#  'PROPN',
#  'SCONJ',
#  'VERB']

# %% [markdown]
# ## Similarity

# %%
import time
import os.path

from django.conf import settings

from navec import Navec
from numpy import dot
from numpy.linalg import norm
from annoy import AnnoyIndex


NAVEC_PATH = "data4notebooks/navec_hudlit_v1_12B_500K_300d_100q.tar"
# ANNOY_INDEX_PATH = os.path.join(settings.ROOT_DIR, "parser_tool", "data", "ANNOY_tree.ann")

navec = Navec.load(NAVEC_PATH)
vocabulary = navec.vocab.words
word_to_index = dict()
for i, word in enumerate(vocabulary):
    word_to_index[word] = i

# %%
vecDict = dict()
for direction in posDict:
    vecDict.setdefault(direction, dict())
    for pos in posDict[direction]:
        vecDict[direction].setdefault(pos, [])
        keywords = [d['keyword'] for d in posDict[direction][pos]]
        for word in tqdm(keywords):
            try:
                embedding = navec[word]
                vecDict[direction][pos].append({
                    "word" : word,
                    "translatedword" : ts.google(word),
                    "vector" : list(float(v) for v in navec[word])
                })
            except:
                continue
# Out:
# 100%|██████████████████████████████████████████| 92/92 [02:21<00:00,  1.54s/it]
# 100%|████████████████████████████████████████████| 6/6 [00:05<00:00,  1.05it/s]
# 100%|████████████████████████████████████████████| 2/2 [00:04<00:00,  2.44s/it]
# 100%|██████████████████████████████████████████| 17/17 [00:21<00:00,  1.25s/it]
# 100%|██████████████████████████████████████████| 33/33 [00:41<00:00,  1.26s/it]
# 100%|████████████████████████████████████████████| 3/3 [00:05<00:00,  1.98s/it]
# 100%|████████████████████████████████████████████| 3/3 [00:03<00:00,  1.10s/it]
# 100%|████████████████████████████████████████████| 7/7 [00:10<00:00,  1.54s/it]
# 100%|██████████████████████████████████████████| 11/11 [00:14<00:00,  1.34s/it]
# 100%|████████████████████████████████████████████| 3/3 [00:05<00:00,  1.93s/it]
# 100%|████████████████████████████████████████████| 2/2 [00:03<00:00,  1.85s/it]
# 100%|████████████████████████████████████████| 102/102 [02:43<00:00,  1.60s/it]
# 100%|██████████████████████████████████████████| 17/17 [00:21<00:00,  1.29s/it]
# 100%|████████████████████████████████████████████| 2/2 [00:02<00:00,  1.17s/it]
# 100%|████████████████████████████████████████████| 2/2 [00:02<00:00,  1.22s/it]
# 100%|██████████████████████████████████████████| 45/45 [00:55<00:00,  1.23s/it]
# 100%|██████████████████████████████████████████| 40/40 [00:53<00:00,  1.33s/it]
# 100%|████████████████████████████████████████████| 2/2 [00:01<00:00,  1.11it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:20<00:00,  1.29s/it]
# 100%|████████████████████████████████████████████| 7/7 [00:06<00:00,  1.02it/s]
# 100%|████████████████████████████████████████████| 2/2 [00:02<00:00,  1.35s/it]
# 100%|████████████████████████████████████████████| 3/3 [00:04<00:00,  1.51s/it]
# 100%|████████████████████████████████████████████| 2/2 [00:02<00:00,  1.43s/it]
# 100%|████████████████████████████████████████████| 2/2 [00:03<00:00,  1.95s/it]

# %%
with open(f'../similarity/sigMeanDiffVecsTranslated0.json', 'w', encoding='utf-8') as f:
    json.dump(vecDict, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## Synsets

# %%
# !ruwordnet download
# Out:
# downloading a ruwordnet model from https://github.com/avidale/python-ruwordnet/releases/download/0.0.4/ruwordnet-2021.db

# %%
from ruwordnet import RuWordNet
wn = RuWordNet()

# %%
lemma = 'мир'
for sense in wn.get_senses(lemma):
    print(sense.synset.title.lower())
# Out:
# вселенная, мироздание, мир
# сообщество (совокупность людей)
# мир, отсутствие конфликтов
# мир, отсутствие войны

# %%
lemmaCts = dict()
totalPoemCts = dict()
scipyArray = dict()
sense2lemmas = dict()

for r in tqdm(records):
    p = r['Before or after']
    totalPoemCts.setdefault(p, 0)
    lemmasFound = set()
    totalPoemCts[p] += 1
    for t in r['doc']:
        if t.lemma_ not in lemmasFound:
            for sense in wn.get_senses(t.lemma_):
                title = sense.synset.title.lower()
                sense2lemmas.setdefault(sense, set())
                sense2lemmas[sense].add(t.lemma_)
                lemmaCts.setdefault(title, {'Before' : 0, 'After' : 0})
                lemmaCts[title][p] += 1
            lemmasFound.add(t.lemma_)
        else:
            continue
lemmaFreqs = dict()
for word in lemmaCts:
    lemmaFreqs.setdefault(word, {'Before' : 0, 'After' : 0})
    for p in lemmaCts[word]:
        lemmaFreqs[word][p] = lemmaCts[word][p]/totalPoemCts[p]
        lemmaFreqs[word][p+'Ct'] = lemmaCts[word][p]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jj/_szc94p56q91q_7c209d1d9w0000gn/T/ipykernel_37206/3289863467.py in <module>
#       3 scipyArray = dict()
#       4
# ----> 5 for r in tqdm(records):
#       6     p = r['Before or after']
#       7     totalPoemCts.setdefault(p, 0)
#
# NameError: name 'tqdm' is not defined

# %%
    # check if title already added
    title = synset.title
    # change synset label to lemma label if only one lemma mentioned
    if len(synsetTokens[synset]) == 1:
        title = list(synsetTokens[synset].keys())[0]
        
    # if title already added, skip entry, else continue
    if title in titleAddedAlready:
        print('OLD:',title, synset.title)
        print('NEW:',title, lemma2synset[title])
        continue
    else:
        lemma2synset[title] = synset.title
        titleAddedAlready.add(title)

# %% [markdown]
# #### Language Detection

# %%
# !pip3 install spacy-language-detection

# %%
import spacy
from spacy.language import Language

from spacy_language_detection import LanguageDetector


def get_lang_detector(nlp, name):
    return LanguageDetector(seed=42)  # We use the seed 42

# %%
nlp_model = spacy.load("ru_core_news_lg")
Language.factory("language_detector", func=get_lang_detector)
nlp_model.add_pipe('language_detector', last=True)

# Sentence level language detection
text = "This is English text. Er lebt mit seinen Eltern und seiner Schwester in Berlin. Yo me divierto todos los días en el parque. Je m'appelle Angélica Summer, j'ai 12 ans et je suis canadienne."
doc = nlp_model(text)
for i, sent in enumerate(doc.sents):
    print(sent, sent._.language)
# Out:
# This is English text. {'language': 'en', 'score': 0.9999987929307774}
# Er lebt mit seinen Eltern und seiner Schwester in Berlin. {'language': 'de', 'score': 0.999996045846908}
# Yo me divierto todos los días en el parque. {'language': 'es', 'score': 0.9999960751128256}
# Je m'appelle Angélica Summer, j'ai 12 ans et je suis canadienne. {'language': 'fr', 'score': 0.9999960488878062}

# %%
from tqdm import tqdm 
random.shuffle(records)
for rec in tqdm(records):
    rec['Doc'] = nlp_model(rec['Text'])
# Out:
# 100%|███████████████████████████████████████| 3252/3252 [05:13<00:00, 10.36it/s]

# %%
langDict = dict()
for rec in tqdm(records):
    for sent in rec['Doc'].sents:
        langDict.setdefault(sent._.language['language'], [])
        langDict[sent._.language['language']].append((sent, rec))
# Out:
# 100%|███████████████████████████████████████| 3252/3252 [07:47<00:00,  6.96it/s]

# %%
langDict.keys()
# Out:
# dict_keys(['ru', 'UNKNOWN', 'bg', 'mk', 'uk', 'en', 'et', 'hr', 'tl', 'ro', 'lt', 'de', 'id', 'ca', 'sk'])

# %%
lg = 'sk'
print(len(langDict[lg]))
[print('Unique index:',d[1]['UniqueIndex'],'\n', d[0],'\n--') for d in random.sample(langDict[lg],1)]
# Out:
# 1
# Unique index: 1652
#  Како добро живети…
# …Ako žiť dobre…
# …Kako dobro živeti.
# --
# [None]

# %%
# 523
r = [r for r in records if r['UniqueIndex'] == 3239][0]

# %%
r['Source'], r['Author'], r['Date posted']
# Out:
# ('essentialpoetry', 'Линор Горалик', datetime.datetime(2018, 5, 9, 0, 0))

# %%
print(r['Text'])
# Out:
# Вот красным лесом красная лиса, –
# а он лежит, смешавшись с автоматом,
# в осеннем красном буром чернозёме,
# неглубоко, –
# и вот лиса несётся,
# пересекая сердце, горло, сердце, –
# подскакивает, лапой влезши в душу,
# отряхивает лапу, мчится дальше, –
# И он кричит распавшейся гортанью:
#
# КАКОГО ХУЯ, ГОСПОДИ, – ЗА ЧТО?!
#
# Я не успел – я инвалид по зренью, –
# я не успел, – они меня в апреле,
# когда уже исход и всё понятно,
# когда таких, как я, – едва одетых,
# полуслепых, хромых или безусых, –
# от киндер, кирхе, запаха из кюхен, –
# в зелёный их апрельский красный лес,
# где я от крови ничего не видел,
# и красный зверь, и горло, сердце, горло –
# а я ни разу даже не пальнул,
# я не успел –
# какого хуя, Боже?!
#
# ТАК ДАЙ МНЕ, ДАЙ МНЕ, ДАЙ МНЕ ЧТО-НИБУДЬ!!!
#
# И тут лиса упала и лежит.

# %%
# other

# %%
total = 0
for rec in records:
    total += len(str(rec['Text']).split(' '))
# 345043
total
# Out:
# 342235

# %%
df['Source'].value_counts()
# Out:
# essentialpoetry      945
# No War Poetry        724
# metajournal          662
# ROAR V3              350
# Facebook             253
# ROAR V2              234
# Personal Telegram     54
# Name: Source, dtype: int64

# %%
df['Before or after'].value_counts()
# Out:
# Before    1661
# After     1561
# Name: Before or after, dtype: int64

# %% [markdown]
# ### Remove duplicates from corpus

# %%
print(random.choice(records)['Text'][:200])
# Out:
# Развивая Бродского
# 1
# Я хотел бы жить, Иосиф, как можно дольше, пока
# ритмично дыханье и тянется на бумаге строка,
# жизнь - гостиный двор, мы временные постояльцы,
# и какое мне дело до того городка,
# где и

# %%
longStringCts = dict()
string2Recs = dict()
string2RecIdx = dict()

windowSize = 100
for i, rec in tqdm(enumerate(records)):
    text = rec['Text']
    rec['UniqueIndex'] = i
    if isinstance(text, str):
        for j in range(len(text)-windowSize):
            windowText = text[j:j+windowSize]
            longStringCts.setdefault(windowText, 0)
            longStringCts[windowText] += 1
            string2Recs.setdefault(windowText, [])
            string2Recs[windowText].append(rec)
            # string2RecIdx.setdefault(windowText, set())
            # string2RecIdx[windowText].add(i)
# Out:
# 3502it [00:08, 406.86it/s]

# %%
relevantCts = dict()
for s in tqdm(longStringCts):
    if longStringCts[s] > 1:
        relevantCts[s] = longStringCts[s]
# Out:
# 100%|████████████████████████████| 2284719/2284719 [00:01<00:00, 1186974.80it/s]

# %%
overlappingRecs = []
for s in tqdm(relevantCts):
    shareString = string2Recs[s]
    if shareString not in overlappingRecs:
        # ids = [r['UniqueIndex'] for r in shareString]
        # if set(ids) 
        overlappingRecs.append(shareString)
len(overlappingRecs)
# Out:
# 100%|█████████████████████████████████| 64074/64074 [00:00<00:00, 133374.94it/s]
# 228

# %%
import datetime

# %%
def decideRec(recList):
    # if just one, return rec
    if len(recList) == 1:
        return recList[0:]
    # convert to datetimes
    for r in recList:
        if not isinstance(r['Date posted'], datetime.datetime):
            # essentialpoetry      1023
            # No War Poetry         793
            # metajournal           713
            # ROAR V3               357
            # Facebook              281
            # ROAR V2               269
            # Personal Telegram      66
            if r['Source'] == 'ROAR V2':
                r['Date posted'] = datetime.datetime(2022, 6, 24, 0, 0)
            elif r['Source'] == 'ROAR V3':
                r['Date posted'] = datetime.datetime(2022, 8, 24, 0, 0)
            else:
                r['Date posted'] = datetime.datetime(2022,12,17,0,0)
    # compare date
    sortedByDate = []
    for i, rec in enumerate(recList):
        sortedByDate.append((rec['Date posted'], i))
    sortedByDate = sorted(sortedByDate)
    # check types
    if isinstance(sortedByDate[0], datetime.datetime) and isinstance(sortedByDate[1], datetime.datetime):
        if sortedByDate[0] != sortedByDate[1]:
            return recList[sortedByDate[0][1]]
    else:
        idxs = [s[1] for s in sortedByDate[1:]]
        return [recList[j] for j in idxs]
    
    # compare length of text
    sortedByLen = []
    for i, rec in enumerate(recList):
        sortedByLen.append((len(rec['Text']), i))
    sortedByLen = sorted(sortedByLen)
    idxs = [s[1] for s in sortedByLen[1:]]
    return [recList[j] for j in idxs]

# %%
records[162]
# Out:
# {'Text': '\nРевёт жена опальная,\nв правах поражена.\nИдёт война двуспальная,\nгражданская война.\nПомыты кухня, ванная\nслезами в три ручья.\nИдёт война диванная,\nтрещит по швам семья.\n+\nБудущему малышу,\nптицам небесным пища?\nСижу в уголке, пишу\nугольком пепелища\nродного. Роднее нет.\nМай. Четвёртое мая.\nВ окне кабинета свет:\nне выключила, убегая.\n+\nВсе страны, кроме одной.\nЧто же мы так бездомны?\nВстречаемся, мой родной,\nоколо пятой колонны\nбольшого театра войны —\nв Эривани, в Тифлисе,\nкак рыбе зонтик нужны\nмировой закулисе.\n+\nОт грохота, скрежета, лязга\nсжимается матка.\nКачает пустую коляску.\nЦе хлопчик? Дiвчатко.\nПоёт колыбельную дочке.\nПечаль непроглядна.\nВойна. Молока на сорочке\nрасплывающиеся пятна.\n+\nСвидетельств — терабайт,\nкак мой народ ушёл\nв искусственный офсайд.\nНо засчитали гол\nи торжествует зло,\nи стадион орёт.\nМне очень повезло\nуспеть на самолёт.\n+\nМеждународный язык —\nмладенческий лепет.\nСпит у груди призывник\nГолгофы. Колеблет\nвоздух взрывная волна.\nПротивник не выбит.\nПуть отрезает война\nдля бегства в Египет.\n+\nНе говори: я стреляю мимо.\nПуля не дура — летит до конца.\nВыстрелишь в небо — убьёшь херувима.\nВыстрелишь в землю — убьёшь мертвеца.\nПтицу. Крота. Стрекозу. Полёвку.\nПуля не дура — найдёт себе цель.\nНе слушай комбата — бросай винтовку.\nПослушайся маму — забейся в щель.\n+\nПросыпаешься — война.\nДа какой тут сон,\nесли спальня спалена,\nесли дом сожжён,\nесли город стал золой,\nпеплом — стар и млад,\nесли не смолкает бой\nи творится ад.\n+\nЛевый плачет об одном,\nправый — о другом.\nЛевый: взорван детский дом.\nПравый: где мой дом?\nНе кори слезу, слеза.\nКолокольный звон,\nнаучи мои глаза\nплакать в унисон.\n+\nСпросит внучка, спросит внук:\nКак ты воевала?\nЯ полку друзей-подруг\nплакать помогала.\nСпросит кто-нибудь из них:\nКак ты победила?\nЯ любимых-дорогих\nимена твердила.\n+\nапофеоз войны\nсажи золы бурьяна\nвсе до одной черны\nклавиши фортепьяно\nбудем играть на нём\nразмазывая копоть\nпод проливным огнем\nв чьей-то крови по локоть\n+\nтрам-там-там\nтрам-там-там\nмаменькин сынок\nпомещён по частям\nв мусорный мешок\nмина взрыв\nмина взрыв\nиз отчёта стёрт\nГосударству — призыв,\nродине — аборт.\n+\nсветомаскировка\nночи звёздный час\nприлегла винтовка\nприкорнул фугас\nа когда проснутся\nпо команде пли\nзвёзды отвернутся\nот моей Земли\n+\nДело мое дрянь.\nСделана сказка пылью.\nПлáчу — плачу дань\nгневу, стыду, бессилью.\nСилой берут дев,\n“Мурку” орут орки.\nТы близорук, гнев.\nСлёзы, вы дальнозорки.\n+\nРадость передышки краткой,\nшуточки о женской доле\nпосле схватки, перед схваткой\nв мариупольском роддоме.\nСокращайтесь, мышцы матки,\nвремя дорого: убийца\nвожделеет — взятки гладки —\nкровью с молоком упиться.\n+\nКто в подвале зачах?\nКто под землю несёт\nдевочку на сносях,\nраненную в живот?\nКто при свете свечи\nжизнью должен истечь?\nВсё, стишок, замолчи.\nТут кончается речь.\n+\nНа фотографии —\nмаленький мальчик,\nпод фотографией —\nплачущий смайлик.\nЛёгкая лодочка.\nХраброе бегство.\nЗоркость наводчика.\nВечное детство.\n+\nДопускать правоту Пилата,\nпонимать и прощать Иуду\nне просите меня, не надо, —\nне хочу, не могу, не буду,\nпотому что слова-пароли,\nпотому что отзывы-рифмы\nтолерантны до первой крови,\nдо последней непримиримы.\n+\nСколько гробов по плечу\nженскому человеку?\nПлачу о мёртвых — плачу\nпожизненную ипотеку,\nтрачу кап-кап-капитал.\nМать утешавший “Жено,\nне плачь”, не Ты ли сказал,\nчто плачущие блаженны?\n+\nНе на митинге, не в неволе,\nне в убежище, не в бою\nя беру интервью у боли.\nГлавный жанр сейчас — интервью.\nНе под бомбами, не в обозе,\nне на кладбище, не в строю\nсокрушительные вопросы\nя самой себе задаю.\n+\nБудем под прицелами плясать\nна колючей провололке над бездной,\nбудем русским языком лизать\nна морозе занавес железный,\nбудем огороды городить,\nбудем, позабыв попытку-пытку,\nв сон, как в самоволку, уходить,\nв прошлое проситься на побывку.\n+\nПеть перестал? Писать перестал?\nНовос ...
#  'Author': 'Вера Павлова',
#  'Before or after': 'After',
#  'Source': 'ROAR V2',
#  'Date posted': datetime.datetime(2022, 6, 24, 0, 0),
#  'UniqueIndex': 162}

# %%
counts = dict()
for recList in overlappingRecs:
    counts.setdefault(len(recList),0)
    counts[len(recList)] += 1

# %%
# create new list using only the earliest overlapping rec
repeatIdxs = set()
for recList in overlappingRecs:
    badRecs = decideRec(recList)
    badIdxs = [b['UniqueIndex'] for b in badRecs]
    for b in badIdxs:
        repeatIdxs.add(b)

# %%
cleanRecList = []
j = 0
for i, rec in enumerate(records):
    if rec['UniqueIndex'] not in repeatIdxs:
        rec['UniqueIndex'] = j
        cleanRecList.append(rec)
        j += 1
len(cleanRecList)
# Out:
# 3289

# %%
cleanRecList[1000]
# Out:
# {'Text': '***\n \n– В Москве – невкусная клубника, бери водку!\n \nВ вытянутой трубке сна так тихо,\n \nЧто можно услышать\n \nНеуловимую чёрную лодку.\n \nСпрашиваю:\n \n– Это каяк?\n \nПтица с ветки:\n \n– Каяк, каяк. Что с тобою не так?\n \n– Со мною не так носовой платок,\n \nКаждое слово.\n \nНеба бесформенный носорог\n \nОживает в половине шестого.\n \nНаблюдаю за ним из окна.\n \nУ меня проблема только одна:\n \n«Скендербеу», «Хабнарфьордюр» и «Нымме Калью» проиграли свои матчи.\n \nИ три любимых, но непростых занятья:\n \nСмотреть на осину,\nСмотреть на берёзу,\nСмотреть на тополь.\n \nМошка умерла у меня на глазах,\nА что пережил ты?\n \n \n(интернет-журнал ”Literratura”)\n \n#выбор_Максима_Дрёмова',
#  'Author': 'Денис Крюков',
#  'Before or after': 'Before',
#  'Source': 'metajournal',
#  'Date posted': datetime.datetime(2019, 11, 14, 0, 0),
#  'UniqueIndex': 1000}

# %%
cleanDf = pd.DataFrame.from_records(cleanRecList)

# %%
cleanDf.to_excel('../Excel_files/Full_Poem_Dataset_12-17.xlsx')

# %% [markdown]
# ## AUTHOR DATA

# %%
authorInfo = pd.read_excel('../Excel_files/Thesis Authors.xlsx')
authorInfo.head()
# Out:
#    Number of Poems                Author      City     Country Identification  \
# 0                3        Виген Аракелян    Razdan     Armenia            NaN
# 1                1     Герман Лукомников      Baku  Azerbaijan            NaN
# 2                1  Александр Иличевский   Sumgait  Azerbaijan            NaN
# 3                7           Леонид Шваб  Babruysk     Belarus            NaN
# 4                6        Ирина Валерина  Babruysk     Belarus            NaN
#
#   Notes                                        Link to bio
# 0   NaN                https://polutona.ru/?show=arakelian
# 1   NaN  https://ru.wikipedia.org/wiki/%D0%9B%D1%83%D0%...
# 2   NaN  https://ru.wikipedia.org/wiki/%D0%98%D0%BB%D0%...
# 3   NaN  http://www.litkarta.ru/world/israel/persons/sh...
# 4   NaN                                                NaN

# %%
authorInfo['Country'].value_counts()
# Out:
# Russia          370
# Ukraine          86
# Kazakhstan       26
# Belarus          16
# Uzbekistan        6
# Moldova           5
# Latvia            5
# Estonia           4
# Kyrgyzstan        2
# Azerbaijan        2
# Lithuania         1
# Iran              1
# Georgia           1
# Tajikistan        1
# Turkmenistan      1
# USA               1
# Armenia           1
# Name: Country, dtype: int64

# %%
value_counts
